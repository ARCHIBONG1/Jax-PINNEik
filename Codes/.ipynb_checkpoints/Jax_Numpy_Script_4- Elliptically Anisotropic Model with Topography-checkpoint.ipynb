# %% [markdown]
# ## Elliptically Anisotropic Model with Topography

# %% [markdown]
# #### Table of Contents
# <ul>
# <li><a href="#lib">Necessary Libraries<a/></li>
# <li><a href="#gpu">GPU Setting & Code Reproducibility<a/></li>
# <li><a href="#model">Elliptically Anisotropic Model with Topography<a/></li>
# <li><a href="#params">Analytical Parameters<a/></li>
# <li><a href="#train">Training & Testing Data<a/></li>
# <li><a href="#sids">Source Location ID<a/></li>
# <li><a href="#archi">Network Architecture & Parameter Initialisation<a/></li>
# <li><a href="#tau">Neural Network<a/></li>
# <li><a href="#pde">Eikonal PDE Loss<a/></li>
# <li><a href="#other">Other Losses<a/></li>
# <li><a href="#combine">Combined Loss Function<a/></li>
# <li><a href="#new">Model Training<a/></li>
# <li><a href="#t_pred">T Prediction<a/></li>

# %% [markdown]
# <a id="lib"></a>
# #### Necessary Libraries

# %%
# Jax Libraries
import jax
import jax.numpy as jnp
from jax import grad, jit, random
import optax
import pickle
from jax.lib import xla_bridge

# Data Visualisation Libraries
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.ndimage import gaussian_filter1d

# Operating System and gpu
import os 
import subprocess

# Additional 
import timeit
import pandas as pd

# %% [markdown]
# <a id="gpu"></a>
# #### GPU Setting & Code Reproducibility

# %%
# Displays if the notebook currently has access to a gpu
print(f"This Notebook is currently running on a: {(xla_bridge.get_backend().platform)}")

# Assigns a specific GPU to be used
GPU = 0
os.environ['CUDA_VISIBLE_DEVICES'] = 'GPU'

# Displays the GPU details used for the notebook execution
output = subprocess.check_output(['nvidia-smi', '-L']).decode('utf-8')
gpu_info = output.strip().split('\n')
print(gpu_info[GPU])

# Defines a random key to be employed using seed 0
random_key = random.PRNGKey(0)
# Out:
# This Notebook is currently running on a: gpu
# GPU 0: NVIDIA RTX A5000 (UUID: GPU-8b9362c6-1305-75bd-e211-a767d8b39a65)

# %% [markdown]
# <a id="model"></a>
# #### Elliptically Anisotropic Model with Topography

# %%
# Loading velocity models

vel_z = jnp.load("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/inputs/vtiseam/model/vzcoarse.npy")
#vz = vel_z[::50,::50]

vel_x = jnp.load("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/inputs/vtiseam/model/vxcoarse.npy")
#vx = vel_x[::50,::50]

#epsilon = 0.5*(vx**2/vz**2 - 1)
epsilon = 0.5*(vel_x**2/vel_z**2 - 1)

eta = epsilon*0.

# %%
#Model specifications

# Grid on the vertical axis 
z_min = 0.; z_max = 10.; z_delta = 0.05

# Grid on the horizontal axis
x_min = 0.; x_max = 10.; x_delta = 0.05

# Generating the vertical and horizontal values of our model
z = jnp.arange(z_min,z_max+z_delta,z_delta)
nz = z.size
x = jnp.arange(x_min,x_max+x_delta,x_delta)
nx = x.size

# Source location on the vertical (sz) and horizontal(sy) axes
sz=8.0
sx=5.0
print('Source location:(%.2f,%.2f)'%(sx,sz))

# Number of training points
training_points = 5000
# Out:
# Source location:(5.00,8.00)

# %%
# Loading the topography data
filename = '/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/inputs/vtiseam/model/elevation.txt'
with open(filename, 'r') as file:
    lines = file.readlines()
    data = [line.split() for line in lines]
    data = jnp.array(data, dtype=jnp.float32)

topo = data[0:401:2, 2] / 1000
topo = gaussian_filter1d(topo, 8)
topo = 100*jnp.gradient(jnp.gradient(topo))+jnp.round(1.2 + 1.2*jnp.sin(x)*jnp.cos(x) ,4)

# %%
# Plot the topography layer

plt.style.use('default')    # Sets the default style for the plot

plt.figure(figsize=(4,4))   # Creates a new figure with a size of 4x4 inches

plt.title("Elliptically Anisotropic Model (topo)")    # Sets the title of the figure

ax = plt.gca()              # Gets the current axes instance.

plt.plot(x,topo)            # Plots the topography

ax.plot(sx,sz,'k*',markersize=8)  # Plots a black star marker at the source location 

plt.xlim(x_min,x_max)       # Defines the horizontal limits of the plot
plt.ylim(z_min,z_max)       # Defines the vertical limits of the plot

plt.gca().invert_yaxis()    # Gets and inverts the y axis instance

plt.xlabel('Offset (km)', fontsize=14) # Sets the label for the x-axis
plt.xticks(fontsize=10)    # Sets the font size for the x-axis tick labels

plt.ylabel('Depth (km)', fontsize=14)  # Sets the label for the y-axis
plt.yticks(fontsize=10)    # Sets the font size for the y-axis tick labels

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/Elliptically Anisotropic Model (topo).pdf", format= "pdf",bbox_inches="tight")  # Saves the image as a pdf file at the specified file directory

plt.show() # Displays the plot

# %%
# Creating grid with points above topography markes as NaN

Z = []
X = []

# For each x component, the loop marks y values above topo at that x to be Nan
for i in enumerate(x):

    index = i[0]; x_val = i[1]
    z_temp = [z[j[0]] if z[j[0]] >= topo[index] else float("Nan") for j in enumerate(z)]                 
    Z = jnp.concatenate([jnp.asarray(Z), jnp.asarray(z_temp)])
    X = jnp.concatenate([jnp.asarray(X),jnp.asarray(jnp.ones(len(z_temp))*x_val)])

# Copying Nan from Z to X
X = X + Z*0.

# Reshaping X and Z to the original model size
X = X.reshape(jnp.meshgrid(z,x,indexing='ij')[0].shape).T
Z = Z.reshape(jnp.meshgrid(z,x,indexing='ij')[0].shape).T

TOPO = jnp.where(X != 0, jnp.divide(X, X,), 1)

# %%
# Overlaying topography on the model
vz = vel_z*TOPO
vx = vel_x*TOPO
epsilon = epsilon*TOPO
eta = eta*TOPO

# %%
# Plot the velocity model with the source location

plt.style.use('default')     # Sets the default style for the plot

plt.figure(figsize=(4,4))    # Creates a new figure with a size of 4x4

plt.title("Elliptically Anisotropic Model (vz)")    # Sets the title of the figure

ax = plt.gca()              # Gets the current axes instance.
im = ax.imshow(vz, extent=[x_min,x_max,z_max,z_min], aspect=1, cmap="jet")  # Plots the velocity model as an image on the current axes (ax)

ax.plot(sx,sz,'k*',markersize=8)  # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14) # Sets the label for the x-axis
plt.xticks(fontsize=10)           # Sets the font size for the x-axis tick labels

plt.ylabel('Depth (km)', fontsize=14)  # Sets the label for the y-axis
plt.yticks(fontsize=10)           # Sets the font size for the y-axis tick labels

ax.xaxis.set_major_locator(plt.MultipleLocator(2)) # Sets the major tick locator for the x-axis to have ticks at intervals of 0.5.
ax.yaxis.set_major_locator(plt.MultipleLocator(2)) # Sets the major tick locator for the y-axis to have ticks at intervals of 0.5.

divider = make_axes_locatable(ax)  # Creates a divider to make room for the colorbar
cax = divider.append_axes("right", size="6%", pad=0.15) # Appends an axes on the right side of the plot to accommodate the colorbar

cbar = plt.colorbar(im, cax=cax)   # Adds a colorbar to the plot using the image im and the colorbar axes cax

cbar.set_label('km/s',size=10)     # Sets the label for the colorbar.
cbar.ax.tick_params(labelsize=10)  # Sets the font size of the colorbar tick labels.

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/Elliptically Anisotropic Model (vz).pdf", format='pdf', bbox_inches="tight")

# %%
# Plot the velocity model with the source location

plt.style.use('default')     # Sets the default style for the plot

plt.figure(figsize=(4,4))    # Creates a new figure with a size of 4x4

plt.title("Elliptically Anisotropic Model (vx)")    # Sets the title of the figure

ax = plt.gca()              # Gets the current axes instance.
im = ax.imshow(vx, extent=[x_min,x_max,z_max,z_min], aspect=1, cmap="jet")  # Plots the velocity model as an image on the current axes (ax)

ax.plot(sx,sz,'k*',markersize=8)  # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14) # Sets the label for the x-axis
plt.xticks(fontsize=10)           # Sets the font size for the x-axis tick labels

plt.ylabel('Depth (km)', fontsize=14)  # Sets the label for the y-axis
plt.yticks(fontsize=10)           # Sets the font size for the y-axis tick labels

ax.xaxis.set_major_locator(plt.MultipleLocator(2)) # Sets the major tick locator for the x-axis to have ticks at intervals of 0.5.
ax.yaxis.set_major_locator(plt.MultipleLocator(2)) # Sets the major tick locator for the y-axis to have ticks at intervals of 0.5.

divider = make_axes_locatable(ax)  # Creates a divider to make room for the colorbar
cax = divider.append_axes("right", size="6%", pad=0.15) # Appends an axes on the right side of the plot to accommodate the colorbar

cbar = plt.colorbar(im, cax=cax)   # Adds a colorbar to the plot using the image im and the colorbar axes cax

cbar.set_label('km/s',size=10)     # Sets the label for the colorbar.
cbar.ax.tick_params(labelsize=10)  # Sets the font size of the colorbar tick labels.

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/Elliptically Anisotropic Model (vx).pdf", format='pdf', bbox_inches="tight")

# %%
# Plot the velocity model with the source location

plt.style.use('default')     # Sets the default style for the plot

plt.figure(figsize=(4,4))    # Creates a new figure with a size of 4x4

plt.title("Elliptically Anisotropic Model (eta)")    # Sets the title of the figure

ax = plt.gca()              # Gets the current axes instance.
im = ax.imshow(eta, extent=[x_min,x_max,z_max,z_min], aspect=1, cmap="jet")  # Plots the velocity model as an image on the current axes (ax)

ax.plot(sx,sz,'k*',markersize=8)  # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14) # Sets the label for the x-axis
plt.xticks(fontsize=10)           # Sets the font size for the x-axis tick labels

plt.ylabel('Depth (km)', fontsize=14)  # Sets the label for the y-axis
plt.yticks(fontsize=10)           # Sets the font size for the y-axis tick labels

ax.xaxis.set_major_locator(plt.MultipleLocator(2)) # Sets the major tick locator for the x-axis to have ticks at intervals of 0.5.
ax.yaxis.set_major_locator(plt.MultipleLocator(2)) # Sets the major tick locator for the y-axis to have ticks at intervals of 0.5.

divider = make_axes_locatable(ax)  # Creates a divider to make room for the colorbar
cax = divider.append_axes("right", size="6%", pad=0.15) # Appends an axes on the right side of the plot to accommodate the colorbar

cbar = plt.colorbar(im, cax=cax)   # Adds a colorbar to the plot using the image im and the colorbar axes cax

cbar.set_label('km/s',size=10)     # Sets the label for the colorbar.
cbar.ax.tick_params(labelsize=10)  # Sets the font size of the colorbar tick labels.

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/Elliptically Anisotropic Model (eta).pdf", format='pdf', bbox_inches="tight")

# %% [markdown]
# <a id="params"></a>
# #### Analytical Parameters

# %%
# Analytical solution for the known traveltime part

vx0 = vx[int(round(sz/z_delta)),int(round(sx/x_delta))]
vz0 = vz[int(round(sz/z_delta)),int(round(sx/x_delta))]

T0 = jnp.sqrt(((vz0**2)*(X-sx)**2 + (vx0**2)*(Z-sz)**2 )/(vx0**2*vz0**2)); 

px0 = jnp.where(T0 != 0, jnp.divide(X - sx, (vx0**2)*T0), 0)  # Calculates the x-component of the vector 

pz0 = jnp.where(T0 != 0, jnp.divide(Z - sz, (vz0**2)*T0), 0)  # Calculates the y-component of the vector

# %% [markdown]
# <a id="train"></a>
# #### Training & Testing Data

# %%
# Grid points for prediction 
X_star = [Z.reshape(-1,1), X.reshape(-1,1)]

# %%
# Total training point include the number of training points above plus the ratio of Nans in the original X
total_training_points = int(round(training_points*(jnp.sum(1+jnp.isnan(X))/X.size)))
selected_points = random.choice(random_key,jnp.arange(Z.size),shape=(total_training_points,),replace=False)

selected_points = X.reshape(-1,1)[selected_points]*0 + selected_points.reshape(-1,1)
selected_points = selected_points[~jnp.isnan(selected_points)]
selected_points = selected_points.astype(int)


Zf = Z.reshape(-1,1)[selected_points]
Zf = jnp.append(Zf,sz)
Xf = X.reshape(-1,1)[selected_points]
Xf = jnp.append(Xf,sx)


X_starf = [Zf.reshape(-1,1), Xf.reshape(-1,1)] # Grid points for training

# %%
jnp.shape(X_starf)
# Out:
# (2, 4916, 1)

# %%
# Checking if any NaN value is left unremoved in selected points for training
jnp.sum(jnp.isnan(jnp.asarray(X_starf)))
# Out:
# Array(0, dtype=int32)

# %%
# Appending source values
vzf = vz.reshape(-1,1)[selected_points]; vzf = jnp.append(vzf,vz[int(round(sz/z_delta)),int(round(sx/x_delta))])
epsilonf = epsilon.reshape(-1,1)[selected_points]; epsilonf = jnp.append(epsilonf,epsilon[int(round(sz/z_delta)),int(round(sx/x_delta))])
etaf = eta.reshape(-1,1)[selected_points]; etaf = jnp.append(etaf,eta[int(round(sz/z_delta)),int(round(sx/x_delta))])
px0f = px0.reshape(-1,1)[selected_points]; px0f = jnp.append(px0f,0.)
pz0f = pz0.reshape(-1,1)[selected_points]; pz0f = jnp.append(pz0f,0.)
T0f = T0.reshape(-1,1)[selected_points]; T0f = jnp.append(T0f,0.)

# %% [markdown]
# <a id="sids"></a>
# #### Source Location ID

# %%
# Find source location id in X_starf

TOLX = 1e-6
TOLZ = 1e-6

sids,_ = jnp.where(jnp.logical_and(jnp.abs(X_starf[0]-sz)<TOLZ , jnp.abs(X_starf[1]-sx)<TOLX))

print(sids)
print(sids.shape)
print(X_starf[0][sids,0])
print(X_starf[1][sids,0])
# Out:
# [4915]
# (1,)
# [8.]
# [5.]

# %% [markdown]
# <a id="archi"></a>
# #### Network Architecture & Parameter Initialisation

# %%
# Architecture of the neural network model
layers = [2,20,20,20,20,20,20,20,20,20,20,1]

# %% [markdown]
# > The random initialisation function using xavier initialisation has been defined below. However, this random initialisation is commented out and was not used to train the model for this script. The weights used to trained the model for this script are the learned weight from the smooth velocity model in script 1. This was done primarily to speedup the convergence of gradient descent and the function defined below was defined purely as an alternative

# %%
"""
# Function to randomly initialise the network parameters using Xavier iniatialisation
def init_params(layers):

  keys = jax.random.split(jax.random.PRNGKey(0),len(layers)-1)
  params = list()      # Defines an empty list to store the parameters

  for key,n_in,n_out in zip(keys,layers[:-1],layers[1:]):   # For loop iterates over the keys, number of input neurons (n_in), and number of output neurons 
    lb = -(1 / jnp.sqrt(n_in)) # lower bound
    ub = (1 / jnp.sqrt(n_in)) # upper bound
    W = lb + (ub-lb) * jax.random.uniform(key,shape=(n_in,n_out))  # Initialises the weight matrix
    B = jax.random.uniform(key,shape=(n_out,))             # Initialises the bias vector 
    params.append({'W':W,'B':B})                           # Adds a dictionary containing the weight matrix W and bias vector B to the params list
  return params        # Returns the initialised parameters
"""
# Out:
# "\n# Function to randomly initialise the network parameters using Xavier iniatialisation\ndef init_params(layers):\n\n  keys = jax.random.split(jax.random.PRNGKey(0),len(layers)-1)\n  params = list()      # Defines an empty list to store the parameters\n\n  for key,n_in,n_out in zip(keys,layers[:-1],layers[1:]):   # For loop iterates over the keys, number of input neurons (n_in), and number of output neurons \n    lb = -(1 / jnp.sqrt(n_in)) # lower bound\n    ub = (1 / jnp.sqrt(n_in)) # upper bound\n    W = lb + (ub-lb) * jax.random.uniform(key,shape=(n_in,n_out))  # Initialises the weight matrix\n    B = jax.random.uniform(key,shape=(n_out,))             # Initialises the bias vector \n    params.append({'W':W,'B':B})                           # Adds a dictionary containing the weight matrix W and bias vector B to the params list\n  return params        # Returns the initialised parameters\n"

# %%
# Initialises the parameters of the neural network based on the specified layer architecture.
#params = init_params(layers)

# %%
with open('/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Model Weights/Jax_script_1_trained_weights.pkl', 'rb') as f:
    params = pickle.load(f)

# %% [markdown]
# <a id="tau"></a>
# #### Neural Network

# %%
# Function tau to computes the output of the neural network 
def tau(params,zt,xt):

  X = jnp.concatenate([zt,xt],axis=1)

  *hidden,last = params
  for layer in hidden:

    X = jax.nn.tanh(X@layer['W']+layer['B']) # Applying the hyperbolic tangent (tanh) activation function

  return X@last['W'] + last['B']

# %% [markdown]
# <a id="pde"></a>
# #### Eikonal PDE Loss

# %%
@jax.jit   # Just-in-Time (JIT) decorator to accelerate computation
def pde_loss(params,X_starf,T0t,px0t,pz0t,vt,epst,etat):
    
    # Reshapes all input parameters
    zt = X_starf[0].reshape(-1, 1)
    xt = X_starf[1].reshape(-1, 1)
    T0t = T0t.reshape(-1, 1)
    px0t = px0t.reshape(-1, 1)
    pz0t = pz0t.reshape(-1, 1)
    vt = vt.reshape(-1, 1)
    
    # Computes the output of the neural network
    tau_output = tau(params,zt,xt) 
    
    # Computes the gradient
    dtau_dz = jax.grad(lambda zt,xt: jnp.sum(tau(params, zt,xt)), argnums=0)(zt,xt)  # Gradient of the tau function with respect to zt
    dtau_dx = jax.grad(lambda zt,xt: jnp.sum(tau(params, zt,xt)), argnums=1)(zt,xt)  # # Gradient of the tau function with respect to xt

    # Computes the combined term
    term1 = T0t * dtau_dz + tau_output * pz0t
    term2 = T0t * dtau_dx + tau_output * px0t
    
    cnst = (2*etat*(vt**2)*(1+2*epst))/(1+2*etat)
    
    # Computes the PDE loss value using MSE function 
    loss= (1+2*epst)*term2**2 + (term1**2)*(1-cnst*term2**2) - 1/vt**2
    
    loss_pde = 20 * MSE(0,loss) 
    
    return loss_pde

# %% [markdown]
# <a id="other"></a>
# #### Other Losses

# %%
@jax.jit    # Just-in-Time (JIT) decorator to accelerate computation
def MSE(true_tau,pred_tau):
    # Function to compute mean squared error (MSE)
    
    return jnp.mean((true_tau-pred_tau)**2)  # Computes and returns the MSE between true and pred

# %%
@jax.jit   # Just-in-Time (JIT) decorator to accelerate computation
def tau_loss(params,X_starf):
    # Function to compute tau loss
    
    # # Reshapes all input parameters
    zt = X_starf[0].reshape(-1, 1)
    xt = X_starf[1].reshape(-1, 1)
    #T0t=T0t.reshape(-1,1)
    
    # Computes the output of the neural network
    tau_output = tau(params,zt,xt)  
    
    # Computes the tau loss value using MSE function
    tau_loss = MSE(jnp.ones(sids.shape), tau_output[sids])
    
    
    return tau_loss

# %% [markdown]
# <a id="combine"></a>
# #### Combined Loss Function

# %%
@jax.jit    # Just-in-Time (JIT) decorator to accelerate computation
def loss_fun(params,X_starf,T0t,px0t,pz0t,vt,epst,etat):
    # Function to compute the combined loss from tau and PDE
    
    loss_tau = tau_loss(params,X_starf) # Obtains the tau loss value from tau loss function
    loss_pde = pde_loss(params,X_starf,T0t,px0t,pz0t,vt,epst,etat) # Obtains the PDE loss value from PDE loss function
    
    return loss_pde + loss_tau # Computes and returns the sum of the boths losses

# %% [markdown]
# <a id="new"></a>
# #### Model Training

# %%
# defines an adaptive learning rate that changes at specified epochs
lr = optax.piecewise_constant_schedule(1e-3,{4000:9.9e-4,10000:9e-3})   #(1e-3)#,{500:2.9e-3})

# Utilises the adam optimiser
optimizer = optax.adam(lr)

# Updates the parameters
opt_state = optimizer.init(params)

# %%
@jax.jit    # Just-in-Time (JIT) decorator to accelerate computation
def update(opt_state,params,X_starf,T0t,px0t,pz0t,vt,epst,etat):
    # Function to update the parameters for each gradient descent
    
    # calculates the gradients of loss_fun
    grads=jax.grad(loss_fun,0)(params,X_starf,T0t,px0t,pz0t,vt,epst,etat)

    # Update params
    updates, opt_state = optimizer.update(grads, opt_state)
    
    # Applies the updated params
    params = optax.apply_updates(params, updates)

    return opt_state,params

# %%
# Defining the input variables
X_starf= X_starf
T0t=T0f
px0t=px0f
pz0t=pz0f
vt=vzf
epst=epsilonf
etat=etaf

# %%
# %%time
epochs = 5000 
loss_value = [] # List to hold the values of the combines loss
loss_pde = []   # List to hold the values of the PDE loss
loss_tau = []   # # List to hold the values of the tau loss

for epoch in range(epochs):  # For loop to iterate over the stipulates epochs
    
    opt_state, params = update(opt_state,params,X_starf,T0t,px0t,pz0t,vt,epst,etat)

    # print loss and epoch info
    if epoch%(1) ==0:
        loss_pp = loss_fun(params,X_starf,T0t,px0t,pz0t,vt,epst,etat) # Computes the total loss
        loss_value.append(loss_pp)                                    # Appends the total loss value to the declared list
        print(f'Epoch = {epoch},\tloss = {loss_pp:.3e}')              # Prints the total loss values for each epoch

        #Individual losses
        loss_pde.append(pde_loss(params,X_starf,T0t,px0t,pz0t,vt,epst,etat)) # Computes and appends the PDE loss
        loss_tau.append(tau_loss(params,X_starf))                       # Computes and appends the tau loss
# Out:
# Epoch = 0,	loss = 2.702e-01
# Epoch = 1,	loss = 2.312e-01
# Epoch = 2,	loss = 1.926e-01
# Epoch = 3,	loss = 1.553e-01
# Epoch = 4,	loss = 1.210e-01
# Epoch = 5,	loss = 9.247e-02
# Epoch = 6,	loss = 7.303e-02
# Epoch = 7,	loss = 6.482e-02
# Epoch = 8,	loss = 6.453e-02
# Epoch = 9,	loss = 6.485e-02
# Epoch = 10,	loss = 6.190e-02
# Epoch = 11,	loss = 5.683e-02
# Epoch = 12,	loss = 5.216e-02
# Epoch = 13,	loss = 4.903e-02
# Epoch = 14,	loss = 4.693e-02
# Epoch = 15,	loss = 4.477e-02
# Epoch = 16,	loss = 4.185e-02
# Epoch = 17,	loss = 3.813e-02
# Epoch = 18,	loss = 3.416e-02
# Epoch = 19,	loss = 3.078e-02
# Epoch = 20,	loss = 2.872e-02
# Epoch = 21,	loss = 2.806e-02
# Epoch = 22,	loss = 2.788e-02
# Epoch = 23,	loss = 2.693e-02
# Epoch = 24,	loss = 2.463e-02
# Epoch = 25,	loss = 2.146e-02
# Epoch = 26,	loss = 1.834e-02
# Epoch = 27,	loss = 1.597e-02
# Epoch = 28,	loss = 1.451e-02
# Epoch = 29,	loss = 1.373e-02
# Epoch = 30,	loss = 1.325e-02
# Epoch = 31,	loss = 1.281e-02
# Epoch = 32,	loss = 1.231e-02
# Epoch = 33,	loss = 1.181e-02
# Epoch = 34,	loss = 1.140e-02
# Epoch = 35,	loss = 1.111e-02
# Epoch = 36,	loss = 1.089e-02
# Epoch = 37,	loss = 1.055e-02
# Epoch = 38,	loss = 9.951e-03
# Epoch = 39,	loss = 9.073e-03
# Epoch = 40,	loss = 8.074e-03
# Epoch = 41,	loss = 7.183e-03
# Epoch = 42,	loss = 6.563e-03
# Epoch = 43,	loss = 6.236e-03
# Epoch = 44,	loss = 6.100e-03
# Epoch = 45,	loss = 6.012e-03
# Epoch = 46,	loss = 5.872e-03
# Epoch = 47,	loss = 5.663e-03
# Epoch = 48,	loss = 5.431e-03
# Epoch = 49,	loss = 5.230e-03
# Epoch = 50,	loss = 5.071e-03
# Epoch = 51,	loss = 4.914e-03
# Epoch = 52,	loss = 4.711e-03
# Epoch = 53,	loss = 4.458e-03
# Epoch = 54,	loss = 4.200e-03
# Epoch = 55,	loss = 3.990e-03
# Epoch = 56,	loss = 3.846e-03
# Epoch = 57,	loss = 3.745e-03
# Epoch = 58,	loss = 3.648e-03
# Epoch = 59,	loss = 3.534e-03
# Epoch = 60,	loss = 3.409e-03
# Epoch = 61,	loss = 3.297e-03
# Epoch = 62,	loss = 3.214e-03
# Epoch = 63,	loss = 3.154e-03
# Epoch = 64,	loss = 3.097e-03
# Epoch = 65,	loss = 3.025e-03
# Epoch = 66,	loss = 2.938e-03
# Epoch = 67,	loss = 2.851e-03
# Epoch = 68,	loss = 2.776e-03
# Epoch = 69,	loss = 2.713e-03
# Epoch = 70,	loss = 2.653e-03
# Epoch = 71,	loss = 2.592e-03
# Epoch = 72,	loss = 2.531e-03
# Epoch = 73,	loss = 2.480e-03
# Epoch = 74,	loss = 2.444e-03
# Epoch = 75,	loss = 2.418e-03
# Epoch = 76,	loss = 2.392e-03
# Epoch = 77,	loss = 2.358e-03
# Epoch = 78,	loss = 2.318e-03
# Epoch = 79,	loss = 2.277e-03
# Epoch = 80,	loss = 2.240e-03
# Epoch = 81,	loss = 2.205e-03
# Epoch = 82,	loss = 2.171e-03
# Epoch = 83,	loss = 2.138e-03
# Epoch = 84,	loss = 2.109e-03
# Epoch = 85,	loss = 2.086e-03
# Epoch = 86,	loss = 2.067e-03
# Epoch = 87,	loss = 2.049e-03
# Epoch = 88,	loss = 2.028e-03
# Epoch = 89,	loss = 2.005e-03
# Epoch = 90,	loss = 1.981e-03
# Epoch = 91,	loss = 1.959e-03
# Epoch = 92,	loss = 1.938e-03
# Epoch = 93,	loss = 1.918e-03
# Epoch = 94,	loss = 1.899e-03
# Epoch = 95,	loss = 1.881e-03
# Epoch = 96,	loss = 1.866e-03
# Epoch = 97,	loss = 1.852e-03
# Epoch = 98,	loss = 1.838e-03
# Epoch = 99,	loss = 1.823e-03
# Epoch = 100,	loss = 1.808e-03
# Epoch = 101,	loss = 1.793e-03
# Epoch = 102,	loss = 1.779e-03
# Epoch = 103,	loss = 1.765e-03
# Epoch = 104,	loss = 1.752e-03
# Epoch = 105,	loss = 1.739e-03
# Epoch = 106,	loss = 1.727e-03
# Epoch = 107,	loss = 1.715e-03
# Epoch = 108,	loss = 1.704e-03
# Epoch = 109,	loss = 1.693e-03
# Epoch = 110,	loss = 1.682e-03
# Epoch = 111,	loss = 1.671e-03
# Epoch = 112,	loss = 1.660e-03
# Epoch = 113,	loss = 1.649e-03
# Epoch = 114,	loss = 1.639e-03
# Epoch = 115,	loss = 1.629e-03
# Epoch = 116,	loss = 1.619e-03
# Epoch = 117,	loss = 1.609e-03
# Epoch = 118,	loss = 1.600e-03
# Epoch = 119,	loss = 1.591e-03
# Epoch = 120,	loss = 1.582e-03
# Epoch = 121,	loss = 1.573e-03
# Epoch = 122,	loss = 1.564e-03
# Epoch = 123,	loss = 1.555e-03
# Epoch = 124,	loss = 1.546e-03
# Epoch = 125,	loss = 1.538e-03
# Epoch = 126,	loss = 1.529e-03
# Epoch = 127,	loss = 1.521e-03
# Epoch = 128,	loss = 1.513e-03
# Epoch = 129,	loss = 1.505e-03
# Epoch = 130,	loss = 1.497e-03
# Epoch = 131,	loss = 1.489e-03
# Epoch = 132,	loss = 1.482e-03
# Epoch = 133,	loss = 1.474e-03
# Epoch = 134,	loss = 1.467e-03
# Epoch = 135,	loss = 1.459e-03
# Epoch = 136,	loss = 1.452e-03
# Epoch = 137,	loss = 1.444e-03
# Epoch = 138,	loss = 1.437e-03
# Epoch = 139,	loss = 1.430e-03
# Epoch = 140,	loss = 1.423e-03
# Epoch = 141,	loss = 1.416e-03
# Epoch = 142,	loss = 1.409e-03
# Epoch = 143,	loss = 1.402e-03
# Epoch = 144,	loss = 1.396e-03
# Epoch = 145,	loss = 1.389e-03
# Epoch = 146,	loss = 1.382e-03
# Epoch = 147,	loss = 1.376e-03
# Epoch = 148,	loss = 1.369e-03
# Epoch = 149,	loss = 1.363e-03
# Epoch = 150,	loss = 1.357e-03
# Epoch = 151,	loss = 1.350e-03
# Epoch = 152,	loss = 1.344e-03
# Epoch = 153,	loss = 1.338e-03
# Epoch = 154,	loss = 1.332e-03
# Epoch = 155,	loss = 1.326e-03
# Epoch = 156,	loss = 1.320e-03
# Epoch = 157,	loss = 1.314e-03
# Epoch = 158,	loss = 1.308e-03
# Epoch = 159,	loss = 1.302e-03
# Epoch = 160,	loss = 1.296e-03
# Epoch = 161,	loss = 1.290e-03
# Epoch = 162,	loss = 1.285e-03
# Epoch = 163,	loss = 1.279e-03
# Epoch = 164,	loss = 1.273e-03
# Epoch = 165,	loss = 1.268e-03
# Epoch = 166,	loss = 1.262e-03
# Epoch = 167,	loss = 1.257e-03
# Epoch = 168,	loss = 1.251e-03
# Epoch = 169,	loss = 1.246e-03
# Epoch = 170,	loss = 1.241e-03
# Epoch = 171,	loss = 1.235e-03
# Epoch = 172,	loss = 1.230e-03
# Epoch = 173,	loss = 1.225e-03
# Epoch = 174,	loss = 1.220e-03
# Epoch = 175,	loss = 1.215e-03
# Epoch = 176,	loss = 1.210e-03
# Epoch = 177,	loss = 1.204e-03
# Epoch = 178,	loss = 1.199e-03
# Epoch = 179,	loss = 1.194e-03
# Epoch = 180,	loss = 1.190e-03
# Epoch = 181,	loss = 1.185e-03
# Epoch = 182,	loss = 1.180e-03
# Epoch = 183,	loss = 1.175e-03
# Epoch = 184,	loss = 1.170e-03
# Epoch = 185,	loss = 1.165e-03
# Epoch = 186,	loss = 1.161e-03
# Epoch = 187,	loss = 1.156e-03
# Epoch = 188,	loss = 1.151e-03
# Epoch = 189,	loss = 1.147e-03
# Epoch = 190,	loss = 1.142e-03
# Epoch = 191,	loss = 1.138e-03
# Epoch = 192,	loss = 1.133e-03
# Epoch = 193,	loss = 1.129e-03
# Epoch = 194,	loss = 1.124e-03
# Epoch = 195,	loss = 1.120e-03
# Epoch = 196,	loss = 1.115e-03
# Epoch = 197,	loss = 1.111e-03
# Epoch = 198,	loss = 1.107e-03
# Epoch = 199,	loss = 1.102e-03
# Epoch = 200,	loss = 1.098e-03
# Epoch = 201,	loss = 1.094e-03
# Epoch = 202,	loss = 1.090e-03
# Epoch = 203,	loss = 1.086e-03
# Epoch = 204,	loss = 1.082e-03
# Epoch = 205,	loss = 1.077e-03
# Epoch = 206,	loss = 1.073e-03
# Epoch = 207,	loss = 1.069e-03
# Epoch = 208,	loss = 1.065e-03
# Epoch = 209,	loss = 1.061e-03
# Epoch = 210,	loss = 1.057e-03
# Epoch = 211,	loss = 1.054e-03
# Epoch = 212,	loss = 1.050e-03
# Epoch = 213,	loss = 1.046e-03
# Epoch = 214,	loss = 1.042e-03
# Epoch = 215,	loss = 1.038e-03
# Epoch = 216,	loss = 1.034e-03
# Epoch = 217,	loss = 1.031e-03
# Epoch = 218,	loss = 1.027e-03
# Epoch = 219,	loss = 1.023e-03
# Epoch = 220,	loss = 1.020e-03
# Epoch = 221,	loss = 1.016e-03
# Epoch = 222,	loss = 1.012e-03
# Epoch = 223,	loss = 1.009e-03
# Epoch = 224,	loss = 1.005e-03
# Epoch = 225,	loss = 1.002e-03
# Epoch = 226,	loss = 9.982e-04
# Epoch = 227,	loss = 9.948e-04
# Epoch = 228,	loss = 9.913e-04
# Epoch = 229,	loss = 9.879e-04
# Epoch = 230,	loss = 9.845e-04
# Epoch = 231,	loss = 9.811e-04
# Epoch = 232,	loss = 9.778e-04
# Epoch = 233,	loss = 9.745e-04
# Epoch = 234,	loss = 9.712e-04
# Epoch = 235,	loss = 9.679e-04
# Epoch = 236,	loss = 9.646e-04
# Epoch = 237,	loss = 9.614e-04
# Epoch = 238,	loss = 9.582e-04
# Epoch = 239,	loss = 9.550e-04
# Epoch = 240,	loss = 9.519e-04
# Epoch = 241,	loss = 9.488e-04
# Epoch = 242,	loss = 9.457e-04
# Epoch = 243,	loss = 9.426e-04
# Epoch = 244,	loss = 9.395e-04
# Epoch = 245,	loss = 9.365e-04
# Epoch = 246,	loss = 9.335e-04
# Epoch = 247,	loss = 9.305e-04
# Epoch = 248,	loss = 9.275e-04
# Epoch = 249,	loss = 9.246e-04
# Epoch = 250,	loss = 9.216e-04
# Epoch = 251,	loss = 9.187e-04
# Epoch = 252,	loss = 9.158e-04
# Epoch = 253,	loss = 9.130e-04
# Epoch = 254,	loss = 9.101e-04
# Epoch = 255,	loss = 9.073e-04
# Epoch = 256,	loss = 9.045e-04
# Epoch = 257,	loss = 9.017e-04
# Epoch = 258,	loss = 8.990e-04
# Epoch = 259,	loss = 8.962e-04
# Epoch = 260,	loss = 8.935e-04
# Epoch = 261,	loss = 8.908e-04
# Epoch = 262,	loss = 8.881e-04
# Epoch = 263,	loss = 8.855e-04
# Epoch = 264,	loss = 8.829e-04
# Epoch = 265,	loss = 8.802e-04
# Epoch = 266,	loss = 8.776e-04
# Epoch = 267,	loss = 8.750e-04
# Epoch = 268,	loss = 8.725e-04
# Epoch = 269,	loss = 8.699e-04
# Epoch = 270,	loss = 8.674e-04
# Epoch = 271,	loss = 8.649e-04
# Epoch = 272,	loss = 8.624e-04
# Epoch = 273,	loss = 8.599e-04
# Epoch = 274,	loss = 8.575e-04
# Epoch = 275,	loss = 8.551e-04
# Epoch = 276,	loss = 8.526e-04
# Epoch = 277,	loss = 8.502e-04
# Epoch = 278,	loss = 8.478e-04
# Epoch = 279,	loss = 8.455e-04
# Epoch = 280,	loss = 8.431e-04
# Epoch = 281,	loss = 8.408e-04
# Epoch = 282,	loss = 8.385e-04
# Epoch = 283,	loss = 8.362e-04
# Epoch = 284,	loss = 8.339e-04
# Epoch = 285,	loss = 8.316e-04
# Epoch = 286,	loss = 8.294e-04
# Epoch = 287,	loss = 8.271e-04
# Epoch = 288,	loss = 8.249e-04
# Epoch = 289,	loss = 8.227e-04
# Epoch = 290,	loss = 8.205e-04
# Epoch = 291,	loss = 8.184e-04
# Epoch = 292,	loss = 8.162e-04
# Epoch = 293,	loss = 8.140e-04
# Epoch = 294,	loss = 8.119e-04
# Epoch = 295,	loss = 8.098e-04
# Epoch = 296,	loss = 8.077e-04
# Epoch = 297,	loss = 8.056e-04
# Epoch = 298,	loss = 8.035e-04
# Epoch = 299,	loss = 8.015e-04
# Epoch = 300,	loss = 7.994e-04
# Epoch = 301,	loss = 7.974e-04
# Epoch = 302,	loss = 7.954e-04
# Epoch = 303,	loss = 7.934e-04
# Epoch = 304,	loss = 7.914e-04
# Epoch = 305,	loss = 7.894e-04
# Epoch = 306,	loss = 7.875e-04
# Epoch = 307,	loss = 7.855e-04
# Epoch = 308,	loss = 7.836e-04
# Epoch = 309,	loss = 7.817e-04
# Epoch = 310,	loss = 7.798e-04
# Epoch = 311,	loss = 7.779e-04
# Epoch = 312,	loss = 7.760e-04
# Epoch = 313,	loss = 7.741e-04
# Epoch = 314,	loss = 7.723e-04
# Epoch = 315,	loss = 7.704e-04
# Epoch = 316,	loss = 7.686e-04
# Epoch = 317,	loss = 7.668e-04
# Epoch = 318,	loss = 7.649e-04
# Epoch = 319,	loss = 7.631e-04
# Epoch = 320,	loss = 7.614e-04
# Epoch = 321,	loss = 7.596e-04
# Epoch = 322,	loss = 7.578e-04
# Epoch = 323,	loss = 7.561e-04
# Epoch = 324,	loss = 7.543e-04
# Epoch = 325,	loss = 7.526e-04
# Epoch = 326,	loss = 7.509e-04
# Epoch = 327,	loss = 7.492e-04
# Epoch = 328,	loss = 7.475e-04
# Epoch = 329,	loss = 7.458e-04
# Epoch = 330,	loss = 7.441e-04
# Epoch = 331,	loss = 7.424e-04
# Epoch = 332,	loss = 7.408e-04
# Epoch = 333,	loss = 7.391e-04
# Epoch = 334,	loss = 7.375e-04
# Epoch = 335,	loss = 7.359e-04
# Epoch = 336,	loss = 7.343e-04
# Epoch = 337,	loss = 7.327e-04
# Epoch = 338,	loss = 7.311e-04
# Epoch = 339,	loss = 7.295e-04
# Epoch = 340,	loss = 7.279e-04
# Epoch = 341,	loss = 7.264e-04
# Epoch = 342,	loss = 7.248e-04
# Epoch = 343,	loss = 7.233e-04
# Epoch = 344,	loss = 7.217e-04
# Epoch = 345,	loss = 7.202e-04
# Epoch = 346,	loss = 7.187e-04
# Epoch = 347,	loss = 7.172e-04
# Epoch = 348,	loss = 7.157e-04
# Epoch = 349,	loss = 7.142e-04
# Epoch = 350,	loss = 7.127e-04
# Epoch = 351,	loss = 7.112e-04
# Epoch = 352,	loss = 7.098e-04
# Epoch = 353,	loss = 7.083e-04
# Epoch = 354,	loss = 7.069e-04
# Epoch = 355,	loss = 7.054e-04
# Epoch = 356,	loss = 7.040e-04
# Epoch = 357,	loss = 7.026e-04
# Epoch = 358,	loss = 7.011e-04
# Epoch = 359,	loss = 6.997e-04
# Epoch = 360,	loss = 6.983e-04
# Epoch = 361,	loss = 6.970e-04
# Epoch = 362,	loss = 6.956e-04
# Epoch = 363,	loss = 6.942e-04
# Epoch = 364,	loss = 6.928e-04
# Epoch = 365,	loss = 6.915e-04
# Epoch = 366,	loss = 6.901e-04
# Epoch = 367,	loss = 6.888e-04
# Epoch = 368,	loss = 6.875e-04
# Epoch = 369,	loss = 6.861e-04
# Epoch = 370,	loss = 6.848e-04
# Epoch = 371,	loss = 6.835e-04
# Epoch = 372,	loss = 6.822e-04
# Epoch = 373,	loss = 6.809e-04
# Epoch = 374,	loss = 6.796e-04
# Epoch = 375,	loss = 6.783e-04
# Epoch = 376,	loss = 6.770e-04
# Epoch = 377,	loss = 6.758e-04
# Epoch = 378,	loss = 6.745e-04
# Epoch = 379,	loss = 6.733e-04
# Epoch = 380,	loss = 6.720e-04
# Epoch = 381,	loss = 6.708e-04
# Epoch = 382,	loss = 6.695e-04
# Epoch = 383,	loss = 6.683e-04
# Epoch = 384,	loss = 6.671e-04
# Epoch = 385,	loss = 6.659e-04
# Epoch = 386,	loss = 6.647e-04
# Epoch = 387,	loss = 6.635e-04
# Epoch = 388,	loss = 6.623e-04
# Epoch = 389,	loss = 6.611e-04
# Epoch = 390,	loss = 6.599e-04
# Epoch = 391,	loss = 6.587e-04
# Epoch = 392,	loss = 6.575e-04
# Epoch = 393,	loss = 6.564e-04
# Epoch = 394,	loss = 6.552e-04
# Epoch = 395,	loss = 6.541e-04
# Epoch = 396,	loss = 6.529e-04
# Epoch = 397,	loss = 6.518e-04
# Epoch = 398,	loss = 6.507e-04
# Epoch = 399,	loss = 6.495e-04
# Epoch = 400,	loss = 6.484e-04
# Epoch = 401,	loss = 6.473e-04
# Epoch = 402,	loss = 6.462e-04
# Epoch = 403,	loss = 6.451e-04
# Epoch = 404,	loss = 6.440e-04
# Epoch = 405,	loss = 6.429e-04
# Epoch = 406,	loss = 6.418e-04
# Epoch = 407,	loss = 6.407e-04
# Epoch = 408,	loss = 6.397e-04
# Epoch = 409,	loss = 6.386e-04
# Epoch = 410,	loss = 6.375e-04
# Epoch = 411,	loss = 6.365e-04
# Epoch = 412,	loss = 6.354e-04
# Epoch = 413,	loss = 6.344e-04
# Epoch = 414,	loss = 6.333e-04
# Epoch = 415,	loss = 6.323e-04
# Epoch = 416,	loss = 6.312e-04
# Epoch = 417,	loss = 6.302e-04
# Epoch = 418,	loss = 6.292e-04
# Epoch = 419,	loss = 6.282e-04
# Epoch = 420,	loss = 6.272e-04
# Epoch = 421,	loss = 6.262e-04
# Epoch = 422,	loss = 6.252e-04
# Epoch = 423,	loss = 6.242e-04
# Epoch = 424,	loss = 6.232e-04
# Epoch = 425,	loss = 6.222e-04
# Epoch = 426,	loss = 6.212e-04
# Epoch = 427,	loss = 6.202e-04
# Epoch = 428,	loss = 6.192e-04
# Epoch = 429,	loss = 6.183e-04
# Epoch = 430,	loss = 6.173e-04
# Epoch = 431,	loss = 6.164e-04
# Epoch = 432,	loss = 6.154e-04
# Epoch = 433,	loss = 6.145e-04
# Epoch = 434,	loss = 6.135e-04
# Epoch = 435,	loss = 6.126e-04
# Epoch = 436,	loss = 6.116e-04
# Epoch = 437,	loss = 6.107e-04
# Epoch = 438,	loss = 6.098e-04
# Epoch = 439,	loss = 6.089e-04
# Epoch = 440,	loss = 6.079e-04
# Epoch = 441,	loss = 6.070e-04
# Epoch = 442,	loss = 6.061e-04
# Epoch = 443,	loss = 6.052e-04
# Epoch = 444,	loss = 6.043e-04
# Epoch = 445,	loss = 6.034e-04
# Epoch = 446,	loss = 6.025e-04
# Epoch = 447,	loss = 6.016e-04
# Epoch = 448,	loss = 6.008e-04
# Epoch = 449,	loss = 5.999e-04
# Epoch = 450,	loss = 5.990e-04
# Epoch = 451,	loss = 5.981e-04
# Epoch = 452,	loss = 5.973e-04
# Epoch = 453,	loss = 5.964e-04
# Epoch = 454,	loss = 5.956e-04
# Epoch = 455,	loss = 5.947e-04
# Epoch = 456,	loss = 5.938e-04
# Epoch = 457,	loss = 5.930e-04
# Epoch = 458,	loss = 5.922e-04
# Epoch = 459,	loss = 5.913e-04
# Epoch = 460,	loss = 5.905e-04
# Epoch = 461,	loss = 5.897e-04
# Epoch = 462,	loss = 5.888e-04
# Epoch = 463,	loss = 5.880e-04
# Epoch = 464,	loss = 5.872e-04
# Epoch = 465,	loss = 5.864e-04
# Epoch = 466,	loss = 5.856e-04
# Epoch = 467,	loss = 5.848e-04
# Epoch = 468,	loss = 5.840e-04
# Epoch = 469,	loss = 5.832e-04
# Epoch = 470,	loss = 5.824e-04
# Epoch = 471,	loss = 5.816e-04
# Epoch = 472,	loss = 5.808e-04
# Epoch = 473,	loss = 5.800e-04
# Epoch = 474,	loss = 5.792e-04
# Epoch = 475,	loss = 5.784e-04
# Epoch = 476,	loss = 5.777e-04
# Epoch = 477,	loss = 5.769e-04
# Epoch = 478,	loss = 5.761e-04
# Epoch = 479,	loss = 5.754e-04
# Epoch = 480,	loss = 5.746e-04
# Epoch = 481,	loss = 5.738e-04
# Epoch = 482,	loss = 5.731e-04
# Epoch = 483,	loss = 5.723e-04
# Epoch = 484,	loss = 5.716e-04
# Epoch = 485,	loss = 5.708e-04
# Epoch = 486,	loss = 5.701e-04
# Epoch = 487,	loss = 5.694e-04
# Epoch = 488,	loss = 5.686e-04
# Epoch = 489,	loss = 5.679e-04
# Epoch = 490,	loss = 5.672e-04
# Epoch = 491,	loss = 5.664e-04
# Epoch = 492,	loss = 5.657e-04
# Epoch = 493,	loss = 5.650e-04
# Epoch = 494,	loss = 5.643e-04
# Epoch = 495,	loss = 5.636e-04
# Epoch = 496,	loss = 5.629e-04
# Epoch = 497,	loss = 5.622e-04
# Epoch = 498,	loss = 5.615e-04
# Epoch = 499,	loss = 5.608e-04
# Epoch = 500,	loss = 5.601e-04
# Epoch = 501,	loss = 5.594e-04
# Epoch = 502,	loss = 5.587e-04
# Epoch = 503,	loss = 5.580e-04
# Epoch = 504,	loss = 5.573e-04
# Epoch = 505,	loss = 5.566e-04
# Epoch = 506,	loss = 5.560e-04
# Epoch = 507,	loss = 5.553e-04
# Epoch = 508,	loss = 5.546e-04
# Epoch = 509,	loss = 5.539e-04
# Epoch = 510,	loss = 5.533e-04
# Epoch = 511,	loss = 5.526e-04
# Epoch = 512,	loss = 5.520e-04
# Epoch = 513,	loss = 5.513e-04
# Epoch = 514,	loss = 5.506e-04
# Epoch = 515,	loss = 5.500e-04
# Epoch = 516,	loss = 5.493e-04
# Epoch = 517,	loss = 5.487e-04
# Epoch = 518,	loss = 5.480e-04
# Epoch = 519,	loss = 5.474e-04
# Epoch = 520,	loss = 5.468e-04
# Epoch = 521,	loss = 5.461e-04
# Epoch = 522,	loss = 5.455e-04
# Epoch = 523,	loss = 5.449e-04
# Epoch = 524,	loss = 5.442e-04
# Epoch = 525,	loss = 5.436e-04
# Epoch = 526,	loss = 5.430e-04
# Epoch = 527,	loss = 5.424e-04
# Epoch = 528,	loss = 5.417e-04
# Epoch = 529,	loss = 5.411e-04
# Epoch = 530,	loss = 5.405e-04
# Epoch = 531,	loss = 5.399e-04
# Epoch = 532,	loss = 5.393e-04
# Epoch = 533,	loss = 5.387e-04
# Epoch = 534,	loss = 5.381e-04
# Epoch = 535,	loss = 5.375e-04
# Epoch = 536,	loss = 5.369e-04
# Epoch = 537,	loss = 5.363e-04
# Epoch = 538,	loss = 5.357e-04
# Epoch = 539,	loss = 5.351e-04
# Epoch = 540,	loss = 5.345e-04
# Epoch = 541,	loss = 5.339e-04
# Epoch = 542,	loss = 5.334e-04
# Epoch = 543,	loss = 5.328e-04
# Epoch = 544,	loss = 5.322e-04
# Epoch = 545,	loss = 5.316e-04
# Epoch = 546,	loss = 5.311e-04
# Epoch = 547,	loss = 5.305e-04
# Epoch = 548,	loss = 5.299e-04
# Epoch = 549,	loss = 5.293e-04
# Epoch = 550,	loss = 5.288e-04
# Epoch = 551,	loss = 5.282e-04
# Epoch = 552,	loss = 5.277e-04
# Epoch = 553,	loss = 5.271e-04
# Epoch = 554,	loss = 5.265e-04
# Epoch = 555,	loss = 5.260e-04
# Epoch = 556,	loss = 5.254e-04
# Epoch = 557,	loss = 5.249e-04
# Epoch = 558,	loss = 5.243e-04
# Epoch = 559,	loss = 5.238e-04
# Epoch = 560,	loss = 5.233e-04
# Epoch = 561,	loss = 5.227e-04
# Epoch = 562,	loss = 5.222e-04
# Epoch = 563,	loss = 5.216e-04
# Epoch = 564,	loss = 5.211e-04
# Epoch = 565,	loss = 5.206e-04
# Epoch = 566,	loss = 5.200e-04
# Epoch = 567,	loss = 5.195e-04
# Epoch = 568,	loss = 5.190e-04
# Epoch = 569,	loss = 5.185e-04
# Epoch = 570,	loss = 5.179e-04
# Epoch = 571,	loss = 5.174e-04
# Epoch = 572,	loss = 5.169e-04
# Epoch = 573,	loss = 5.164e-04
# Epoch = 574,	loss = 5.159e-04
# Epoch = 575,	loss = 5.154e-04
# Epoch = 576,	loss = 5.148e-04
# Epoch = 577,	loss = 5.143e-04
# Epoch = 578,	loss = 5.138e-04
# Epoch = 579,	loss = 5.133e-04
# Epoch = 580,	loss = 5.128e-04
# Epoch = 581,	loss = 5.123e-04
# Epoch = 582,	loss = 5.118e-04
# Epoch = 583,	loss = 5.113e-04
# Epoch = 584,	loss = 5.108e-04
# Epoch = 585,	loss = 5.103e-04
# Epoch = 586,	loss = 5.099e-04
# Epoch = 587,	loss = 5.094e-04
# Epoch = 588,	loss = 5.089e-04
# Epoch = 589,	loss = 5.084e-04
# Epoch = 590,	loss = 5.079e-04
# Epoch = 591,	loss = 5.074e-04
# Epoch = 592,	loss = 5.069e-04
# Epoch = 593,	loss = 5.065e-04
# Epoch = 594,	loss = 5.060e-04
# Epoch = 595,	loss = 5.055e-04
# Epoch = 596,	loss = 5.050e-04
# Epoch = 597,	loss = 5.046e-04
# Epoch = 598,	loss = 5.041e-04
# Epoch = 599,	loss = 5.036e-04
# Epoch = 600,	loss = 5.032e-04
# Epoch = 601,	loss = 5.027e-04
# Epoch = 602,	loss = 5.022e-04
# Epoch = 603,	loss = 5.018e-04
# Epoch = 604,	loss = 5.013e-04
# Epoch = 605,	loss = 5.009e-04
# Epoch = 606,	loss = 5.004e-04
# Epoch = 607,	loss = 4.999e-04
# Epoch = 608,	loss = 4.995e-04
# Epoch = 609,	loss = 4.990e-04
# Epoch = 610,	loss = 4.986e-04
# Epoch = 611,	loss = 4.981e-04
# Epoch = 612,	loss = 4.977e-04
# Epoch = 613,	loss = 4.972e-04
# Epoch = 614,	loss = 4.968e-04
# Epoch = 615,	loss = 4.964e-04
# Epoch = 616,	loss = 4.959e-04
# Epoch = 617,	loss = 4.955e-04
# Epoch = 618,	loss = 4.950e-04
# Epoch = 619,	loss = 4.946e-04
# Epoch = 620,	loss = 4.942e-04
# Epoch = 989,	loss = 3.982e-04
# Epoch = 990,	loss = 3.980e-04
# Epoch = 991,	loss = 3.979e-04
# Epoch = 992,	loss = 3.977e-04
# Epoch = 993,	loss = 3.976e-04
# Epoch = 994,	loss = 3.974e-04
# Epoch = 995,	loss = 3.973e-04
# Epoch = 996,	loss = 3.971e-04
# Epoch = 997,	loss = 3.970e-04
# Epoch = 998,	loss = 3.968e-04
# Epoch = 999,	loss = 3.967e-04
# Epoch = 1000,	loss = 3.965e-04
# Epoch = 1001,	loss = 3.964e-04
# Epoch = 1002,	loss = 3.962e-04
# Epoch = 1003,	loss = 3.961e-04
# Epoch = 1004,	loss = 3.959e-04
# Epoch = 1005,	loss = 3.958e-04
# Epoch = 1006,	loss = 3.956e-04
# Epoch = 1007,	loss = 3.955e-04
# Epoch = 1008,	loss = 3.954e-04
# Epoch = 1009,	loss = 3.952e-04
# Epoch = 1010,	loss = 3.951e-04
# Epoch = 1011,	loss = 3.949e-04
# Epoch = 1012,	loss = 3.948e-04
# Epoch = 1013,	loss = 3.946e-04
# Epoch = 1014,	loss = 3.945e-04
# Epoch = 1015,	loss = 3.944e-04
# Epoch = 1016,	loss = 3.942e-04
# Epoch = 1017,	loss = 3.941e-04
# Epoch = 1018,	loss = 3.939e-04
# Epoch = 1019,	loss = 3.938e-04
# Epoch = 1020,	loss = 3.936e-04
# Epoch = 1021,	loss = 3.935e-04
# Epoch = 1022,	loss = 3.934e-04
# Epoch = 1023,	loss = 3.932e-04
# Epoch = 1024,	loss = 3.931e-04
# Epoch = 1025,	loss = 3.930e-04
# Epoch = 1026,	loss = 3.928e-04
# Epoch = 1027,	loss = 3.927e-04
# Epoch = 1028,	loss = 3.925e-04
# Epoch = 1029,	loss = 3.924e-04
# Epoch = 1030,	loss = 3.923e-04
# Epoch = 1031,	loss = 3.921e-04
# Epoch = 1032,	loss = 3.920e-04
# Epoch = 1033,	loss = 3.919e-04
# Epoch = 1034,	loss = 3.917e-04
# Epoch = 1035,	loss = 3.916e-04
# Epoch = 1036,	loss = 3.914e-04
# Epoch = 1037,	loss = 3.913e-04
# Epoch = 1038,	loss = 3.912e-04
# Epoch = 1039,	loss = 3.910e-04
# Epoch = 1040,	loss = 3.909e-04
# Epoch = 1041,	loss = 3.908e-04
# Epoch = 1042,	loss = 3.906e-04
# Epoch = 1043,	loss = 3.905e-04
# Epoch = 1044,	loss = 3.904e-04
# Epoch = 1045,	loss = 3.902e-04
# Epoch = 1046,	loss = 3.901e-04
# Epoch = 1047,	loss = 3.900e-04
# Epoch = 1048,	loss = 3.899e-04
# Epoch = 1049,	loss = 3.897e-04
# Epoch = 1050,	loss = 3.896e-04
# Epoch = 1051,	loss = 3.895e-04
# Epoch = 1052,	loss = 3.893e-04
# Epoch = 1053,	loss = 3.892e-04
# Epoch = 1054,	loss = 3.891e-04
# Epoch = 1055,	loss = 3.889e-04
# Epoch = 1056,	loss = 3.888e-04
# Epoch = 1057,	loss = 3.887e-04
# Epoch = 1058,	loss = 3.886e-04
# Epoch = 1059,	loss = 3.884e-04
# Epoch = 1060,	loss = 3.883e-04
# Epoch = 1061,	loss = 3.882e-04
# Epoch = 1062,	loss = 3.880e-04
# Epoch = 1063,	loss = 3.879e-04
# Epoch = 1064,	loss = 3.878e-04
# Epoch = 1065,	loss = 3.877e-04
# Epoch = 1066,	loss = 3.875e-04
# Epoch = 1067,	loss = 3.874e-04
# Epoch = 1068,	loss = 3.873e-04
# Epoch = 1069,	loss = 3.872e-04
# Epoch = 1070,	loss = 3.870e-04
# Epoch = 1071,	loss = 3.869e-04
# Epoch = 1072,	loss = 3.868e-04
# Epoch = 1073,	loss = 3.867e-04
# Epoch = 1074,	loss = 3.865e-04
# Epoch = 1075,	loss = 3.864e-04
# Epoch = 1076,	loss = 3.863e-04
# Epoch = 1077,	loss = 3.862e-04
# Epoch = 1078,	loss = 3.860e-04
# Epoch = 1079,	loss = 3.859e-04
# Epoch = 1080,	loss = 3.858e-04
# Epoch = 1081,	loss = 3.857e-04
# Epoch = 1082,	loss = 3.856e-04
# Epoch = 1083,	loss = 3.854e-04
# Epoch = 1084,	loss = 3.853e-04
# Epoch = 1085,	loss = 3.852e-04
# Epoch = 1086,	loss = 3.851e-04
# Epoch = 1087,	loss = 3.850e-04
# Epoch = 1088,	loss = 3.848e-04
# Epoch = 1089,	loss = 3.847e-04
# Epoch = 1090,	loss = 3.846e-04
# Epoch = 1091,	loss = 3.845e-04
# Epoch = 1092,	loss = 3.844e-04
# Epoch = 1093,	loss = 3.842e-04
# Epoch = 1094,	loss = 3.841e-04
# Epoch = 1095,	loss = 3.840e-04
# Epoch = 1096,	loss = 3.839e-04
# Epoch = 1097,	loss = 3.838e-04
# Epoch = 1098,	loss = 3.837e-04
# Epoch = 1099,	loss = 3.835e-04
# Epoch = 1100,	loss = 3.834e-04
# Epoch = 1101,	loss = 3.833e-04
# Epoch = 1102,	loss = 3.832e-04
# Epoch = 1103,	loss = 3.831e-04
# Epoch = 1104,	loss = 3.830e-04
# Epoch = 1105,	loss = 3.828e-04
# Epoch = 1106,	loss = 3.827e-04
# Epoch = 1107,	loss = 3.826e-04
# Epoch = 1108,	loss = 3.825e-04
# Epoch = 1109,	loss = 3.824e-04
# Epoch = 1110,	loss = 3.823e-04
# Epoch = 1111,	loss = 3.822e-04
# Epoch = 1112,	loss = 3.820e-04
# Epoch = 1113,	loss = 3.819e-04
# Epoch = 1114,	loss = 3.818e-04
# Epoch = 1115,	loss = 3.817e-04
# Epoch = 1116,	loss = 3.816e-04
# Epoch = 1117,	loss = 3.815e-04
# Epoch = 1118,	loss = 3.814e-04
# Epoch = 1119,	loss = 3.812e-04
# Epoch = 1120,	loss = 3.811e-04
# Epoch = 1121,	loss = 3.810e-04
# Epoch = 1122,	loss = 3.809e-04
# Epoch = 1123,	loss = 3.808e-04
# Epoch = 1124,	loss = 3.807e-04
# Epoch = 1125,	loss = 3.806e-04
# Epoch = 1126,	loss = 3.805e-04
# Epoch = 1127,	loss = 3.804e-04
# Epoch = 1128,	loss = 3.803e-04
# Epoch = 1129,	loss = 3.801e-04
# Epoch = 1130,	loss = 3.800e-04
# Epoch = 1131,	loss = 3.799e-04
# Epoch = 1132,	loss = 3.798e-04
# Epoch = 1133,	loss = 3.797e-04
# Epoch = 1134,	loss = 3.796e-04
# Epoch = 1135,	loss = 3.795e-04
# Epoch = 1136,	loss = 3.794e-04
# Epoch = 1137,	loss = 3.793e-04
# Epoch = 1138,	loss = 3.792e-04
# Epoch = 1139,	loss = 3.791e-04
# Epoch = 1140,	loss = 3.789e-04
# Epoch = 1141,	loss = 3.788e-04
# Epoch = 1142,	loss = 3.787e-04
# Epoch = 1143,	loss = 3.786e-04
# Epoch = 1144,	loss = 3.785e-04
# Epoch = 1145,	loss = 3.784e-04
# Epoch = 1146,	loss = 3.783e-04
# Epoch = 1147,	loss = 3.782e-04
# Epoch = 1148,	loss = 3.781e-04
# Epoch = 1149,	loss = 3.780e-04
# Epoch = 1150,	loss = 3.779e-04
# Epoch = 1151,	loss = 3.778e-04
# Epoch = 1152,	loss = 3.777e-04
# Epoch = 1153,	loss = 3.776e-04
# Epoch = 1154,	loss = 3.775e-04
# Epoch = 1155,	loss = 3.774e-04
# Epoch = 1156,	loss = 3.773e-04
# Epoch = 1157,	loss = 3.772e-04
# Epoch = 1158,	loss = 3.771e-04
# Epoch = 1159,	loss = 3.770e-04
# Epoch = 1160,	loss = 3.768e-04
# Epoch = 1161,	loss = 3.767e-04
# Epoch = 1162,	loss = 3.766e-04
# Epoch = 1163,	loss = 3.765e-04
# Epoch = 1164,	loss = 3.764e-04
# Epoch = 1165,	loss = 3.763e-04
# Epoch = 1166,	loss = 3.762e-04
# Epoch = 1167,	loss = 3.761e-04
# Epoch = 1168,	loss = 3.760e-04
# Epoch = 1169,	loss = 3.759e-04
# Epoch = 1170,	loss = 3.758e-04
# Epoch = 1171,	loss = 3.757e-04
# Epoch = 1172,	loss = 3.756e-04
# Epoch = 1173,	loss = 3.755e-04
# Epoch = 1174,	loss = 3.754e-04
# Epoch = 1175,	loss = 3.753e-04
# Epoch = 1176,	loss = 3.752e-04
# Epoch = 1177,	loss = 3.751e-04
# Epoch = 1178,	loss = 3.750e-04
# Epoch = 1179,	loss = 3.749e-04
# Epoch = 1180,	loss = 3.748e-04
# Epoch = 1181,	loss = 3.747e-04
# Epoch = 1182,	loss = 3.746e-04
# Epoch = 1183,	loss = 3.745e-04
# Epoch = 1184,	loss = 3.744e-04
# Epoch = 1185,	loss = 3.743e-04
# Epoch = 1186,	loss = 3.742e-04
# Epoch = 1187,	loss = 3.741e-04
# Epoch = 1188,	loss = 3.740e-04
# Epoch = 1189,	loss = 3.739e-04
# Epoch = 1190,	loss = 3.738e-04
# Epoch = 1191,	loss = 3.737e-04
# Epoch = 1192,	loss = 3.737e-04
# Epoch = 1193,	loss = 3.736e-04
# Epoch = 1194,	loss = 3.735e-04
# Epoch = 1195,	loss = 3.734e-04
# Epoch = 1196,	loss = 3.733e-04
# Epoch = 1197,	loss = 3.732e-04
# Epoch = 1198,	loss = 3.731e-04
# Epoch = 1199,	loss = 3.730e-04
# Epoch = 1200,	loss = 3.729e-04
# Epoch = 1201,	loss = 3.728e-04
# Epoch = 1202,	loss = 3.727e-04
# Epoch = 1203,	loss = 3.726e-04
# Epoch = 1204,	loss = 3.725e-04
# Epoch = 1205,	loss = 3.724e-04
# Epoch = 1206,	loss = 3.723e-04
# Epoch = 1207,	loss = 3.722e-04
# Epoch = 1208,	loss = 3.721e-04
# Epoch = 1209,	loss = 3.720e-04
# Epoch = 1210,	loss = 3.719e-04
# Epoch = 1211,	loss = 3.718e-04
# Epoch = 1212,	loss = 3.717e-04
# Epoch = 1213,	loss = 3.717e-04
# Epoch = 1214,	loss = 3.716e-04
# Epoch = 1215,	loss = 3.715e-04
# Epoch = 1216,	loss = 3.714e-04
# Epoch = 1217,	loss = 3.713e-04
# Epoch = 1218,	loss = 3.712e-04
# Epoch = 1219,	loss = 3.711e-04
# Epoch = 1220,	loss = 3.710e-04
# Epoch = 1221,	loss = 3.709e-04
# Epoch = 1222,	loss = 3.708e-04
# Epoch = 1223,	loss = 3.707e-04
# Epoch = 1224,	loss = 3.706e-04
# Epoch = 1225,	loss = 3.705e-04
# Epoch = 1226,	loss = 3.705e-04
# Epoch = 1227,	loss = 3.704e-04
# Epoch = 1228,	loss = 3.703e-04
# Epoch = 1229,	loss = 3.702e-04
# Epoch = 1230,	loss = 3.701e-04
# Epoch = 1231,	loss = 3.700e-04
# Epoch = 1232,	loss = 3.699e-04
# Epoch = 1233,	loss = 3.698e-04
# Epoch = 1234,	loss = 3.697e-04
# Epoch = 1235,	loss = 3.696e-04
# Epoch = 1236,	loss = 3.696e-04
# Epoch = 1237,	loss = 3.695e-04
# Epoch = 1238,	loss = 3.694e-04
# Epoch = 1239,	loss = 3.693e-04
# Epoch = 1240,	loss = 3.692e-04
# Epoch = 1241,	loss = 3.691e-04
# Epoch = 1242,	loss = 3.690e-04
# Epoch = 1243,	loss = 3.689e-04
# Epoch = 1244,	loss = 3.688e-04
# Epoch = 1245,	loss = 3.688e-04
# Epoch = 1246,	loss = 3.687e-04
# Epoch = 1247,	loss = 3.686e-04
# Epoch = 1248,	loss = 3.685e-04
# Epoch = 1249,	loss = 3.684e-04
# Epoch = 1250,	loss = 3.683e-04
# Epoch = 1251,	loss = 3.682e-04
# Epoch = 1252,	loss = 3.681e-04
# Epoch = 1253,	loss = 3.680e-04
# Epoch = 1254,	loss = 3.680e-04
# Epoch = 1255,	loss = 3.679e-04
# Epoch = 1256,	loss = 3.678e-04
# Epoch = 1257,	loss = 3.677e-04
# Epoch = 1258,	loss = 3.676e-04
# Epoch = 1259,	loss = 3.675e-04
# Epoch = 1260,	loss = 3.674e-04
# Epoch = 1261,	loss = 3.674e-04
# Epoch = 1262,	loss = 3.673e-04
# Epoch = 1263,	loss = 3.672e-04
# Epoch = 1264,	loss = 3.671e-04
# Epoch = 1265,	loss = 3.670e-04
# Epoch = 1266,	loss = 3.669e-04
# Epoch = 1267,	loss = 3.668e-04
# Epoch = 1268,	loss = 3.668e-04
# Epoch = 1269,	loss = 3.667e-04
# Epoch = 1270,	loss = 3.666e-04
# Epoch = 1271,	loss = 3.665e-04
# Epoch = 1272,	loss = 3.664e-04
# Epoch = 1273,	loss = 3.663e-04
# Epoch = 1274,	loss = 3.662e-04
# Epoch = 1275,	loss = 3.662e-04
# Epoch = 1276,	loss = 3.661e-04
# Epoch = 1277,	loss = 3.660e-04
# Epoch = 1278,	loss = 3.659e-04
# Epoch = 1279,	loss = 3.658e-04
# Epoch = 1280,	loss = 3.657e-04
# Epoch = 1281,	loss = 3.657e-04
# Epoch = 1282,	loss = 3.656e-04
# Epoch = 1283,	loss = 3.655e-04
# Epoch = 1284,	loss = 3.654e-04
# Epoch = 1285,	loss = 3.653e-04
# Epoch = 1286,	loss = 3.652e-04
# Epoch = 1287,	loss = 3.652e-04
# Epoch = 1288,	loss = 3.651e-04
# Epoch = 1289,	loss = 3.650e-04
# Epoch = 1290,	loss = 3.649e-04
# Epoch = 1291,	loss = 3.648e-04
# Epoch = 1292,	loss = 3.648e-04
# Epoch = 1293,	loss = 3.647e-04
# Epoch = 1294,	loss = 3.646e-04
# Epoch = 1295,	loss = 3.645e-04
# Epoch = 1296,	loss = 3.644e-04
# Epoch = 1297,	loss = 3.643e-04
# Epoch = 1298,	loss = 3.643e-04
# Epoch = 1299,	loss = 3.642e-04
# Epoch = 1300,	loss = 3.641e-04
# Epoch = 1301,	loss = 3.640e-04
# Epoch = 1302,	loss = 3.639e-04
# Epoch = 1303,	loss = 3.639e-04
# Epoch = 1304,	loss = 3.638e-04
# Epoch = 1305,	loss = 3.637e-04
# Epoch = 1306,	loss = 3.636e-04
# Epoch = 1307,	loss = 3.635e-04
# Epoch = 1308,	loss = 3.635e-04
# Epoch = 1309,	loss = 3.634e-04
# Epoch = 1310,	loss = 3.633e-04
# Epoch = 1311,	loss = 3.632e-04
# Epoch = 1312,	loss = 3.631e-04
# Epoch = 1313,	loss = 3.631e-04
# Epoch = 1314,	loss = 3.630e-04
# Epoch = 1315,	loss = 3.629e-04
# Epoch = 1316,	loss = 3.628e-04
# Epoch = 1317,	loss = 3.627e-04
# Epoch = 1318,	loss = 3.627e-04
# Epoch = 1319,	loss = 3.626e-04
# Epoch = 1320,	loss = 3.625e-04
# Epoch = 1321,	loss = 3.624e-04
# Epoch = 1322,	loss = 3.624e-04
# Epoch = 1323,	loss = 3.623e-04
# Epoch = 1324,	loss = 3.622e-04
# Epoch = 1325,	loss = 3.621e-04
# Epoch = 1326,	loss = 3.620e-04
# Epoch = 1327,	loss = 3.620e-04
# Epoch = 1328,	loss = 3.619e-04
# Epoch = 1329,	loss = 3.618e-04
# Epoch = 1330,	loss = 3.617e-04
# Epoch = 1331,	loss = 3.617e-04
# Epoch = 1332,	loss = 3.616e-04
# Epoch = 1333,	loss = 3.615e-04
# Epoch = 1334,	loss = 3.614e-04
# Epoch = 1335,	loss = 3.613e-04
# Epoch = 1336,	loss = 3.613e-04
# Epoch = 1337,	loss = 3.612e-04
# Epoch = 1338,	loss = 3.611e-04
# Epoch = 1339,	loss = 3.610e-04
# Epoch = 1340,	loss = 3.610e-04
# Epoch = 1341,	loss = 3.609e-04
# Epoch = 1342,	loss = 3.608e-04
# Epoch = 1343,	loss = 3.607e-04
# Epoch = 1344,	loss = 3.607e-04
# Epoch = 1345,	loss = 3.606e-04
# Epoch = 1346,	loss = 3.605e-04
# Epoch = 1347,	loss = 3.604e-04
# Epoch = 1348,	loss = 3.604e-04
# Epoch = 1349,	loss = 3.603e-04
# Epoch = 1350,	loss = 3.602e-04
# Epoch = 1351,	loss = 3.601e-04
# Epoch = 1352,	loss = 3.601e-04
# Epoch = 1353,	loss = 3.600e-04
# Epoch = 1354,	loss = 3.599e-04
# Epoch = 1355,	loss = 3.598e-04
# Epoch = 1356,	loss = 3.598e-04
# Epoch = 1357,	loss = 3.597e-04
# Epoch = 1358,	loss = 3.596e-04
# Epoch = 1359,	loss = 3.595e-04
# Epoch = 1360,	loss = 3.595e-04
# Epoch = 1361,	loss = 3.594e-04
# Epoch = 1362,	loss = 3.593e-04
# Epoch = 1363,	loss = 3.592e-04
# Epoch = 1364,	loss = 3.592e-04
# Epoch = 1365,	loss = 3.591e-04
# Epoch = 1366,	loss = 3.590e-04
# Epoch = 1367,	loss = 3.589e-04
# Epoch = 1368,	loss = 3.589e-04
# Epoch = 1369,	loss = 3.588e-04
# Epoch = 1370,	loss = 3.587e-04
# Epoch = 1371,	loss = 3.587e-04
# Epoch = 1372,	loss = 3.586e-04
# Epoch = 1373,	loss = 3.585e-04
# Epoch = 1374,	loss = 3.584e-04
# Epoch = 1375,	loss = 3.584e-04
# Epoch = 1376,	loss = 3.583e-04
# Epoch = 1377,	loss = 3.582e-04
# Epoch = 1378,	loss = 3.581e-04
# Epoch = 1379,	loss = 3.581e-04
# Epoch = 1380,	loss = 3.580e-04
# Epoch = 1381,	loss = 3.579e-04
# Epoch = 1382,	loss = 3.579e-04
# Epoch = 1383,	loss = 3.578e-04
# Epoch = 1384,	loss = 3.577e-04
# Epoch = 1385,	loss = 3.576e-04
# Epoch = 1386,	loss = 3.576e-04
# Epoch = 1387,	loss = 3.575e-04
# Epoch = 1388,	loss = 3.574e-04
# Epoch = 1389,	loss = 3.574e-04
# Epoch = 1390,	loss = 3.573e-04
# Epoch = 1391,	loss = 3.572e-04
# Epoch = 1392,	loss = 3.572e-04
# Epoch = 1393,	loss = 3.571e-04
# Epoch = 1394,	loss = 3.570e-04
# Epoch = 1395,	loss = 3.569e-04
# Epoch = 1396,	loss = 3.569e-04
# Epoch = 1397,	loss = 3.568e-04
# Epoch = 1398,	loss = 3.567e-04
# Epoch = 1399,	loss = 3.567e-04
# Epoch = 1400,	loss = 3.566e-04
# Epoch = 1401,	loss = 3.565e-04
# Epoch = 1402,	loss = 3.565e-04
# Epoch = 1403,	loss = 3.564e-04
# Epoch = 1404,	loss = 3.563e-04
# Epoch = 1405,	loss = 3.562e-04
# Epoch = 1406,	loss = 3.562e-04
# Epoch = 1407,	loss = 3.561e-04
# Epoch = 1408,	loss = 3.560e-04
# Epoch = 1409,	loss = 3.560e-04
# Epoch = 1410,	loss = 3.559e-04
# Epoch = 1411,	loss = 3.558e-04
# Epoch = 1412,	loss = 3.558e-04
# Epoch = 1413,	loss = 3.557e-04
# Epoch = 1414,	loss = 3.556e-04
# Epoch = 1415,	loss = 3.556e-04
# Epoch = 1416,	loss = 3.555e-04
# Epoch = 1417,	loss = 3.554e-04
# Epoch = 1418,	loss = 3.554e-04
# Epoch = 1419,	loss = 3.553e-04
# Epoch = 1420,	loss = 3.552e-04
# Epoch = 1421,	loss = 3.552e-04
# Epoch = 1422,	loss = 3.551e-04
# Epoch = 1423,	loss = 3.550e-04
# Epoch = 1424,	loss = 3.550e-04
# Epoch = 1425,	loss = 3.549e-04
# Epoch = 1426,	loss = 3.548e-04
# Epoch = 1427,	loss = 3.548e-04
# Epoch = 1428,	loss = 3.547e-04
# Epoch = 1429,	loss = 3.546e-04
# Epoch = 1430,	loss = 3.546e-04
# Epoch = 1431,	loss = 3.545e-04
# Epoch = 1432,	loss = 3.544e-04
# Epoch = 1433,	loss = 3.544e-04
# Epoch = 1434,	loss = 3.543e-04
# Epoch = 1435,	loss = 3.542e-04
# Epoch = 1436,	loss = 3.542e-04
# Epoch = 1437,	loss = 3.541e-04
# Epoch = 1438,	loss = 3.540e-04
# Epoch = 1439,	loss = 3.540e-04
# Epoch = 1440,	loss = 3.539e-04
# Epoch = 1441,	loss = 3.538e-04
# Epoch = 1442,	loss = 3.538e-04
# Epoch = 1443,	loss = 3.537e-04
# Epoch = 1444,	loss = 3.536e-04
# Epoch = 1445,	loss = 3.536e-04
# Epoch = 1446,	loss = 3.535e-04
# Epoch = 1447,	loss = 3.534e-04
# Epoch = 1448,	loss = 3.534e-04
# Epoch = 1449,	loss = 3.533e-04
# Epoch = 1450,	loss = 3.533e-04
# Epoch = 1451,	loss = 3.532e-04
# Epoch = 1452,	loss = 3.531e-04
# Epoch = 1453,	loss = 3.531e-04
# Epoch = 1454,	loss = 3.530e-04
# Epoch = 1455,	loss = 3.529e-04
# Epoch = 1456,	loss = 3.529e-04
# Epoch = 1457,	loss = 3.528e-04
# Epoch = 1458,	loss = 3.527e-04
# Epoch = 1459,	loss = 3.527e-04
# Epoch = 1460,	loss = 3.526e-04
# Epoch = 1461,	loss = 3.526e-04
# Epoch = 1462,	loss = 3.525e-04
# Epoch = 1463,	loss = 3.524e-04
# Epoch = 1464,	loss = 3.524e-04
# Epoch = 1465,	loss = 3.523e-04
# Epoch = 1466,	loss = 3.522e-04
# Epoch = 1467,	loss = 3.522e-04
# Epoch = 1468,	loss = 3.521e-04
# Epoch = 1469,	loss = 3.521e-04
# Epoch = 1470,	loss = 3.520e-04
# Epoch = 1471,	loss = 3.519e-04
# Epoch = 1472,	loss = 3.519e-04
# Epoch = 1473,	loss = 3.518e-04
# Epoch = 1474,	loss = 3.517e-04
# Epoch = 1475,	loss = 3.517e-04
# Epoch = 1476,	loss = 3.516e-04
# Epoch = 1477,	loss = 3.516e-04
# Epoch = 1478,	loss = 3.515e-04
# Epoch = 1479,	loss = 3.514e-04
# Epoch = 1480,	loss = 3.514e-04
# Epoch = 1481,	loss = 3.513e-04
# Epoch = 1482,	loss = 3.513e-04
# Epoch = 1483,	loss = 3.512e-04
# Epoch = 1484,	loss = 3.511e-04
# Epoch = 1485,	loss = 3.511e-04
# Epoch = 1486,	loss = 3.510e-04
# Epoch = 1487,	loss = 3.510e-04
# Epoch = 1488,	loss = 3.509e-04
# Epoch = 1489,	loss = 3.508e-04
# Epoch = 1490,	loss = 3.508e-04
# Epoch = 1491,	loss = 3.507e-04
# Epoch = 1492,	loss = 3.507e-04
# Epoch = 1493,	loss = 3.506e-04
# Epoch = 1494,	loss = 3.505e-04
# Epoch = 1495,	loss = 3.505e-04
# Epoch = 1496,	loss = 3.504e-04
# Epoch = 1497,	loss = 3.504e-04
# Epoch = 1498,	loss = 3.503e-04
# Epoch = 1499,	loss = 3.502e-04
# Epoch = 1500,	loss = 3.502e-04
# Epoch = 1501,	loss = 3.501e-04
# Epoch = 1502,	loss = 3.501e-04
# Epoch = 1503,	loss = 3.500e-04
# Epoch = 1504,	loss = 3.499e-04
# Epoch = 1505,	loss = 3.499e-04
# Epoch = 1506,	loss = 3.498e-04
# Epoch = 1507,	loss = 3.498e-04
# Epoch = 1508,	loss = 3.497e-04
# Epoch = 1509,	loss = 3.497e-04
# Epoch = 1510,	loss = 3.496e-04
# Epoch = 1511,	loss = 3.495e-04
# Epoch = 1512,	loss = 3.495e-04
# Epoch = 1513,	loss = 3.494e-04
# Epoch = 1514,	loss = 3.494e-04
# Epoch = 1515,	loss = 3.493e-04
# Epoch = 1516,	loss = 3.493e-04
# Epoch = 1517,	loss = 3.492e-04
# Epoch = 1518,	loss = 3.491e-04
# Epoch = 1519,	loss = 3.491e-04
# Epoch = 1520,	loss = 3.490e-04
# Epoch = 1521,	loss = 3.490e-04
# Epoch = 1522,	loss = 3.489e-04
# Epoch = 1523,	loss = 3.489e-04
# Epoch = 1524,	loss = 3.488e-04
# Epoch = 1525,	loss = 3.487e-04
# Epoch = 1526,	loss = 3.487e-04
# Epoch = 1527,	loss = 3.486e-04
# Epoch = 1528,	loss = 3.486e-04
# Epoch = 1529,	loss = 3.485e-04
# Epoch = 1530,	loss = 3.485e-04
# Epoch = 1531,	loss = 3.484e-04
# Epoch = 1532,	loss = 3.484e-04
# Epoch = 1533,	loss = 3.483e-04
# Epoch = 1534,	loss = 3.482e-04
# Epoch = 1535,	loss = 3.482e-04
# Epoch = 1536,	loss = 3.481e-04
# Epoch = 1537,	loss = 3.481e-04
# Epoch = 1538,	loss = 3.480e-04
# Epoch = 1539,	loss = 3.480e-04
# Epoch = 1540,	loss = 3.479e-04
# Epoch = 1541,	loss = 3.479e-04
# Epoch = 1542,	loss = 3.478e-04
# Epoch = 1543,	loss = 3.477e-04
# Epoch = 1544,	loss = 3.477e-04
# Epoch = 1545,	loss = 3.476e-04
# Epoch = 1546,	loss = 3.476e-04
# Epoch = 1547,	loss = 3.475e-04
# Epoch = 1548,	loss = 3.475e-04
# Epoch = 1549,	loss = 3.474e-04
# Epoch = 1550,	loss = 3.474e-04
# Epoch = 1551,	loss = 3.473e-04
# Epoch = 1552,	loss = 3.473e-04
# Epoch = 1553,	loss = 3.472e-04
# Epoch = 1554,	loss = 3.472e-04
# Epoch = 1555,	loss = 3.471e-04
# Epoch = 1556,	loss = 3.470e-04
# Epoch = 1557,	loss = 3.470e-04
# Epoch = 1558,	loss = 3.469e-04
# Epoch = 1559,	loss = 3.469e-04
# Epoch = 1560,	loss = 3.468e-04
# Epoch = 1561,	loss = 3.468e-04
# Epoch = 1562,	loss = 3.467e-04
# Epoch = 1563,	loss = 3.467e-04
# Epoch = 1564,	loss = 3.466e-04
# Epoch = 1565,	loss = 3.466e-04
# Epoch = 1566,	loss = 3.465e-04
# Epoch = 1567,	loss = 3.465e-04
# Epoch = 1568,	loss = 3.464e-04
# Epoch = 1569,	loss = 3.464e-04
# Epoch = 1570,	loss = 3.463e-04
# Epoch = 1571,	loss = 3.463e-04
# Epoch = 1572,	loss = 3.462e-04
# Epoch = 1573,	loss = 3.461e-04
# Epoch = 1574,	loss = 3.461e-04
# Epoch = 1575,	loss = 3.460e-04
# Epoch = 1576,	loss = 3.460e-04
# Epoch = 1577,	loss = 3.459e-04
# Epoch = 1578,	loss = 3.459e-04
# Epoch = 1579,	loss = 3.458e-04
# Epoch = 1580,	loss = 3.458e-04
# Epoch = 1581,	loss = 3.457e-04
# Epoch = 1582,	loss = 3.457e-04
# Epoch = 1583,	loss = 3.456e-04
# ...
# Epoch = 4487,	loss = 2.895e-04
# Epoch = 4488,	loss = 2.895e-04
# Epoch = 4489,	loss = 2.895e-04
# Epoch = 4490,	loss = 2.895e-04
# Epoch = 4491,	loss = 2.895e-04
# Epoch = 4492,	loss = 2.895e-04
# Epoch = 4493,	loss = 2.895e-04
# Epoch = 4494,	loss = 2.895e-04
# Epoch = 4495,	loss = 2.895e-04
# Epoch = 4496,	loss = 2.895e-04
# Epoch = 4497,	loss = 2.895e-04
# Epoch = 4498,	loss = 2.895e-04
# Epoch = 4499,	loss = 2.895e-04
# Epoch = 4500,	loss = 2.895e-04
# Epoch = 4501,	loss = 2.895e-04
# Epoch = 4502,	loss = 2.895e-04
# Epoch = 4503,	loss = 2.895e-04
# Epoch = 4504,	loss = 2.895e-04
# Epoch = 4505,	loss = 2.895e-04
# Epoch = 4506,	loss = 2.895e-04
# Epoch = 4507,	loss = 2.895e-04
# Epoch = 4508,	loss = 2.895e-04
# Epoch = 4509,	loss = 2.895e-04
# Epoch = 4510,	loss = 2.895e-04
# Epoch = 4511,	loss = 2.895e-04
# Epoch = 4512,	loss = 2.895e-04
# Epoch = 4513,	loss = 2.895e-04
# Epoch = 4514,	loss = 2.895e-04
# Epoch = 4515,	loss = 2.895e-04
# Epoch = 4516,	loss = 2.895e-04
# Epoch = 4517,	loss = 2.895e-04
# Epoch = 4518,	loss = 2.895e-04
# Epoch = 4519,	loss = 2.895e-04
# Epoch = 4520,	loss = 2.895e-04
# Epoch = 4521,	loss = 2.895e-04
# Epoch = 4522,	loss = 2.895e-04
# Epoch = 4523,	loss = 2.895e-04
# Epoch = 4524,	loss = 2.895e-04
# Epoch = 4525,	loss = 2.895e-04
# Epoch = 4526,	loss = 2.895e-04
# Epoch = 4527,	loss = 2.895e-04
# Epoch = 4528,	loss = 2.895e-04
# Epoch = 4529,	loss = 2.895e-04
# Epoch = 4530,	loss = 2.895e-04
# Epoch = 4531,	loss = 2.895e-04
# Epoch = 4532,	loss = 2.895e-04
# Epoch = 4533,	loss = 2.895e-04
# Epoch = 4534,	loss = 2.895e-04
# Epoch = 4535,	loss = 2.895e-04
# Epoch = 4536,	loss = 2.895e-04
# Epoch = 4537,	loss = 2.895e-04
# Epoch = 4538,	loss = 2.895e-04
# Epoch = 4539,	loss = 2.895e-04
# Epoch = 4540,	loss = 2.895e-04
# Epoch = 4541,	loss = 2.895e-04
# Epoch = 4542,	loss = 2.895e-04
# Epoch = 4543,	loss = 2.895e-04
# Epoch = 4544,	loss = 2.895e-04
# Epoch = 4545,	loss = 2.895e-04
# Epoch = 4546,	loss = 2.895e-04
# Epoch = 4547,	loss = 2.895e-04
# Epoch = 4548,	loss = 2.895e-04
# Epoch = 4549,	loss = 2.895e-04
# Epoch = 4550,	loss = 2.895e-04
# Epoch = 4551,	loss = 2.895e-04
# Epoch = 4552,	loss = 2.895e-04
# Epoch = 4553,	loss = 2.895e-04
# Epoch = 4554,	loss = 2.895e-04
# Epoch = 4555,	loss = 2.895e-04
# Epoch = 4556,	loss = 2.895e-04
# Epoch = 4557,	loss = 2.895e-04
# Epoch = 4558,	loss = 2.895e-04
# Epoch = 4559,	loss = 2.895e-04
# Epoch = 4560,	loss = 2.895e-04
# Epoch = 4561,	loss = 2.895e-04
# Epoch = 4562,	loss = 2.895e-04
# Epoch = 4563,	loss = 2.895e-04
# Epoch = 4564,	loss = 2.895e-04
# Epoch = 4565,	loss = 2.895e-04
# Epoch = 4566,	loss = 2.895e-04
# Epoch = 4567,	loss = 2.895e-04
# Epoch = 4568,	loss = 2.895e-04
# Epoch = 4569,	loss = 2.895e-04
# Epoch = 4570,	loss = 2.895e-04
# Epoch = 4571,	loss = 2.895e-04
# Epoch = 4572,	loss = 2.895e-04
# Epoch = 4573,	loss = 2.895e-04
# Epoch = 4574,	loss = 2.895e-04
# Epoch = 4575,	loss = 2.895e-04
# Epoch = 4576,	loss = 2.895e-04
# Epoch = 4577,	loss = 2.895e-04
# Epoch = 4578,	loss = 2.895e-04
# Epoch = 4579,	loss = 2.895e-04
# Epoch = 4580,	loss = 2.895e-04
# Epoch = 4581,	loss = 2.895e-04
# Epoch = 4582,	loss = 2.895e-04
# Epoch = 4583,	loss = 2.895e-04
# Epoch = 4584,	loss = 2.895e-04
# Epoch = 4585,	loss = 2.895e-04
# Epoch = 4586,	loss = 2.895e-04
# Epoch = 4587,	loss = 2.895e-04
# Epoch = 4588,	loss = 2.895e-04
# Epoch = 4589,	loss = 2.895e-04
# Epoch = 4590,	loss = 2.895e-04
# Epoch = 4591,	loss = 2.895e-04
# Epoch = 4592,	loss = 2.895e-04
# Epoch = 4593,	loss = 2.895e-04
# Epoch = 4945,	loss = 2.895e-04
# Epoch = 4946,	loss = 2.895e-04
# Epoch = 4947,	loss = 2.895e-04
# Epoch = 4948,	loss = 2.895e-04
# Epoch = 4949,	loss = 2.895e-04
# Epoch = 4950,	loss = 2.895e-04
# Epoch = 4951,	loss = 2.895e-04
# Epoch = 4952,	loss = 2.895e-04
# Epoch = 4953,	loss = 2.895e-04
# Epoch = 4954,	loss = 2.895e-04
# Epoch = 4955,	loss = 2.895e-04
# Epoch = 4956,	loss = 2.895e-04
# Epoch = 4957,	loss = 2.895e-04
# Epoch = 4958,	loss = 2.895e-04
# Epoch = 4959,	loss = 2.895e-04
# Epoch = 4960,	loss = 2.895e-04
# Epoch = 4961,	loss = 2.895e-04
# Epoch = 4962,	loss = 2.895e-04
# Epoch = 4963,	loss = 2.895e-04
# Epoch = 4964,	loss = 2.895e-04
# Epoch = 4965,	loss = 2.895e-04
# Epoch = 4966,	loss = 2.895e-04
# Epoch = 4967,	loss = 2.895e-04
# Epoch = 4968,	loss = 2.895e-04
# Epoch = 4969,	loss = 2.895e-04
# Epoch = 4970,	loss = 2.895e-04
# Epoch = 4971,	loss = 2.895e-04
# Epoch = 4972,	loss = 2.895e-04
# Epoch = 4973,	loss = 2.895e-04
# Epoch = 4974,	loss = 2.895e-04
# Epoch = 4975,	loss = 2.895e-04
# Epoch = 4976,	loss = 2.895e-04
# Epoch = 4977,	loss = 2.895e-04
# Epoch = 4978,	loss = 2.895e-04
# Epoch = 4979,	loss = 2.895e-04
# Epoch = 4980,	loss = 2.895e-04
# Epoch = 4981,	loss = 2.895e-04
# Epoch = 4982,	loss = 2.895e-04
# Epoch = 4983,	loss = 2.895e-04
# Epoch = 4984,	loss = 2.895e-04
# Epoch = 4985,	loss = 2.895e-04
# Epoch = 4986,	loss = 2.895e-04
# Epoch = 4987,	loss = 2.895e-04
# Epoch = 4988,	loss = 2.895e-04
# Epoch = 4989,	loss = 2.895e-04
# Epoch = 4990,	loss = 2.895e-04
# Epoch = 4991,	loss = 2.895e-04
# Epoch = 4992,	loss = 2.895e-04
# Epoch = 4993,	loss = 2.895e-04
# Epoch = 4994,	loss = 2.895e-04
# Epoch = 4995,	loss = 2.895e-04
# Epoch = 4996,	loss = 2.895e-04
# Epoch = 4997,	loss = 2.895e-04
# Epoch = 4998,	loss = 2.895e-04
# Epoch = 4999,	loss = 2.895e-04
# CPU times: user 20.5 s, sys: 2.84 s, total: 23.4 s
# Wall time: 16.9 s

# %%
# Plotting the Loss Curve
plt.semilogy(loss_value, label="Total", linewidth=2) # Plots the total loss
#plt.semilogy(loss_pde, label="PDE", linewidth=2)     # Plots the PDE loss
#plt.semilogy(loss_tau, label="tau", linewidth=2)    # Plots the tau loss

plt.title("Elliptically Anisotropic Model Loss", fontsize=14)   # Sets the title of the figure

plt.xlabel("Epochs ", fontsize=15)              # Sets the x-axis label of the figure
plt.ylabel("Loss", fontsize=15,)                # Sets the y-axis label of the figure

plt.grid(color = 'black', linestyle = '--', linewidth = 0.5) # Sets the grid of the figure

plt.legend(loc="upper right")   # Sets the legend of the figure

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/SElliptically Anisotropic Model Loss.pdf", format="pdf", bbox_inches="tight") # Saves the figure

plt.show() # Displays the figure

# %% [markdown]
# <a id="t_pred"></a>
# #### T Prediction

# %%
# Predicts tau output
tau_pred = tau(params,X_star[0].reshape(-1,1),X_star[1].reshape(-1,1))

tau_pred = tau_pred.reshape(Z.shape)

T_pred = tau_pred*T0

# %%
# Load fast sweeping traveltims for comparison

T_ref = jnp.load('/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/inputs/vtiseam/traveltimes/Tref.npy')*TOPO
T_comp = jnp.load('/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/inputs/vtiseam/traveltimes/Tcomp.npy')*TOPO

# %%
#Plot the difference between T_Pred and T_Ref

plt.style.use('default')     # Sets the default style for the plot

plt.figure(figsize=(4,4))    # Creates a new figure with a size of 4x4

plt.title("Elliptically Anisotropic Model Difference Plot (T_1)")    # Sets the title of the figure

ax = plt.gca()              # Gets the current axes instance.
im = ax.imshow(jnp.abs(T_pred-T_ref), extent=[x_min,x_max,z_max,z_min], aspect=1, cmap="jet")  # Plots the velocity model as an image on the current axes (ax)

ax.plot(sx,sz,'k*',markersize=8)  # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14) # Sets the label for the x-axis
plt.xticks(fontsize=10)           # Sets the font size for the x-axis tick labels

plt.ylabel('Depth (km)', fontsize=14)  # Sets the label for the y-axis
plt.yticks(fontsize=10)           # Sets the font size for the y-axis tick labels

ax.xaxis.set_major_locator(plt.MultipleLocator(2)) # Sets the major tick locator for the x-axis to have ticks at intervals of 0.5.
ax.yaxis.set_major_locator(plt.MultipleLocator(2)) # Sets the major tick locator for the y-axis to have ticks at intervals of 0.5.

divider = make_axes_locatable(ax)  # Creates a divider to make room for the colorbar
cax = divider.append_axes("right", size="6%", pad=0.15) # Appends an axes on the right side of the plot to accommodate the colorbar

cbar = plt.colorbar(im, cax=cax)   # Adds a colorbar to the plot using the image im and the colorbar axes cax

cbar.set_label('km/s',size=10)     # Sets the label for the colorbar.
cbar.ax.tick_params(labelsize=10)  # Sets the font size of the colorbar tick labels.

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/Elliptically Anisotropic Model Difference Plot (T_1).pdf", format='pdf', bbox_inches="tight")

# %%
#Plot the difference between T_Ref and T_Comp

plt.style.use('default')     # Sets the default style for the plot

plt.figure(figsize=(4,4))    # Creates a new figure with a size of 4x4

plt.title("Elliptically Anisotropic Model Difference Plot (T_2)")    # Sets the title of the figure

ax = plt.gca()              # Gets the current axes instance.
im = ax.imshow(jnp.abs(T_ref-T_comp), extent=[x_min,x_max,z_max,z_min], aspect=1, cmap="jet")  # Plots the velocity model as an image on the current axes (ax)

ax.plot(sx,sz,'k*',markersize=8)  # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14) # Sets the label for the x-axis
plt.xticks(fontsize=10)           # Sets the font size for the x-axis tick labels

plt.ylabel('Depth (km)', fontsize=14)  # Sets the label for the y-axis
plt.yticks(fontsize=10)           # Sets the font size for the y-axis tick labels

ax.xaxis.set_major_locator(plt.MultipleLocator(2)) # Sets the major tick locator for the x-axis to have ticks at intervals of 0.5.
ax.yaxis.set_major_locator(plt.MultipleLocator(2)) # Sets the major tick locator for the y-axis to have ticks at intervals of 0.5.

divider = make_axes_locatable(ax)  # Creates a divider to make room for the colorbar
cax = divider.append_axes("right", size="6%", pad=0.15) # Appends an axes on the right side of the plot to accommodate the colorbar

cbar = plt.colorbar(im, cax=cax)   # Adds a colorbar to the plot using the image im and the colorbar axes cax

cbar.set_label('km/s',size=10)     # Sets the label for the colorbar.
cbar.ax.tick_params(labelsize=10)  # Sets the font size of the colorbar tick labels.

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/Elliptically Anisotropic Model Difference Plot (T_2).pdf", format='pdf', bbox_inches="tight")

# %%
# Traveltime contour plots

plt.figure(figsize=(5,5)) # Creates a new figure with a size of 5x5 inches

ax = plt.gca()      # Gets the current axes instance

plt.title("Elliptically Anisotropic Model Contour Plot", fontsize=14)    # Sets the title of the figure

# Plots the contours of the difference T values as an image
im1 = ax.contour(T_ref, 6, extent=[x_min,x_max,z_min,z_max], colors='r')
im2 = ax.contour(T_pred, 6, extent=[x_min,x_max,z_min,z_max], colors='k',linestyles = 'dashed')
im3 = ax.contour(T_comp, 6, extent=[x_min,x_max,z_min,z_max], colors='b',linestyles = 'dotted')

plt.plot(x,topo,'k')             # Plots the topography

ax.plot(sx,sz,'k*',markersize=8) # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14)   # Sets the x-axis label
plt.ylabel('Depth (km)', fontsize=14)    # Sets the y-axis label

ax.tick_params(axis='both', which='major', labelsize=8)
plt.gca().invert_yaxis()

# Sets im1 legend
h1,_ = im1.legend_elements()
h2,_ = im2.legend_elements()
h3,_ = im3.legend_elements()

ax.legend([h1[0], h2[0], h3[0]], ['Reference', 'PINN', 'Fast sweeping'],fontsize=12,loc='lower left')  # Sets the combined legend

ax.xaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the x-axis
ax.yaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the y-axis

plt.xticks(fontsize=10)   # Sets the x-axis ticks
plt.yticks(fontsize=10)   # Sets the y-axis ticks

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/Elliptically Anisotropic Model Contour Plot.pdf", format="pdf", bbox_inches="tight")

plt.show()

# %%
# Determining the accuracy of the model by quantifying the difference between T_pred and T_data using Vector Norm
print(jnp.linalg.norm(T_pred-T_ref/jnp.linalg.norm(T_ref)))
print(jnp.linalg.norm(T_pred-T_ref))
# Out:
# nan
# nan
