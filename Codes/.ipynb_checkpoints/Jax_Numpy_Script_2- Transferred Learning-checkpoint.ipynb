# %% [markdown]
# ## Transfer Learning for Smooth Velocity Model

# %% [markdown]
# #### Table of Contents
# <ul>
# <li><a href="#lib">Necessary Libraries<a/></li>
# <li><a href="#gpu">GPU Setting & Code Reproducibility<a/></li>
# <li><a href="#model">Velocity Model<a/></li>
# <li><a href="#analytical">Analytical Solution<a/></li>
# <li><a href="#test">Testing Data<a/></li>
# <li><a href="#train">Training Data<a/></li>
# <li><a href="#sids">Source Location ID<a/></li>
# <li><a href="#archi">Network Architecture & Random Initialisation<a/></li>
# <li><a href="#tau">Neural Network<a/></li>
# <li><a href="#pde">Eikonal PDE Loss<a/></li>
# <li><a href="#other">Other Losses<a/></li>
# <li><a href="#comnbine">Combined Loss Function<a/></li>
# <li><a href="#new">New Model Training<a/></li>
# <li><a href="#transferred">Transferred Model Training<a/></li>
# <li><a href="#loss">Loss Curves<a/></li>
# <li><a href="#tau_pred">Tau Prediction<a/></li>
# <li><a href="#t_pred">T Prediction<a/></li>
# <li><a href="#accuracy">Rapid Accuracy Assessment<a/></li>

# %% [markdown]
# <a id="lib"></a>
# #### Necessary Libraries

# %%
# Jax Libraries
import jax
import jax.numpy as jnp
from jax import grad, jit, random
import optax
import pickle
from jax.lib import xla_bridge

# Data Visualisation Libraries
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# Operating System and gpu
import os 
import subprocess

# Additional 
import timeit

# %% [markdown]
# <a id="gpu"></a>
# #### GPU Setting & Code Reproducibility

# %%
# Displays if the notebook currently has access to a gpu
print(f"This Notebook is currently running on a: {(xla_bridge.get_backend().platform)}")

# Assigns a specific GPU to be used
GPU = 1
os.environ['CUDA_VISIBLE_DEVICES'] = 'GPU'

# Displays the GPU details used for the notebook execution
output = subprocess.check_output(['nvidia-smi', '-L']).decode('utf-8')
gpu_info = output.strip().split('\n')
print(gpu_info[GPU])

# Defines a random key to be employed using seed 0
random_key = random.PRNGKey(0)
# Out:
# This Notebook is currently running on a: gpu
# GPU 1: NVIDIA RTX A5000 (UUID: GPU-ee5cc10d-b7ab-8d6d-9149-28295c7820d0)

# %% [markdown]
# <a id="model"></a>
# #### Velocity Model

# %%
v0 = 2.; # Velocity at origin

z_grad = 0.4; # Vertical gradient
x_grad = 0.1; # Horizontal gradient

z_min = 0.; z_max = 6.; z_delta = 0.02;
x_min = 0.; x_max = 6.; x_delta = 0.02;


# Point-source location
sz = 1.0; sx = 4.0;

# Number of training points
training_points = 2500

# %%
# Generating the vertical and horizontal values of our model

z = jnp.arange(z_min,z_max+z_delta,z_delta)
nz = z.size

x = jnp.arange(x_min,x_max+x_delta,x_delta)
nx =x.size

# %%
Z,X = jnp.meshgrid(z,x,indexing='ij')

# %%
# Preparing velocity model
vs = v0 + z_grad*sz + x_grad*sx # Velocity at the source location
velmodel = vs + z_grad*(Z-sz) + x_grad*(X-sx);

# %%
# Model with the source location

plt.style.use('default')         # Sets the default style for the plot

plt.figure(figsize=(4,4))        # Creates a new figure with a size of 4x4 inches

plt.title("TL Velocity Model")    # Sets the title of the figure

ax = plt.gca()                   # Gets the current axes instance.
im = ax.imshow(velmodel, extent=[x_min,x_max,z_max,z_min], aspect=1, cmap="jet") # Plots the velocity model velmodel as an image on the current axes (ax)

ax.plot(sx,sz,'k*',markersize=8) # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14)     # Sets the label for the x-axis
plt.xticks(fontsize=10)          # Sets the font size for the x-axis tick labels

plt.ylabel('Depth (km)', fontsize=14)      # Sets the label for the y-axis
plt.yticks(fontsize=10)          # Sets the font size for the y-axis tick labels

ax.xaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the major tick locator for the x-axis to have ticks at intervals of 0.5.
ax.yaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the major tick locator for the y-axis to have ticks at intervals of 0.5.

divider = make_axes_locatable(ax)         # Creates a divider to make room for the colorbar
cax = divider.append_axes("right", size="6%", pad=0.15) # Appends an axes on the right side of the plot to accommodate the colorbar

cbar = plt.colorbar(im, cax=cax) # Adds a colorbar to the plot using the image im and the colorbar axes cax

cbar.set_label('km/s',size=10)   # Sets the label for the colorbar.
cbar.ax.tick_params(labelsize=10)        # Sets the font size of the colorbar tick labels.

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/TL Velocity Model.pdf", format= "pdf",bbox_inches="tight")  # Saves the image as a pdf file at the specified file directory

plt.show()   # Displays the defined image

# %% [markdown]
# <a id="analytical"></a>
# #### Analytical SOlution

# %%
# Traveltime solution
if z_grad==0 and x_grad==0: 
  # For homogeneous velocity model
  T_data = jnp.sqrt((Z-sz)**2 + (X-sx)**2)/v0
else: 
  # For velocity gradient model
  T_data = jnp.arccosh(1.0+0.5*(1.0/velmodel)*(1/vs)*(z_grad**2 + x_grad**2)*((X-sx)**2 + (Z-sz)**2))/jnp.sqrt(z_grad**2 + x_grad**2)

# %% [markdown]
# <a id="test"></a>
# #### Testing Data

# %%
# Grid points for prediction 
X_star = [Z.reshape(-1,1), X.reshape(-1,1)]

# %%
# Analytical solution
vel = velmodel[int(round(sz/z_delta)),int(round(sx/x_delta))] # Velocity at the source location

T0 = jnp.sqrt((Z-sz)**2 + (X-sx)**2)/vel; 

px0 = jnp.where(T0 != 0, jnp.divide(X - sx, T0 * vel**2), 0)

pz0 = jnp.where(T0 != 0, jnp.divide(Z - sz, T0 * vel**2), 0)

# %% [markdown]
# <a id="train"></a>
# #### Training Data

# %%
# Saves 2500 randomly selected points
selected_points = random.choice(random_key, jnp.arange(Z.size), shape=(training_points,), replace=False)

# %%
# Z and X Values for training
Zf = Z.reshape(-1,1)[selected_points] # selects the 2500 points from Zf
Zf = jnp.append(Zf,sz)                # Appends the source location to the selected points for Zf
Xf = X.reshape(-1,1)[selected_points] # selects the 2500 points from Xf
Xf = jnp.append(Xf,sx)                # Appends the source location to the selected points for Xf

# %%
# Grid points for training
X_starf = [Zf.reshape(-1,1), Xf.reshape(-1,1)]

# %%
# Preparing Training data
velmodelf = velmodel.reshape(-1,1)[selected_points]; velmodelf = jnp.append(velmodelf,vs)   # selects the 2500 points from velmodel and appends the velocity at source location
px0f = px0.reshape(-1,1)[selected_points]; px0f = jnp.append(px0f,0.)    # selects the 2500 points from px0 and appends the value at source location
pz0f = pz0.reshape(-1,1)[selected_points]; pz0f = jnp.append(pz0f,0.)    # selects the 2500 points from pz0 and appends the value at source location
T0f = T0.reshape(-1,1)[selected_points]; T0f = jnp.append(T0f,0.)        # selects the 2500 points from T0 and appends the value at source location

# %% [markdown]
# <a id="sids"></a>
# #### Source Location ID

# %%
# Tolerance values for the x and z coordinates
TOLX = 1e-6
TOLZ = 1e-6

sids,_= jnp.where(jnp.logical_and(jnp.abs(X_starf[0]-sz)<TOLZ , jnp.abs(X_starf[1]-sx)<TOLX))   # Computes the source location ID using the established tolerance values

print(sids)
print(sids.shape)
print(X_starf[0][sids,0])
print(X_starf[1][sids,0])
# Out:
# [2500]
# (1,)
# [1.]
# [4.]

# %% [markdown]
# <a id="archi"></a>
# #### Network Architecture & Random Initialisation

# %%
# defines the number of hidden layers and neuron contained within each layer
layers = [2,20,20,20,20,20,20,20,20,20,20,1]

# %%
# Function to randomly initialise the network parameters using Xavier iniatialisation
def init_params(layers):

  keys = jax.random.split(jax.random.PRNGKey(0),len(layers)-1)
  params = list()      # Defines an empty list to store the parameters

  for key,n_in,n_out in zip(keys,layers[:-1],layers[1:]):   # For loop iterates over the keys, number of input neurons (n_in), and number of output neurons 
    lb = -(1 / jnp.sqrt(n_in)) # lower bound
    ub = (1 / jnp.sqrt(n_in)) # upper bound
    W = lb + (ub-lb) * jax.random.uniform(key,shape=(n_in,n_out))  # Initialises the weight matrix
    B = jax.random.uniform(key,shape=(n_out,))             # Initialises the bias vector 
    params.append({'W':W,'B':B})                           # Adds a dictionary containing the weight matrix W and bias vector B to the params list
  return params        # Returns the initialised parameters

# %%
# Initialises the parameters of the neural network based on the specified layer architecture.
params = init_params(layers)

# %% [markdown]
# <a id="tau"></a>
# #### Neural Network

# %%
# Function tau to computes the output of the neural network 
def tau(params,zt,xt):

  X = jnp.concatenate([zt,xt],axis=1)

  *hidden,last = params
  for layer in hidden:

    X = jax.nn.tanh(X@layer['W']+layer['B']) # Applying the hyperbolic tangent (tanh) activation function

  return X@last['W'] + last['B']

# %% [markdown]
# <a id="pde"></a>
# #### Eikonal PDE Loss

# %%
@jax.jit   # Just-in-Time (JIT) decorator to accelerate computation
def pde_loss(params,X_starf,T0t,px0t,pz0t,vt):
    
    # Reshapes all input parameters
    zt = X_starf[0].reshape(-1, 1)
    xt = X_starf[1].reshape(-1, 1)
    T0t = T0t.reshape(-1, 1)
    px0t = px0t.reshape(-1, 1)
    pz0t = pz0t.reshape(-1, 1)
    vt = vt.reshape(-1, 1)
    
    # Computes the output of the neural network
    tau_output = tau(params,zt,xt) 
    
    # Computes the gradient
    dtau_dz = jax.grad(lambda zt,xt: jnp.sum(tau(params, zt,xt)), argnums=0)(zt,xt)  # Gradient of the tau function with respect to zt
    dtau_dx = jax.grad(lambda zt,xt: jnp.sum(tau(params, zt,xt)), argnums=1)(zt,xt)  # # Gradient of the tau function with respect to xt

    # Computes the combined term
    term1 = T0t * dtau_dz + tau_output * pz0t
    term2 = T0t * dtau_dx + tau_output * px0t
    
    # Computes the PDE loss value using MSE function 
    loss_pde = MSE(0,10*(jnp.square(term1) + jnp.square(term2) - 1.0 / (vt ** 2))) 
    
    return loss_pde

# %% [markdown]
# <a id="other"></a>
# #### Other Losses

# %%
@jax.jit    # Just-in-Time (JIT) decorator to accelerate computation
def MSE(true_tau,pred_tau):
    # Function to compute mean squared error (MSE)
    
    return jnp.mean((true_tau-pred_tau)**2)  # Computes and returns the MSE between true and pred

# %%
@jax.jit   # Just-in-Time (JIT) decorator to accelerate computation
def tau_loss(params,X_starf):
    # Function to compute tau loss
    
    # # Reshapes all input parameters
    zt = X_starf[0].reshape(-1, 1)
    xt = X_starf[1].reshape(-1, 1)
    
    # Computes the output of the neural network
    tau_output = tau(params,zt,xt)  
    
    # Computes the tau loss value using MSE function
    tau_loss = MSE(jnp.ones(sids.shape), tau_output[sids])
    
    
    return tau_loss

# %% [markdown]
# <a id="combine"></a>
# #### Combined Loss Function

# %%
@jax.jit    # Just-in-Time (JIT) decorator to accelerate computation
def loss_fun(params,X_starf, T0t, px0t, pz0t, vt):
    # Function to compute the combined loss from tau and PDE
    
    loss_tau = tau_loss(params,X_starf) # Obtains the tau loss value from tau loss function
    loss_pde = pde_loss(params,X_starf, T0t, px0t, pz0t, vt) # Obtains the PDE loss value from PDE loss function
    
    return loss_pde + loss_tau # Computes and returns the sum of the boths losses

# %% [markdown]
# <a id="new"></a>
# #### New Learning

# %%
# defines an adaptive learning rate that changes at specified epochs
lr = optax.piecewise_constant_schedule(9e-3,{650:7e-3,7500:7e-3}) 

# Utilises the adam optimiser
optimizer = optax.adam(lr)

# Updates the parameters
opt_state = optimizer.init(params)

# %%
@jax.jit    # Just-in-Time (JIT) decorator to accelerate computation
def update(opt_state,params,X_starf, T0t, px0t, pz0t, vt):
    # Function to update the parameters for each gradient descent
    
    # calculates the gradients of loss_fun
    grads=jax.grad(loss_fun,0)(params,X_starf, T0t, px0t, pz0t, vt)

    # Update params
    updates, opt_state = optimizer.update(grads, opt_state)
    
    # Applies the updated params
    params = optax.apply_updates(params, updates)

    return opt_state,params

# %%
# %%time
epochs = 700 
loss_value = [] # List to hold the values of the combines loss
loss_pde = []   # List to hold the values of the PDE loss
loss_tau = []   # # List to hold the values of the tau loss

for epoch in range(epochs):  # For loop to iterate over the stipulates epochs
    opt_state, params = update(opt_state,params, X_starf,T0f, px0f, pz0f, velmodelf)

    # print loss and epoch info
    if epoch%(1) ==0:
        loss_pp = loss_fun(params,X_starf,T0f, px0f, pz0f, velmodelf) # Computes the total loss
        loss_value.append(loss_pp)                                    # Appends the total loss value to the declared list
        print(f'Epoch = {epoch},\tloss = {loss_pp:.3e}')              # Prints the total loss values for each epoch

        #Individual losses
        loss_pde.append(pde_loss(params,X_starf, T0f, px0f, pz0f, velmodelf)) # Computes and appends the PDE loss
        loss_tau.append(tau_loss(params,X_starf))                       # Computes and appends the tau loss
# Out:
# Epoch = 0,	loss = 7.357e-01
# Epoch = 1,	loss = 2.181e-01
# Epoch = 2,	loss = 2.758e-01
# Epoch = 3,	loss = 4.050e-01
# Epoch = 4,	loss = 3.916e-01
# Epoch = 5,	loss = 2.887e-01
# Epoch = 6,	loss = 2.018e-01
# Epoch = 7,	loss = 2.164e-01
# Epoch = 8,	loss = 2.848e-01
# Epoch = 9,	loss = 2.786e-01
# Epoch = 10,	loss = 2.223e-01
# Epoch = 11,	loss = 1.928e-01
# Epoch = 12,	loss = 2.052e-01
# Epoch = 13,	loss = 2.295e-01
# Epoch = 14,	loss = 2.375e-01
# Epoch = 15,	loss = 2.240e-01
# Epoch = 16,	loss = 2.012e-01
# Epoch = 17,	loss = 1.859e-01
# Epoch = 18,	loss = 1.851e-01
# Epoch = 19,	loss = 1.888e-01
# Epoch = 20,	loss = 1.792e-01
# Epoch = 21,	loss = 1.543e-01
# Epoch = 22,	loss = 1.309e-01
# Epoch = 23,	loss = 1.190e-01
# Epoch = 24,	loss = 1.121e-01
# Epoch = 25,	loss = 1.023e-01
# Epoch = 26,	loss = 8.442e-02
# Epoch = 27,	loss = 5.910e-02
# Epoch = 28,	loss = 4.381e-02
# Epoch = 29,	loss = 4.405e-02
# Epoch = 30,	loss = 3.722e-02
# Epoch = 31,	loss = 2.251e-02
# Epoch = 32,	loss = 1.306e-02
# Epoch = 33,	loss = 7.796e-03
# Epoch = 34,	loss = 5.793e-03
# Epoch = 35,	loss = 9.474e-03
# Epoch = 36,	loss = 1.719e-02
# Epoch = 37,	loss = 1.991e-02
# Epoch = 38,	loss = 9.616e-03
# Epoch = 39,	loss = 1.259e-02
# Epoch = 40,	loss = 1.299e-02
# Epoch = 41,	loss = 6.044e-03
# Epoch = 42,	loss = 1.083e-02
# Epoch = 43,	loss = 7.184e-03
# Epoch = 44,	loss = 4.307e-03
# Epoch = 45,	loss = 7.058e-03
# Epoch = 46,	loss = 1.764e-03
# Epoch = 47,	loss = 6.407e-03
# Epoch = 48,	loss = 3.008e-03
# Epoch = 49,	loss = 5.379e-03
# Epoch = 50,	loss = 2.555e-03
# Epoch = 51,	loss = 5.042e-03
# Epoch = 52,	loss = 2.724e-03
# Epoch = 53,	loss = 4.027e-03
# Epoch = 54,	loss = 2.524e-03
# Epoch = 55,	loss = 3.482e-03
# Epoch = 56,	loss = 2.015e-03
# Epoch = 57,	loss = 2.272e-03
# Epoch = 58,	loss = 1.876e-03
# Epoch = 59,	loss = 1.863e-03
# Epoch = 60,	loss = 1.544e-03
# Epoch = 61,	loss = 1.726e-03
# Epoch = 62,	loss = 1.610e-03
# Epoch = 63,	loss = 1.598e-03
# Epoch = 64,	loss = 1.641e-03
# Epoch = 65,	loss = 1.767e-03
# Epoch = 66,	loss = 1.499e-03
# Epoch = 67,	loss = 1.555e-03
# Epoch = 68,	loss = 1.332e-03
# Epoch = 69,	loss = 1.273e-03
# Epoch = 70,	loss = 1.056e-03
# Epoch = 71,	loss = 1.183e-03
# Epoch = 72,	loss = 9.974e-04
# Epoch = 73,	loss = 1.055e-03
# Epoch = 74,	loss = 1.002e-03
# Epoch = 75,	loss = 1.095e-03
# Epoch = 76,	loss = 9.885e-04
# Epoch = 77,	loss = 1.092e-03
# Epoch = 78,	loss = 9.805e-04
# Epoch = 79,	loss = 9.983e-04
# Epoch = 80,	loss = 8.812e-04
# Epoch = 81,	loss = 9.468e-04
# Epoch = 82,	loss = 8.012e-04
# Epoch = 83,	loss = 8.878e-04
# Epoch = 84,	loss = 7.927e-04
# Epoch = 85,	loss = 8.570e-04
# Epoch = 86,	loss = 7.934e-04
# Epoch = 87,	loss = 8.516e-04
# Epoch = 88,	loss = 8.146e-04
# Epoch = 89,	loss = 8.069e-04
# Epoch = 90,	loss = 8.237e-04
# Epoch = 91,	loss = 7.651e-04
# Epoch = 92,	loss = 8.013e-04
# Epoch = 93,	loss = 7.588e-04
# Epoch = 94,	loss = 7.722e-04
# Epoch = 95,	loss = 7.601e-04
# Epoch = 96,	loss = 7.532e-04
# Epoch = 97,	loss = 7.655e-04
# Epoch = 98,	loss = 7.443e-04
# Epoch = 99,	loss = 7.647e-04
# Epoch = 100,	loss = 7.457e-04
# Epoch = 101,	loss = 7.460e-04
# Epoch = 102,	loss = 7.523e-04
# Epoch = 103,	loss = 7.335e-04
# Epoch = 104,	loss = 7.456e-04
# Epoch = 105,	loss = 7.357e-04
# Epoch = 106,	loss = 7.295e-04
# Epoch = 107,	loss = 7.371e-04
# Epoch = 108,	loss = 7.253e-04
# Epoch = 109,	loss = 7.292e-04
# Epoch = 110,	loss = 7.298e-04
# Epoch = 111,	loss = 7.219e-04
# Epoch = 112,	loss = 7.277e-04
# Epoch = 113,	loss = 7.241e-04
# Epoch = 114,	loss = 7.204e-04
# Epoch = 115,	loss = 7.239e-04
# Epoch = 116,	loss = 7.180e-04
# Epoch = 117,	loss = 7.166e-04
# Epoch = 118,	loss = 7.183e-04
# Epoch = 119,	loss = 7.134e-04
# Epoch = 120,	loss = 7.139e-04
# Epoch = 121,	loss = 7.145e-04
# Epoch = 122,	loss = 7.111e-04
# Epoch = 123,	loss = 7.121e-04
# Epoch = 197,	loss = 6.766e-04
# Epoch = 198,	loss = 6.763e-04
# Epoch = 199,	loss = 6.761e-04
# Epoch = 200,	loss = 6.759e-04
# Epoch = 201,	loss = 6.757e-04
# Epoch = 202,	loss = 6.755e-04
# Epoch = 203,	loss = 6.752e-04
# Epoch = 204,	loss = 6.751e-04
# Epoch = 205,	loss = 6.749e-04
# Epoch = 206,	loss = 6.747e-04
# Epoch = 207,	loss = 6.745e-04
# Epoch = 208,	loss = 6.745e-04
# Epoch = 209,	loss = 6.746e-04
# Epoch = 210,	loss = 6.751e-04
# Epoch = 211,	loss = 6.763e-04
# Epoch = 212,	loss = 6.793e-04
# Epoch = 213,	loss = 6.862e-04
# Epoch = 214,	loss = 7.031e-04
# Epoch = 215,	loss = 7.439e-04
# Epoch = 216,	loss = 8.502e-04
# Epoch = 217,	loss = 1.109e-03
# Epoch = 218,	loss = 1.823e-03
# Epoch = 219,	loss = 3.336e-03
# Epoch = 220,	loss = 7.267e-03
# Epoch = 221,	loss = 1.020e-02
# Epoch = 222,	loss = 1.245e-02
# Epoch = 223,	loss = 2.720e-03
# Epoch = 224,	loss = 2.595e-03
# Epoch = 225,	loss = 6.720e-03
# Epoch = 226,	loss = 1.073e-03
# Epoch = 227,	loss = 4.690e-03
# Epoch = 228,	loss = 2.774e-03
# Epoch = 229,	loss = 2.587e-03
# Epoch = 230,	loss = 3.157e-03
# Epoch = 231,	loss = 1.495e-03
# Epoch = 232,	loss = 3.003e-03
# Epoch = 233,	loss = 1.221e-03
# Epoch = 234,	loss = 2.817e-03
# Epoch = 235,	loss = 1.016e-03
# Epoch = 236,	loss = 2.435e-03
# Epoch = 237,	loss = 9.518e-04
# Epoch = 238,	loss = 2.137e-03
# Epoch = 239,	loss = 8.855e-04
# Epoch = 240,	loss = 1.796e-03
# Epoch = 241,	loss = 8.474e-04
# Epoch = 242,	loss = 1.599e-03
# Epoch = 243,	loss = 8.372e-04
# Epoch = 244,	loss = 1.398e-03
# Epoch = 245,	loss = 8.054e-04
# Epoch = 246,	loss = 1.249e-03
# Epoch = 247,	loss = 7.989e-04
# Epoch = 248,	loss = 1.103e-03
# Epoch = 249,	loss = 8.002e-04
# Epoch = 250,	loss = 9.856e-04
# Epoch = 251,	loss = 8.296e-04
# Epoch = 252,	loss = 8.825e-04
# Epoch = 253,	loss = 8.524e-04
# Epoch = 254,	loss = 8.029e-04
# Epoch = 255,	loss = 8.744e-04
# Epoch = 256,	loss = 7.583e-04
# Epoch = 257,	loss = 8.762e-04
# Epoch = 258,	loss = 7.242e-04
# Epoch = 259,	loss = 8.502e-04
# Epoch = 260,	loss = 7.068e-04
# Epoch = 261,	loss = 8.184e-04
# Epoch = 262,	loss = 7.102e-04
# Epoch = 263,	loss = 7.828e-04
# Epoch = 264,	loss = 7.234e-04
# Epoch = 265,	loss = 7.486e-04
# Epoch = 266,	loss = 7.342e-04
# Epoch = 267,	loss = 7.172e-04
# Epoch = 268,	loss = 7.373e-04
# Epoch = 269,	loss = 6.980e-04
# Epoch = 635,	loss = 6.580e-04
# Epoch = 636,	loss = 6.575e-04
# Epoch = 637,	loss = 6.570e-04
# Epoch = 638,	loss = 6.571e-04
# Epoch = 639,	loss = 6.574e-04
# Epoch = 640,	loss = 6.572e-04
# Epoch = 641,	loss = 6.568e-04
# Epoch = 642,	loss = 6.567e-04
# Epoch = 643,	loss = 6.569e-04
# Epoch = 644,	loss = 6.569e-04
# Epoch = 645,	loss = 6.566e-04
# Epoch = 646,	loss = 6.565e-04
# Epoch = 647,	loss = 6.566e-04
# Epoch = 648,	loss = 6.566e-04
# Epoch = 649,	loss = 6.564e-04
# Epoch = 650,	loss = 6.564e-04
# Epoch = 651,	loss = 6.564e-04
# Epoch = 652,	loss = 6.564e-04
# Epoch = 653,	loss = 6.563e-04
# Epoch = 654,	loss = 6.563e-04
# Epoch = 655,	loss = 6.563e-04
# Epoch = 656,	loss = 6.563e-04
# Epoch = 657,	loss = 6.563e-04
# Epoch = 658,	loss = 6.563e-04
# Epoch = 659,	loss = 6.563e-04
# Epoch = 660,	loss = 6.563e-04
# Epoch = 661,	loss = 6.563e-04
# Epoch = 662,	loss = 6.563e-04
# Epoch = 663,	loss = 6.563e-04
# Epoch = 664,	loss = 6.563e-04
# Epoch = 665,	loss = 6.563e-04
# Epoch = 666,	loss = 6.563e-04
# Epoch = 667,	loss = 6.563e-04
# Epoch = 668,	loss = 6.563e-04
# Epoch = 669,	loss = 6.563e-04
# Epoch = 670,	loss = 6.563e-04
# Epoch = 671,	loss = 6.563e-04
# Epoch = 672,	loss = 6.563e-04
# Epoch = 673,	loss = 6.563e-04
# Epoch = 674,	loss = 6.563e-04
# Epoch = 675,	loss = 6.563e-04
# Epoch = 676,	loss = 6.563e-04
# Epoch = 677,	loss = 6.563e-04
# Epoch = 678,	loss = 6.563e-04
# Epoch = 679,	loss = 6.563e-04
# Epoch = 680,	loss = 6.563e-04
# Epoch = 681,	loss = 6.563e-04
# Epoch = 682,	loss = 6.563e-04
# Epoch = 683,	loss = 6.563e-04
# Epoch = 684,	loss = 6.563e-04
# Epoch = 685,	loss = 6.563e-04
# Epoch = 686,	loss = 6.563e-04
# Epoch = 687,	loss = 6.563e-04
# Epoch = 688,	loss = 6.563e-04
# Epoch = 689,	loss = 6.563e-04
# Epoch = 690,	loss = 6.563e-04
# Epoch = 691,	loss = 6.563e-04
# Epoch = 692,	loss = 6.563e-04
# Epoch = 693,	loss = 6.563e-04
# Epoch = 694,	loss = 6.563e-04
# Epoch = 695,	loss = 6.563e-04
# Epoch = 696,	loss = 6.563e-04
# Epoch = 697,	loss = 6.563e-04
# Epoch = 698,	loss = 6.563e-04
# Epoch = 699,	loss = 6.563e-04
# CPU times: user 7.28 s, sys: 1.94 s, total: 9.22 s
# Wall time: 5.24 s

# %% [markdown]
# <a id="transferred"></a>
# #### Transferred Learning

# %%
# Loading the saved weights
with open('/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Model Weights/Jax_script_1_trained_weights.pkl', 'rb') as f:
    trans_params = pickle.load(f)

# %%
# defines an adaptive learning rate that changes at specified epochs
#lr = optax.piecewise_constant_schedule(9e-3,{650:7e-3,7500:7e-3})

# Utilises the adam optimiser
#optimizer = optax.adam(lr)

# Updates the parameters
opt_state = optimizer.init(trans_params)

# %%
@jax.jit    # Just-in-Time (JIT) decorator to accelerate computation
def update(opt_state,trans_params,X_starf, T0t, px0t, pz0t, vt):
    # Function to update the parameters for each gradient descent
    
    # calculates the gradients of loss_fun
    grads=jax.grad(loss_fun,0)(trans_params,X_starf, T0t, px0t, pz0t, vt)

    # Update trans_params
    updates, opt_state = optimizer.update(grads, opt_state)
    
    # Applies the updated trans_params
    trans_params = optax.apply_updates(trans_params, updates)

    return opt_state,trans_params

# %%
# %%time
epochs = 400 
trans_loss_value = [] # List to hold the values of the combines loss
trans_loss_pde = []   # List to hold the values of the PDE loss
trans_loss_tau = []   # # List to hold the values of the tau loss

for epoch in range(epochs):  # For loop to iterate over the stipulates epochs
    opt_state, trans_params = update(opt_state,trans_params, X_starf,T0f, px0f, pz0f, velmodelf)

    # print loss and epoch info
    if epoch%(1) ==0:
        loss_pp = loss_fun(trans_params,X_starf,T0f, px0f, pz0f, velmodelf) # Computes the total loss
        trans_loss_value.append(loss_pp)                                    # Appends the total loss value to the declared list
        print(f'Epoch = {epoch},\tloss = {loss_pp:.3e}')              # Prints the total loss values for each epoch

        #Individual losses
        trans_loss_pde.append(pde_loss(trans_params,X_starf, T0f, px0f, pz0f, velmodelf)) # Computes and appends the PDE loss
        trans_loss_tau.append(tau_loss(trans_params,X_starf))                       # Computes and appends the tau loss
# Out:
# Epoch = 0,	loss = 2.233e-01
# Epoch = 1,	loss = 5.716e-02
# Epoch = 2,	loss = 9.847e-02
# Epoch = 3,	loss = 5.623e-02
# Epoch = 4,	loss = 4.129e-02
# Epoch = 5,	loss = 7.291e-02
# Epoch = 6,	loss = 7.537e-02
# Epoch = 7,	loss = 4.875e-02
# Epoch = 8,	loss = 2.924e-02
# Epoch = 9,	loss = 3.666e-02
# Epoch = 10,	loss = 4.041e-02
# Epoch = 11,	loss = 1.761e-02
# Epoch = 12,	loss = 6.835e-03
# Epoch = 13,	loss = 2.808e-02
# Epoch = 14,	loss = 2.381e-02
# Epoch = 15,	loss = 1.001e-02
# Epoch = 16,	loss = 1.575e-02
# Epoch = 17,	loss = 1.466e-02
# Epoch = 18,	loss = 9.686e-03
# Epoch = 19,	loss = 1.240e-02
# Epoch = 20,	loss = 1.504e-02
# Epoch = 21,	loss = 1.191e-02
# Epoch = 22,	loss = 6.717e-03
# Epoch = 23,	loss = 7.749e-03
# Epoch = 24,	loss = 1.033e-02
# Epoch = 25,	loss = 5.572e-03
# Epoch = 26,	loss = 2.490e-03
# Epoch = 27,	loss = 5.950e-03
# Epoch = 28,	loss = 7.800e-03
# Epoch = 29,	loss = 4.634e-03
# Epoch = 30,	loss = 3.006e-03
# Epoch = 31,	loss = 5.044e-03
# Epoch = 32,	loss = 4.732e-03
# Epoch = 33,	loss = 3.064e-03
# Epoch = 34,	loss = 3.349e-03
# Epoch = 35,	loss = 3.464e-03
# Epoch = 36,	loss = 2.907e-03
# Epoch = 37,	loss = 2.956e-03
# Epoch = 38,	loss = 2.963e-03
# Epoch = 39,	loss = 2.323e-03
# Epoch = 40,	loss = 2.358e-03
# Epoch = 41,	loss = 2.790e-03
# Epoch = 42,	loss = 1.987e-03
# Epoch = 43,	loss = 1.418e-03
# Epoch = 44,	loss = 2.207e-03
# Epoch = 45,	loss = 2.108e-03
# Epoch = 46,	loss = 1.319e-03
# Epoch = 47,	loss = 1.669e-03
# Epoch = 48,	loss = 1.842e-03
# Epoch = 49,	loss = 1.293e-03
# Epoch = 50,	loss = 1.306e-03
# Epoch = 51,	loss = 1.478e-03
# Epoch = 52,	loss = 1.302e-03
# Epoch = 53,	loss = 1.274e-03
# Epoch = 54,	loss = 1.241e-03
# Epoch = 55,	loss = 1.176e-03
# Epoch = 56,	loss = 1.254e-03
# Epoch = 57,	loss = 1.082e-03
# Epoch = 58,	loss = 1.000e-03
# Epoch = 59,	loss = 1.151e-03
# Epoch = 60,	loss = 1.010e-03
# Epoch = 61,	loss = 9.295e-04
# Epoch = 62,	loss = 1.091e-03
# Epoch = 63,	loss = 9.783e-04
# Epoch = 64,	loss = 9.086e-04
# Epoch = 65,	loss = 9.824e-04
# Epoch = 66,	loss = 9.198e-04
# Epoch = 67,	loss = 8.977e-04
# Epoch = 68,	loss = 9.047e-04
# Epoch = 69,	loss = 8.786e-04
# Epoch = 70,	loss = 8.898e-04
# Epoch = 71,	loss = 8.478e-04
# Epoch = 72,	loss = 8.540e-04
# Epoch = 73,	loss = 8.706e-04
# Epoch = 74,	loss = 8.133e-04
# Epoch = 75,	loss = 8.389e-04
# Epoch = 76,	loss = 8.417e-04
# Epoch = 77,	loss = 8.017e-04
# Epoch = 78,	loss = 8.251e-04
# Epoch = 79,	loss = 8.096e-04
# Epoch = 80,	loss = 7.954e-04
# Epoch = 81,	loss = 8.018e-04
# Epoch = 82,	loss = 7.937e-04
# Epoch = 83,	loss = 7.948e-04
# Epoch = 84,	loss = 7.828e-04
# Epoch = 85,	loss = 7.867e-04
# Epoch = 86,	loss = 7.814e-04
# Epoch = 87,	loss = 7.699e-04
# Epoch = 88,	loss = 7.802e-04
# Epoch = 89,	loss = 7.676e-04
# Epoch = 90,	loss = 7.670e-04
# Epoch = 91,	loss = 7.702e-04
# Epoch = 92,	loss = 7.612e-04
# Epoch = 93,	loss = 7.629e-04
# Epoch = 94,	loss = 7.590e-04
# Epoch = 95,	loss = 7.578e-04
# Epoch = 96,	loss = 7.547e-04
# Epoch = 97,	loss = 7.545e-04
# Epoch = 98,	loss = 7.528e-04
# Epoch = 99,	loss = 7.483e-04
# Epoch = 100,	loss = 7.507e-04
# Epoch = 101,	loss = 7.460e-04
# Epoch = 102,	loss = 7.460e-04
# Epoch = 103,	loss = 7.452e-04
# Epoch = 104,	loss = 7.422e-04
# Epoch = 105,	loss = 7.422e-04
# Epoch = 106,	loss = 7.402e-04
# Epoch = 107,	loss = 7.392e-04
# CPU times: user 4.73 s, sys: 149 ms, total: 4.88 s
# Wall time: 2.79 s

# %% [markdown]
# <a id="loss"></a>
# #### Loss Curve

# %%
# Plotting the Loss Curve
plt.semilogy(loss_value, label="New Learning",linewidth=2)                # Plots the New learning Loss
plt.semilogy(trans_loss_value, label="Transferred Learning", linewidth=2) # Plots the transferred learning Loss

plt.title("TL Velocity Model Loss", fontsize=14)   # Sets the title of the figure

plt.xlabel("Epochs ", fontsize=15)              # Sets the x-axis label of the figure
plt.ylabel("Loss", fontsize=15,)                # Sets the y-axis label of the figure

plt.grid(color = 'black', linestyle = '--', linewidth = 0.5) # Sets the grid of the figure

plt.legend(loc="upper right")   # Sets the legend of the figure

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/TL Model Loss.pdf", format="pdf", bbox_inches="tight")

plt.show() # Displays the figure

# %% [markdown]
# <a id="tau_pred"></a>
# #### Tau Prediction

# %%
# Predicts tau output
tau_pred = tau(params,X_star[0].reshape(-1,1),X_star[1].reshape(-1,1))

# Predicts tau output
trans_tau_pred = tau(trans_params,X_star[0].reshape(-1,1),X_star[1].reshape(-1,1))

# %%
# Tau new and tau transferred difference plot

plt.style.use('default')         # Sets the default style for the plot

plt.figure(figsize=(4,4))        # Creates a new figure with a size of 4x4 inches

plt.title("TL Model Difference Plot (Tau)", fontsize=14)    # Sets the title of the figure

ax = plt.gca()                   # Gets the current axes instance
im = ax.imshow(jnp.abs(tau_pred.reshape(301,301)-trans_tau_pred.reshape(301,301)), extent=[x_min,x_max,z_max,z_min], aspect=1, cmap="jet")   # Plots the velocity model velmodel as an image on the current axes (ax)

ax.plot(sx,sz,'k*',markersize=8) # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14)     # Sets the label for the x-axis
plt.xticks(fontsize=10)          # Sets the font size for the x-axis tick labels

plt.ylabel('Depth (km)', fontsize=14)      # Sets the label for the y-axis
plt.yticks(fontsize=10)          # Sets the font size for the y-axis tick labels

ax.xaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the major tick locator for the x-axis to have ticks at intervals of 0.5.
ax.yaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the major tick locator for the y-axis to have ticks at intervals of 0.5.

divider = make_axes_locatable(ax)         # Creates a divider to make room for the colorbar
cax = divider.append_axes("right", size="6%", pad=0.15) # Appends an axes on the right side of the plot to accommodate the colorbar

cbar = plt.colorbar(im, cax=cax) # Adds a colorbar to the plot using the image im and the colorbar axes cax

cbar.set_label('seconds',size=10)   # Sets the label for the colorbar.
cbar.ax.tick_params(labelsize=10)        # Sets the font size of the colorbar tick labels.

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/TL Model Difference Plot (Tau).pdf", format= "pdf",bbox_inches="tight")  # Saves the image as a pdf file at the specified file directory

plt.show()   # Displays the defined image

# %%
# Traveltime contour plots

plt.figure(figsize=(5,5)) # Creates a new figure with a size of 5x5 inches

ax = plt.gca()      # Gets the current axes instance

plt.title("TL Model Contour Plot (Tau)", fontsize=14)    # Sets the title of the figure

im1 = ax.contour(tau_pred.reshape(301,301), 6, extent=[x_min,x_max,z_min,z_max], colors='b') # Plots the contour of tau_pred as an image
im2 = ax.contour(trans_tau_pred.reshape(301,301), 6, extent=[x_min,x_max,z_min,z_max], colors='r',linestyles = 'dashed')   # Plots the contour of tau_data as an image

ax.plot(sx,sz,'k*',markersize=8) # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14)   # Sets the x-axis label
plt.ylabel('Depth (km)', fontsize=14)    # Sets the y-axis label

ax.tick_params(axis='both', which='major', labelsize=8)
plt.gca().invert_yaxis()
h1,_ = im1.legend_elements()     # Sets im1 legend
h2,_ = im2.legend_elements()     # Sets im1 legend

ax.legend([h1[0], h2[0]], ['New Learning Tau', 'Transferred Learning Tau'],fontsize=12,)  # Sets the combined legend

ax.xaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the x-axis
ax.yaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the y-axis

plt.xticks(fontsize=10)   # Sets the x-axis ticks
plt.yticks(fontsize=10)   # Sets the y-axis ticks

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/TL Model Contour Plot (Tau).pdf", format="pdf", bbox_inches="tight")

plt.show() # Displays the

# %% [markdown]
# <a id="t_pred"></a>
# #### T Prediction

# %%
# Computes T predicted using tau predicted
T_pred = tau_pred *T0.reshape(-1,1)
T_pred.shape
# Out:
# (90601, 1)

# %%
# T predicted and T analytical difference plot

plt.style.use('default')         # Sets the default style for the plot

plt.figure(figsize=(4,4))        # Creates a new figure with a size of 4x4 inches

plt.title("TL Model Difference Plot (T_1)", fontsize=14)    # Sets the title of the figure

ax = plt.gca()                   # Gets the current axes instance

im = ax.imshow(jnp.abs(T_pred.reshape(301,301)-T_data.reshape(301,301)), extent=[x_min,x_max,z_max,z_min], aspect=1, cmap="jet")# Plots the velocity model velmodel as an image on the current axes (ax)

ax.plot(sx,sz,'k*',markersize=8) # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14)     # Sets the label for the x-axis
plt.xticks(fontsize=10)          # Sets the font size for the x-axis tick labels

plt.ylabel('Depth (km)', fontsize=14)      # Sets the label for the y-axis
plt.yticks(fontsize=10)          # Sets the font size for the y-axis tick labels

ax.xaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the major tick locator for the x-axis to have ticks at intervals of 0.5.
ax.yaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the major tick locator for the y-axis to have ticks at intervals of 0.5.

divider = make_axes_locatable(ax)         # Creates a divider to make room for the colorbar
cax = divider.append_axes("right", size="6%", pad=0.15) # Appends an axes on the right side of the plot to accommodate the colorbar

cbar = plt.colorbar(im, cax=cax) # Adds a colorbar to the plot using the image im and the colorbar axes cax

cbar.set_label('seconds',size=10)   # Sets the label for the colorbar.
cbar.ax.tick_params(labelsize=10)        # Sets the font size of the colorbar tick labels.

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/TL Model Difference Plot (T_1).pdf", format= "pdf",bbox_inches="tight")  # Saves the image as a pdf file at the specified file directory

plt.show()   # Displays the defined image

# %%
# Load fast sweeping traveltims for comparison

T_fsm = jnp.load("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/inputs/vofxz/traveltimes/Tcomp.npy")

# %%
# T predicted and T analytical difference plot

plt.style.use('default')         # Sets the default style for the plot

plt.figure(figsize=(4,4))        # Creates a new figure with a size of 4x4 inches

plt.title("TL Model Difference Plot (T_2)", fontsize=14)    # Sets the title of the figure

ax = plt.gca()                   # Gets the current axes instance

im = ax.imshow(jnp.abs(T_fsm.reshape(301,301)-T_data.reshape(301,301)), extent=[x_min,x_max,z_max,z_min], aspect=1, cmap="jet")# Plots the velocity model velmodel as an image on the current axes (ax)

ax.plot(sx,sz,'k*',markersize=8) # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14)     # Sets the label for the x-axis
plt.xticks(fontsize=10)          # Sets the font size for the x-axis tick labels

plt.ylabel('Depth (km)', fontsize=14)      # Sets the label for the y-axis
plt.yticks(fontsize=10)          # Sets the font size for the y-axis tick labels

ax.xaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the major tick locator for the x-axis to have ticks at intervals of 0.5.
ax.yaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the major tick locator for the y-axis to have ticks at intervals of 0.5.

divider = make_axes_locatable(ax)         # Creates a divider to make room for the colorbar
cax = divider.append_axes("right", size="6%", pad=0.15) # Appends an axes on the right side of the plot to accommodate the colorbar

cbar = plt.colorbar(im, cax=cax) # Adds a colorbar to the plot using the image im and the colorbar axes cax

cbar.set_label('seconds',size=10)   # Sets the label for the colorbar.
cbar.ax.tick_params(labelsize=10)        # Sets the font size of the colorbar tick labels.

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/TL Model Difference Plot (T_2).pdf", format= "pdf",bbox_inches="tight")  # Saves the image as a pdf file at the specified file directory

plt.show()   # Displays the defined image

# %%
# Traveltime contour plots

plt.figure(figsize=(5,5)) # Creates a new figure with a size of 5x5 inches

ax = plt.gca()      # Gets the current axes instance

plt.title("TL Model Contour Plot (T)", fontsize=14)    # Sets the title of the figure

# Plots the contours of the difference T values as an image
im1 = ax.contour(T_data.reshape(301,301), 6, extent=[x_min,x_max,z_min,z_max], colors='r')
im2 = ax.contour(T_pred.reshape(301,301), 6, extent=[x_min,x_max,z_min,z_max], colors='b',linestyles = 'dashed')
im3 = ax.contour(T_fsm.reshape(301,301), 6, extent=[x_min,x_max,z_min,z_max], colors='k',linestyles = 'dotted')


ax.plot(sx,sz,'k*',markersize=8) # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14)   # Sets the x-axis label
plt.ylabel('Depth (km)', fontsize=14)    # Sets the y-axis label

ax.tick_params(axis='both', which='major', labelsize=8)
plt.gca().invert_yaxis()

# Sets im1 legend
h1,_ = im1.legend_elements()
h2,_ = im2.legend_elements()
h3,_ = im3.legend_elements()

ax.legend([h1[0], h2[0], h3[0]], ['Analytical', 'PINN', 'Fast sweeping'],fontsize=12)  # Sets the combined legend

ax.xaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the x-axis
ax.yaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the y-axis

plt.xticks(fontsize=10)   # Sets the x-axis ticks
plt.yticks(fontsize=10)   # Sets the y-axis ticks

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/TL Model Contour Plot (T).pdf", format="pdf", bbox_inches="tight")

plt.show()

# %% [markdown]
# <a id="accuracy"></a>
# #### Rapid Accuracy Assessment

# %%
# Determining the accuracy of the model by quantifying the difference between T_pred and T_data using Vector Norm
print(jnp.linalg.norm(T_pred-T_data.reshape(-1,1))/jnp.linalg.norm(T_data))
print(jnp.linalg.norm(T_pred-T_data.reshape(-1,1)))
# Out:
# 0.000483813
# 0.1480891
