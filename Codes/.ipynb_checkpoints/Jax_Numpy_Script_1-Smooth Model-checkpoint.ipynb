# %% [markdown]
# ## Smooth Velocity Model

# %% [markdown]
# #### Table of Contents
# <ul>
# <li><a href="#lib">Necessary Libraries<a/></li>
# <li><a href="#gpu">GPU Setting & Code Reproducibility<a/></li>
# <li><a href="#model">Smooth Velocity Model<a/></li>
# <li><a href="#analytical">Analytical Solution<a/></li>
# <li><a href="#test">Testing Data<a/></li>
# <li><a href="#train">Training Data<a/></li>
# <li><a href="#sids">Source Location ID<a/></li>
# <li><a href="#archi">Network Architecture & Random Initialisation<a/></li>
# <li><a href="#tau">Neural Network<a/></li>
# <li><a href="#pde">Eikonal PDE Loss<a/></li>
# <li><a href="#other">Other Losses<a/></li>
# <li><a href="#comnbine">Combined Loss Function<a/></li>
# <li><a href="#training">Model Training<a/></li>
# <li><a href="#tau_pred">Tau Prediction<a/></li>
# <li><a href="#t_pred">T Prediction<a/></li>
# <li><a href="#accuracy">Rapid Accuracy Assessment<a/></li>

# %% [markdown]
# <a id="lib"></a>
# #### Necessary Libraries

# %%
# Jax Libraries
import jax
import jax.numpy as jnp
from jax import grad, jit, random
import optax
import pickle
from jax.lib import xla_bridge

# Data Visualisation Libraries
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import timeit

# Operating System and gpu
import os 
import subprocess

# %% [markdown]
# <a id="gpu"></a>
# #### GPU Setting & Code Reproducibility

# %%
# Displays if the notebook currently has access to a gpu
print(f"This Notebook is currently running on a: {(xla_bridge.get_backend().platform)}")

# Assigns a specific GPU to be used
GPU = 0
os.environ['CUDA_VISIBLE_DEVICES'] = 'GPU'

# Displays the GPU details used for the notebook execution
output = subprocess.check_output(['nvidia-smi', '-L']).decode('utf-8')
gpu_info = output.strip().split('\n')
print(gpu_info[GPU])

# Defines a random key to be employed using seed 0
random_key = random.PRNGKey(0)
# Out:
# This Notebook is currently running on a: gpu
# GPU 0: NVIDIA RTX A5000 (UUID: GPU-8b9362c6-1305-75bd-e211-a767d8b39a65)

# %% [markdown]
# <a id="model"></a>
# #### Smooth Velocity Model

# %%
# Velocity at origin
v0 = 2 

# Vertical axis
z_grad = 0.5; z_min = 0.; z_max = 2; z_delta = 0.02

# Horizontal axis
x_grad = 0.0; x_min = 0.0; x_max = 2; x_delta = 0.02

# Point-source location
sz = 1.0; sx = 1.0;

# Number of training points
training_points = 2500

# %%
# Generating the vertical and horizontal values of our model
z = jnp.arange(z_min,z_max+z_delta,z_delta)
x = jnp.arange(x_min,x_max+x_delta,x_delta)

# %%
Z,X = jnp.meshgrid(z,x,indexing='ij')

# %%
# Preparing velocity model
vs = v0 + z_grad*sz + x_grad*sx # Velocity at source location
velmodel = vs + z_grad*(Z-sz) + x_grad*(X-sx);

# %%
# Model with the source location

plt.style.use('default')         # Sets the default style for the plot

plt.figure(figsize=(4,4))        # Creates a new figure with a size of 4x4 inches

plt.title("Smooth Velocity Model")    # Sets the title of the figure

ax = plt.gca()                   # Gets the current axes instance.
im = ax.imshow(velmodel, extent=[x_min,x_max,z_max,z_min], aspect=1, cmap="jet") # Plots the velocity model velmodel as an image on the current axes (ax)

ax.plot(sx,sz,'k*',markersize=8) # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14)     # Sets the label for the x-axis
plt.xticks(fontsize=10)          # Sets the font size for the x-axis tick labels

plt.ylabel('Depth (km)', fontsize=14)      # Sets the label for the y-axis
plt.yticks(fontsize=10)          # Sets the font size for the y-axis tick labels

ax.xaxis.set_major_locator(plt.MultipleLocator(0.5))   # Sets the major tick locator for the x-axis to have ticks at intervals of 0.5.
ax.yaxis.set_major_locator(plt.MultipleLocator(0.5))   # Sets the major tick locator for the y-axis to have ticks at intervals of 0.5.

divider = make_axes_locatable(ax)         # Creates a divider to make room for the colorbar
cax = divider.append_axes("right", size="6%", pad=0.15) # Appends an axes on the right side of the plot to accommodate the colorbar

cbar = plt.colorbar(im, cax=cax) # Adds a colorbar to the plot using the image im and the colorbar axes cax

cbar.set_label('km/s',size=10)   # Sets the label for the colorbar.
cbar.ax.tick_params(labelsize=10)        # Sets the font size of the colorbar tick labels.

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/Smooth Velocity Model.pdf", format= "pdf",bbox_inches="tight")  # Saves the image as a pdf file at the specified file directory

plt.show()   # Displays the defined image

# %% [markdown]
# <a id="analytical"></a>
# #### Analytical Solution

# %%
# Traveltime solution

if z_grad==0 and x_grad==0: 
  # Homogeneous velocity model
  T_data = jnp.sqrt((Z-sz)**2 + (X-sx)**2)/v0;
else: 
  # Velocity gradient model
  T_data = jnp.arccosh(1.0+0.5*(1.0/velmodel)*(1/vs)*(z_grad**2 + x_grad**2)*((X-sx)**2 + (Z-sz)**2))/jnp.sqrt(z_grad**2 + x_grad**2)

# %% [markdown]
# <a id="test"></a>
# #### Testing Data

# %%
# Grid points for testing 
X_star = [Z.reshape(-1,1), X.reshape(-1,1)]

# %%
# Analytical Parameters for testing
vel = velmodel[int(round(sz/z_delta)),int(round(sx/x_delta))] # Velocity at the source location

T0 = jnp.sqrt((Z-sz)**2 + (X-sx)**2)/vel; #  Calculates the travel time T0 for each point in the grid

px0 = jnp.where(T0 != 0, jnp.divide(X - sx, T0 * vel**2), 0)  # Calculates the x-component of the vector 

pz0 = jnp.where(T0 != 0, jnp.divide(Z - sz, T0 * vel**2), 0)  # Calculates the y-component of the vector

# %% [markdown]
# <a id="train"></a>
# #### Training Data

# %%
# Saves 2500 randomly selected points
selected_points = random.choice(random_key, jnp.arange(Z.size), shape=(training_points,), replace=False)

# %%
# Z and X Values for training
Zf = Z.reshape(-1,1)[selected_points] # selects the 2500 points from Zf
Zf = jnp.append(Zf,sz)                # Appends the source location to the selected points for Zf
Xf = X.reshape(-1,1)[selected_points] # selects the 2500 points from Xf
Xf = jnp.append(Xf,sx)                # Appends the source location to the selected points for Xf

# %%
# Grid points for training
X_starf = [Zf.reshape(-1,1), Xf.reshape(-1,1)]

# %%
# Preparing Training data
velmodelf = velmodel.reshape(-1,1)[selected_points]; velmodelf = jnp.append(velmodelf,vs)   # selects the 2500 points from velmodel and appends the velocity at source location
px0f = px0.reshape(-1,1)[selected_points]; px0f = jnp.append(px0f,0.)    # selects the 2500 points from px0 and appends the value at source location
pz0f = pz0.reshape(-1,1)[selected_points]; pz0f = jnp.append(pz0f,0.)    # selects the 2500 points from pz0 and appends the value at source location
T0f = T0.reshape(-1,1)[selected_points]; T0f = jnp.append(T0f,0.)        # selects the 2500 points from T0 and appends the value at source location

# %% [markdown]
# <a id="sids"></a>
# #### Source Location ID

# %%
# Tolerance values for the x and z coordinates
TOLX = 1e-6
TOLZ = 1e-6

sids,_= jnp.where(jnp.logical_and(jnp.abs(X_starf[0]-sz)<TOLZ , jnp.abs(X_starf[1]-sx)<TOLX))   # Computes the source location ID using the established tolerance values

print(sids)
print(sids.shape)
print(X_starf[0][sids,0])
print(X_starf[1][sids,0])
# Out:
# [2500]
# (1,)
# [1.]
# [1.]

# %% [markdown]
# <a id="archi"></a>
# #### Network Architecture & Random Initialisation

# %%
# Architecture of the neural network model
layers = [2,20,20,20,20,20,20,20,20,20,20,1]

# %%
# Function to randomly initialise the network parameters using Xavier iniatialisation
def init_params(layers):

  keys = jax.random.split(jax.random.PRNGKey(0),len(layers)-1)
  params = list()      # Defines an empty list to store the parameters

  for key,n_in,n_out in zip(keys,layers[:-1],layers[1:]):   # For loop iterates over the keys, number of input neurons (n_in), and number of output neurons 
    lb = -(1 / jnp.sqrt(n_in)) # lower bound
    ub = (1 / jnp.sqrt(n_in)) # upper bound
    W = lb + (ub-lb) * jax.random.uniform(key,shape=(n_in,n_out))  # Initialises the weight matrix
    B = jax.random.uniform(key,shape=(n_out,))             # Initialises the bias vector 
    params.append({'W':W,'B':B})                           # Adds a dictionary containing the weight matrix W and bias vector B to the params list
  return params        # Returns the initialised parameters

# %%
# Initialises the parameters of the neural network based on the specified layer architecture.
params = init_params(layers)

# %% [markdown]
# <a id="tau"></a>
# #### Neural Network

# %%
# Function tau to computes the output of the neural network 
def tau(params,zt,xt):

  X = jnp.concatenate([zt,xt],axis=1)

  *hidden,last = params
  for layer in hidden:

    X = jax.nn.tanh(X@layer['W']+layer['B']) # Applying the hyperbolic tangent (tanh) activation function

  return X@last['W'] + last['B']

# %% [markdown]
# <a id="pde"></a>
# #### Eikonal PDE Loss

# %%
@jax.jit   # Just-in-Time (JIT) decorator to accelerate computation
def pde_loss(params,X_starf,T0t,px0t,pz0t,vt):
    
    # Reshapes all input parameters
    zt = X_starf[0].reshape(-1, 1)
    xt = X_starf[1].reshape(-1, 1)
    T0t = T0t.reshape(-1, 1)
    px0t = px0t.reshape(-1, 1)
    pz0t = pz0t.reshape(-1, 1)
    vt = vt.reshape(-1, 1)
    
    # Computes the output of the neural network
    tau_output = tau(params,zt,xt) 
    
    # Computes the gradient
    dtau_dz = jax.grad(lambda zt,xt: jnp.sum(tau(params, zt,xt)), argnums=0)(zt,xt)  # Gradient of the tau function with respect to zt
    dtau_dx = jax.grad(lambda zt,xt: jnp.sum(tau(params, zt,xt)), argnums=1)(zt,xt)  # # Gradient of the tau function with respect to xt

    # Computes the combined term
    term1 = T0t * dtau_dz + tau_output * pz0t
    term2 = T0t * dtau_dx + tau_output * px0t
    
    # Computes the PDE loss value using MSE function 
    loss_pde = MSE(0,(jnp.square(term1) + jnp.square(term2) - 1.0 / (vt ** 2))) 
    
    return loss_pde

# %% [markdown]
# <a id="other"></a>
# #### Other Losses

# %%
@jax.jit    # Just-in-Time (JIT) decorator to accelerate computation
def MSE(true_tau,pred_tau):
    # Function to compute mean squared error (MSE)
    
    return jnp.mean((true_tau-pred_tau)**2)  # Computes and returns the MSE between true and pred

# %%
@jax.jit   # Just-in-Time (JIT) decorator to accelerate computation
def tau_loss(params,X_starf):
    # Function to compute tau loss
    
    # # Reshapes all input parameters
    zt = X_starf[0].reshape(-1, 1)
    xt = X_starf[1].reshape(-1, 1)
    
    # Computes the output of the neural network
    tau_output = tau(params,zt,xt)  
    
    # Computes the tau loss value using MSE function
    tau_loss = MSE(jnp.ones(sids.shape), tau_output[sids])
    
    
    return tau_loss

# %% [markdown]
# <a id="combine"></a>
# #### Combined Loss Function

# %%
@jax.jit    # Just-in-Time (JIT) decorator to accelerate computation
def loss_fun(params,X_starf, T0t, px0t, pz0t, vt):
    # Function to compute the combined loss from tau and PDE
    
    loss_tau = tau_loss(params,X_starf) # Obtains the tau loss value from tau loss function
    loss_pde = pde_loss(params,X_starf, T0t, px0t, pz0t, vt) # Obtains the PDE loss value from PDE loss function
    
    return loss_pde + loss_tau # Computes and returns the sum of the boths losses

# %% [markdown]
# <a id="training"></a>
# #### Model Training

# %%
# defines an adaptive learning rate that changes at specified epochs
lr = optax.piecewise_constant_schedule(1e-2,{500:2.9e-3})

# Utilises the adam optimiser
optimizer = optax.adam(lr)

# Updates the parameters
opt_state = optimizer.init(params)

# %%
@jax.jit    # Just-in-Time (JIT) decorator to accelerate computation
def update(opt_state,params,X_starf, T0t, px0t, pz0t, vt):
    # Function to update the parameters for each gradient descent
    
    # calculates the gradients of loss_fun
    grads=jax.grad(loss_fun,0)(params,X_starf, T0t, px0t, pz0t, vt)

    # Update params
    updates, opt_state = optimizer.update(grads, opt_state)
    
    # Applies the updated params
    params = optax.apply_updates(params, updates)

    return opt_state,params

# %%
# %%time
epochs = 10000 
loss_value = [] # List to hold the values of the combines loss
loss_pde = []   # List to hold the values of the PDE loss
loss_tau = []   # # List to hold the values of the tau loss

for epoch in range(epochs):  # For loop to iterate over the stipulates epochs
    opt_state, params = update(opt_state,params, X_starf,T0f, px0f, pz0f, velmodelf)

    # print loss and epoch info
    if epoch%(1) ==0:
        loss_pp = loss_fun(params,X_starf,T0f, px0f, pz0f, velmodelf) # Computes the total loss
        loss_value.append(loss_pp)                                    # Appends the total loss value to the declared list
        print(f'Epoch = {epoch},\tloss = {loss_pp:.3e}')              # Prints the total loss values for each epoch

        #Individual losses
        loss_pde.append(pde_loss(params,X_starf, T0f, px0f, pz0f, velmodelf)) # Computes and appends the PDE loss
        loss_tau.append(tau_loss(params,X_starf))                       # Computes and appends the tau loss

# saving the final trained weights
with open('/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Model Weights/Jax_script_1_trained_weights.pkl', 'wb') as f:
    pickle.dump(params, f)
# Out:
# Epoch = 0,	loss = 4.201e-02
# Epoch = 1,	loss = 4.302e-02
# Epoch = 2,	loss = 4.768e-03
# Epoch = 3,	loss = 1.052e-02
# Epoch = 4,	loss = 2.598e-02
# Epoch = 5,	loss = 1.786e-02
# Epoch = 6,	loss = 4.237e-03
# Epoch = 7,	loss = 2.739e-03
# Epoch = 8,	loss = 1.006e-02
# Epoch = 9,	loss = 1.309e-02
# Epoch = 10,	loss = 8.469e-03
# Epoch = 11,	loss = 2.837e-03
# Epoch = 12,	loss = 1.980e-03
# Epoch = 13,	loss = 5.166e-03
# Epoch = 14,	loss = 7.609e-03
# Epoch = 15,	loss = 6.517e-03
# Epoch = 16,	loss = 3.460e-03
# Epoch = 17,	loss = 1.676e-03
# Epoch = 18,	loss = 2.513e-03
# Epoch = 19,	loss = 4.348e-03
# Epoch = 20,	loss = 4.791e-03
# Epoch = 21,	loss = 3.470e-03
# Epoch = 22,	loss = 1.973e-03
# Epoch = 23,	loss = 1.719e-03
# Epoch = 24,	loss = 2.574e-03
# Epoch = 25,	loss = 3.355e-03
# Epoch = 26,	loss = 3.211e-03
# Epoch = 27,	loss = 2.367e-03
# Epoch = 28,	loss = 1.702e-03
# Epoch = 29,	loss = 1.777e-03
# Epoch = 30,	loss = 2.324e-03
# Epoch = 31,	loss = 2.639e-03
# Epoch = 32,	loss = 2.384e-03
# Epoch = 33,	loss = 1.874e-03
# Epoch = 34,	loss = 1.640e-03
# Epoch = 35,	loss = 1.833e-03
# Epoch = 36,	loss = 2.138e-03
# Epoch = 37,	loss = 2.180e-03
# Epoch = 38,	loss = 1.931e-03
# Epoch = 39,	loss = 1.679e-03
# Epoch = 40,	loss = 1.670e-03
# Epoch = 41,	loss = 1.850e-03
# Epoch = 42,	loss = 1.967e-03
# Epoch = 43,	loss = 1.883e-03
# Epoch = 44,	loss = 1.709e-03
# Epoch = 45,	loss = 1.641e-03
# Epoch = 46,	loss = 1.721e-03
# Epoch = 47,	loss = 1.820e-03
# Epoch = 48,	loss = 1.809e-03
# Epoch = 49,	loss = 1.709e-03
# Epoch = 50,	loss = 1.641e-03
# Epoch = 51,	loss = 1.670e-03
# Epoch = 52,	loss = 1.737e-03
# Epoch = 53,	loss = 1.747e-03
# Epoch = 54,	loss = 1.692e-03
# Epoch = 55,	loss = 1.643e-03
# Epoch = 56,	loss = 1.653e-03
# Epoch = 57,	loss = 1.694e-03
# Epoch = 58,	loss = 1.705e-03
# Epoch = 59,	loss = 1.673e-03
# Epoch = 60,	loss = 1.642e-03
# Epoch = 61,	loss = 1.646e-03
# Epoch = 62,	loss = 1.671e-03
# Epoch = 63,	loss = 1.678e-03
# Epoch = 64,	loss = 1.658e-03
# Epoch = 65,	loss = 1.640e-03
# Epoch = 66,	loss = 1.644e-03
# Epoch = 67,	loss = 1.659e-03
# Epoch = 68,	loss = 1.661e-03
# Epoch = 69,	loss = 1.648e-03
# Epoch = 70,	loss = 1.637e-03
# Epoch = 71,	loss = 1.642e-03
# Epoch = 72,	loss = 1.651e-03
# Epoch = 73,	loss = 1.650e-03
# Epoch = 74,	loss = 1.640e-03
# Epoch = 75,	loss = 1.636e-03
# Epoch = 76,	loss = 1.640e-03
# Epoch = 77,	loss = 1.644e-03
# Epoch = 78,	loss = 1.641e-03
# Epoch = 79,	loss = 1.635e-03
# Epoch = 80,	loss = 1.634e-03
# Epoch = 81,	loss = 1.637e-03
# Epoch = 82,	loss = 1.637e-03
# Epoch = 83,	loss = 1.634e-03
# Epoch = 84,	loss = 1.630e-03
# Epoch = 85,	loss = 1.630e-03
# Epoch = 86,	loss = 1.631e-03
# Epoch = 87,	loss = 1.629e-03
# Epoch = 88,	loss = 1.625e-03
# Epoch = 89,	loss = 1.622e-03
# Epoch = 90,	loss = 1.621e-03
# Epoch = 91,	loss = 1.619e-03
# Epoch = 92,	loss = 1.615e-03
# Epoch = 93,	loss = 1.610e-03
# Epoch = 94,	loss = 1.605e-03
# Epoch = 95,	loss = 1.601e-03
# Epoch = 96,	loss = 1.594e-03
# Epoch = 97,	loss = 1.585e-03
# Epoch = 98,	loss = 1.575e-03
# Epoch = 99,	loss = 1.564e-03
# Epoch = 100,	loss = 1.550e-03
# Epoch = 101,	loss = 1.531e-03
# Epoch = 102,	loss = 1.508e-03
# Epoch = 103,	loss = 1.480e-03
# Epoch = 104,	loss = 1.445e-03
# Epoch = 105,	loss = 1.399e-03
# Epoch = 106,	loss = 1.340e-03
# Epoch = 107,	loss = 1.266e-03
# Epoch = 108,	loss = 1.175e-03
# Epoch = 109,	loss = 1.072e-03
# Epoch = 110,	loss = 9.722e-04
# Epoch = 111,	loss = 9.091e-04
# Epoch = 112,	loss = 9.058e-04
# Epoch = 113,	loss = 9.190e-04
# Epoch = 114,	loss = 8.659e-04
# Epoch = 115,	loss = 7.586e-04
# Epoch = 116,	loss = 6.565e-04
# Epoch = 117,	loss = 5.913e-04
# Epoch = 118,	loss = 5.633e-04
# Epoch = 119,	loss = 5.343e-04
# Epoch = 120,	loss = 5.050e-04
# Epoch = 121,	loss = 4.559e-04
# Epoch = 122,	loss = 4.267e-04
# Epoch = 123,	loss = 8.122e-04
# Epoch = 124,	loss = 7.233e-04
# Epoch = 125,	loss = 5.651e-04
# Epoch = 126,	loss = 3.152e-04
# Epoch = 127,	loss = 6.288e-04
# Epoch = 128,	loss = 2.850e-04
# Epoch = 129,	loss = 5.324e-04
# Epoch = 130,	loss = 2.858e-04
# Epoch = 131,	loss = 4.854e-04
# Epoch = 132,	loss = 2.390e-04
# Epoch = 133,	loss = 3.746e-04
# Epoch = 134,	loss = 2.130e-04
# Epoch = 135,	loss = 2.263e-04
# Epoch = 136,	loss = 3.544e-04
# Epoch = 137,	loss = 1.463e-04
# Epoch = 138,	loss = 1.406e-04
# Epoch = 139,	loss = 3.330e-04
# Epoch = 140,	loss = 3.290e-04
# Epoch = 141,	loss = 1.927e-04
# Epoch = 142,	loss = 6.486e-05
# Epoch = 143,	loss = 1.494e-04
# Epoch = 144,	loss = 2.453e-04
# Epoch = 145,	loss = 1.222e-04
# Epoch = 146,	loss = 3.614e-05
# Epoch = 147,	loss = 1.110e-04
# Epoch = 148,	loss = 1.400e-04
# Epoch = 149,	loss = 5.919e-05
# Epoch = 150,	loss = 4.065e-05
# Epoch = 151,	loss = 9.744e-05
# Epoch = 152,	loss = 7.079e-05
# Epoch = 153,	loss = 2.783e-05
# Epoch = 154,	loss = 6.644e-05
# Epoch = 155,	loss = 6.734e-05
# Epoch = 156,	loss = 2.334e-05
# Epoch = 157,	loss = 3.872e-05
# Epoch = 158,	loss = 6.274e-05
# Epoch = 159,	loss = 3.526e-05
# Epoch = 160,	loss = 2.181e-05
# Epoch = 161,	loss = 4.451e-05
# Epoch = 162,	loss = 4.290e-05
# Epoch = 163,	loss = 2.123e-05
# Epoch = 164,	loss = 2.765e-05
# Epoch = 165,	loss = 3.771e-05
# Epoch = 166,	loss = 2.350e-05
# Epoch = 167,	loss = 2.027e-05
# Epoch = 168,	loss = 3.085e-05
# Epoch = 169,	loss = 2.489e-05
# Epoch = 170,	loss = 1.854e-05
# Epoch = 171,	loss = 2.613e-05
# Epoch = 172,	loss = 2.526e-05
# Epoch = 173,	loss = 1.801e-05
# Epoch = 174,	loss = 2.149e-05
# Epoch = 175,	loss = 2.381e-05
# Epoch = 176,	loss = 1.823e-05
# Epoch = 177,	loss = 1.813e-05
# Epoch = 178,	loss = 2.171e-05
# Epoch = 179,	loss = 1.925e-05
# Epoch = 180,	loss = 1.635e-05
# Epoch = 181,	loss = 1.853e-05
# Epoch = 182,	loss = 1.968e-05
# Epoch = 183,	loss = 1.694e-05
# Epoch = 184,	loss = 1.560e-05
# Epoch = 185,	loss = 1.724e-05
# Epoch = 186,	loss = 1.758e-05
# Epoch = 187,	loss = 1.566e-05
# Epoch = 188,	loss = 1.491e-05
# Epoch = 189,	loss = 1.601e-05
# Epoch = 190,	loss = 1.636e-05
# Epoch = 191,	loss = 1.517e-05
# Epoch = 192,	loss = 1.425e-05
# Epoch = 193,	loss = 1.463e-05
# Epoch = 194,	loss = 1.524e-05
# Epoch = 195,	loss = 1.501e-05
# Epoch = 196,	loss = 1.416e-05
# Epoch = 197,	loss = 1.360e-05
# Epoch = 198,	loss = 1.372e-05
# Epoch = 199,	loss = 1.414e-05
# Epoch = 200,	loss = 1.433e-05
# Epoch = 201,	loss = 1.412e-05
# Epoch = 202,	loss = 1.365e-05
# Epoch = 203,	loss = 1.320e-05
# Epoch = 204,	loss = 1.292e-05
# Epoch = 205,	loss = 1.286e-05
# Epoch = 206,	loss = 1.295e-05
# Epoch = 207,	loss = 1.312e-05
# Epoch = 208,	loss = 1.331e-05
# Epoch = 209,	loss = 1.350e-05
# Epoch = 210,	loss = 1.375e-05
# Epoch = 211,	loss = 1.413e-05
# Epoch = 212,	loss = 1.482e-05
# Epoch = 213,	loss = 1.612e-05
# Epoch = 214,	loss = 1.874e-05
# Epoch = 215,	loss = 2.399e-05
# Epoch = 216,	loss = 3.512e-05
# Epoch = 217,	loss = 5.777e-05
# Epoch = 218,	loss = 1.041e-04
# Epoch = 219,	loss = 1.784e-04
# Epoch = 220,	loss = 2.644e-04
# Epoch = 221,	loss = 2.501e-04
# Epoch = 222,	loss = 1.026e-04
# Epoch = 223,	loss = 2.052e-05
# Epoch = 224,	loss = 1.066e-04
# Epoch = 225,	loss = 1.112e-04
# Epoch = 226,	loss = 2.195e-05
# Epoch = 227,	loss = 6.123e-05
# Epoch = 228,	loss = 8.199e-05
# Epoch = 229,	loss = 1.856e-05
# Epoch = 230,	loss = 4.930e-05
# Epoch = 231,	loss = 5.805e-05
# Epoch = 232,	loss = 1.800e-05
# Epoch = 233,	loss = 4.883e-05
# Epoch = 234,	loss = 3.982e-05
# Epoch = 235,	loss = 1.968e-05
# Epoch = 236,	loss = 4.424e-05
# Epoch = 237,	loss = 2.539e-05
# Epoch = 238,	loss = 2.321e-05
# Epoch = 239,	loss = 3.565e-05
# Epoch = 240,	loss = 1.744e-05
# Epoch = 241,	loss = 2.710e-05
# Epoch = 242,	loss = 2.640e-05
# Epoch = 243,	loss = 1.695e-05
# Epoch = 244,	loss = 2.728e-05
# Epoch = 245,	loss = 1.902e-05
# Epoch = 246,	loss = 1.797e-05
# Epoch = 247,	loss = 2.375e-05
# Epoch = 248,	loss = 1.562e-05
# Epoch = 249,	loss = 1.819e-05
# Epoch = 250,	loss = 2.078e-05
# Epoch = 251,	loss = 1.465e-05
# Epoch = 252,	loss = 1.742e-05
# Epoch = 253,	loss = 1.874e-05
# Epoch = 254,	loss = 1.404e-05
# Epoch = 255,	loss = 1.588e-05
# Epoch = 256,	loss = 1.709e-05
# Epoch = 257,	loss = 1.361e-05
# Epoch = 258,	loss = 1.449e-05
# Epoch = 259,	loss = 1.604e-05
# Epoch = 260,	loss = 1.358e-05
# Epoch = 261,	loss = 1.326e-05
# Epoch = 262,	loss = 1.486e-05
# Epoch = 263,	loss = 1.364e-05
# Epoch = 264,	loss = 1.238e-05
# Epoch = 265,	loss = 1.348e-05
# Epoch = 266,	loss = 1.369e-05
# Epoch = 267,	loss = 1.236e-05
# Epoch = 268,	loss = 1.221e-05
# Epoch = 269,	loss = 1.305e-05
# Epoch = 270,	loss = 1.279e-05
# Epoch = 271,	loss = 1.186e-05
# Epoch = 272,	loss = 1.185e-05
# Epoch = 273,	loss = 1.240e-05
# Epoch = 274,	loss = 1.225e-05
# Epoch = 275,	loss = 1.163e-05
# Epoch = 276,	loss = 1.152e-05
# Epoch = 277,	loss = 1.188e-05
# Epoch = 278,	loss = 1.195e-05
# Epoch = 279,	loss = 1.157e-05
# Epoch = 280,	loss = 1.127e-05
# Epoch = 281,	loss = 1.137e-05
# Epoch = 282,	loss = 1.158e-05
# Epoch = 283,	loss = 1.157e-05
# Epoch = 284,	loss = 1.133e-05
# Epoch = 285,	loss = 1.113e-05
# Epoch = 286,	loss = 1.114e-05
# Epoch = 287,	loss = 1.126e-05
# Epoch = 288,	loss = 1.132e-05
# Epoch = 289,	loss = 1.125e-05
# Epoch = 290,	loss = 1.110e-05
# Epoch = 291,	loss = 1.099e-05
# Epoch = 292,	loss = 1.097e-05
# Epoch = 293,	loss = 1.102e-05
# Epoch = 294,	loss = 1.108e-05
# Epoch = 295,	loss = 1.109e-05
# Epoch = 296,	loss = 1.106e-05
# Epoch = 297,	loss = 1.099e-05
# Epoch = 298,	loss = 1.092e-05
# Epoch = 299,	loss = 1.087e-05
# Epoch = 300,	loss = 1.084e-05
# Epoch = 301,	loss = 1.083e-05
# Epoch = 302,	loss = 1.084e-05
# Epoch = 303,	loss = 1.086e-05
# Epoch = 304,	loss = 1.088e-05
# Epoch = 305,	loss = 1.091e-05
# Epoch = 306,	loss = 1.094e-05
# Epoch = 307,	loss = 1.099e-05
# Epoch = 308,	loss = 1.106e-05
# Epoch = 309,	loss = 1.117e-05
# Epoch = 310,	loss = 1.135e-05
# Epoch = 311,	loss = 1.167e-05
# Epoch = 312,	loss = 1.223e-05
# Epoch = 313,	loss = 1.325e-05
# Epoch = 314,	loss = 1.518e-05
# Epoch = 315,	loss = 1.885e-05
# Epoch = 316,	loss = 2.605e-05
# Epoch = 317,	loss = 3.995e-05
# Epoch = 318,	loss = 6.649e-05
# Epoch = 319,	loss = 1.121e-04
# Epoch = 320,	loss = 1.783e-04
# Epoch = 321,	loss = 2.308e-04
# Epoch = 322,	loss = 2.002e-04
# Epoch = 323,	loss = 8.059e-05
# Epoch = 324,	loss = 1.729e-05
# Epoch = 325,	loss = 8.209e-05
# Epoch = 326,	loss = 1.012e-04
# Epoch = 327,	loss = 2.722e-05
# Epoch = 328,	loss = 2.996e-05
# Epoch = 329,	loss = 7.284e-05
# Epoch = 330,	loss = 3.326e-05
# Epoch = 331,	loss = 2.003e-05
# Epoch = 332,	loss = 5.461e-05
# Epoch = 333,	loss = 2.979e-05
# Epoch = 334,	loss = 1.957e-05
# Epoch = 335,	loss = 4.264e-05
# Epoch = 336,	loss = 2.180e-05
# Epoch = 337,	loss = 2.144e-05
# Epoch = 338,	loss = 3.407e-05
# Epoch = 339,	loss = 1.667e-05
# Epoch = 340,	loss = 2.489e-05
# Epoch = 341,	loss = 2.644e-05
# Epoch = 342,	loss = 1.524e-05
# Epoch = 343,	loss = 2.492e-05
# Epoch = 344,	loss = 1.960e-05
# Epoch = 345,	loss = 1.513e-05
# Epoch = 346,	loss = 2.268e-05
# Epoch = 347,	loss = 1.646e-05
# Epoch = 348,	loss = 1.520e-05
# Epoch = 349,	loss = 2.023e-05
# Epoch = 350,	loss = 1.486e-05
# Epoch = 351,	loss = 1.432e-05
# Epoch = 352,	loss = 1.784e-05
# Epoch = 353,	loss = 1.386e-05
# Epoch = 354,	loss = 1.335e-05
# Epoch = 355,	loss = 1.623e-05
# Epoch = 356,	loss = 1.362e-05
# Epoch = 357,	loss = 1.246e-05
# Epoch = 358,	loss = 1.471e-05
# Epoch = 359,	loss = 1.346e-05
# Epoch = 360,	loss = 1.171e-05
# Epoch = 361,	loss = 1.319e-05
# Epoch = 362,	loss = 1.349e-05
# Epoch = 363,	loss = 1.175e-05
# Epoch = 364,	loss = 1.179e-05
# Epoch = 365,	loss = 1.288e-05
# Epoch = 366,	loss = 1.224e-05
# Epoch = 367,	loss = 1.117e-05
# Epoch = 368,	loss = 1.162e-05
# Epoch = 369,	loss = 1.221e-05
# Epoch = 370,	loss = 1.161e-05
# Epoch = 371,	loss = 1.100e-05
# Epoch = 372,	loss = 1.135e-05
# Epoch = 373,	loss = 1.173e-05
# Epoch = 374,	loss = 1.136e-05
# Epoch = 375,	loss = 1.088e-05
# Epoch = 376,	loss = 1.099e-05
# Epoch = 377,	loss = 1.134e-05
# Epoch = 378,	loss = 1.129e-05
# Epoch = 379,	loss = 1.094e-05
# Epoch = 380,	loss = 1.077e-05
# Epoch = 381,	loss = 1.094e-05
# Epoch = 382,	loss = 1.111e-05
# Epoch = 383,	loss = 1.103e-05
# Epoch = 384,	loss = 1.081e-05
# Epoch = 385,	loss = 1.072e-05
# Epoch = 386,	loss = 1.081e-05
# Epoch = 387,	loss = 1.092e-05
# Epoch = 388,	loss = 1.091e-05
# Epoch = 389,	loss = 1.079e-05
# Epoch = 390,	loss = 1.068e-05
# Epoch = 391,	loss = 1.068e-05
# Epoch = 392,	loss = 1.074e-05
# Epoch = 393,	loss = 1.080e-05
# Epoch = 394,	loss = 1.078e-05
# Epoch = 395,	loss = 1.072e-05
# Epoch = 396,	loss = 1.065e-05
# Epoch = 397,	loss = 1.063e-05
# Epoch = 398,	loss = 1.064e-05
# Epoch = 399,	loss = 1.067e-05
# Epoch = 400,	loss = 1.069e-05
# Epoch = 401,	loss = 1.068e-05
# Epoch = 402,	loss = 1.065e-05
# Epoch = 403,	loss = 1.062e-05
# Epoch = 404,	loss = 1.059e-05
# Epoch = 405,	loss = 1.058e-05
# Epoch = 406,	loss = 1.059e-05
# Epoch = 407,	loss = 1.060e-05
# Epoch = 408,	loss = 1.061e-05
# Epoch = 409,	loss = 1.061e-05
# Epoch = 410,	loss = 1.061e-05
# Epoch = 411,	loss = 1.060e-05
# Epoch = 412,	loss = 1.059e-05
# Epoch = 413,	loss = 1.057e-05
# Epoch = 414,	loss = 1.056e-05
# Epoch = 415,	loss = 1.055e-05
# Epoch = 416,	loss = 1.054e-05
# Epoch = 417,	loss = 1.054e-05
# Epoch = 418,	loss = 1.053e-05
# Epoch = 419,	loss = 1.053e-05
# Epoch = 420,	loss = 1.053e-05
# Epoch = 421,	loss = 1.053e-05
# Epoch = 422,	loss = 1.053e-05
# Epoch = 423,	loss = 1.053e-05
# Epoch = 424,	loss = 1.053e-05
# Epoch = 425,	loss = 1.054e-05
# Epoch = 426,	loss = 1.055e-05
# Epoch = 427,	loss = 1.057e-05
# Epoch = 428,	loss = 1.061e-05
# Epoch = 429,	loss = 1.067e-05
# Epoch = 430,	loss = 1.077e-05
# Epoch = 431,	loss = 1.095e-05
# Epoch = 432,	loss = 1.127e-05
# Epoch = 433,	loss = 1.186e-05
# Epoch = 434,	loss = 1.296e-05
# Epoch = 435,	loss = 1.505e-05
# Epoch = 436,	loss = 1.905e-05
# Epoch = 437,	loss = 2.675e-05
# Epoch = 438,	loss = 4.147e-05
# Epoch = 439,	loss = 6.859e-05
# Epoch = 440,	loss = 1.146e-04
# Epoch = 441,	loss = 1.773e-04
# Epoch = 442,	loss = 2.288e-04
# Epoch = 443,	loss = 1.978e-04
# Epoch = 444,	loss = 8.466e-05
# Epoch = 445,	loss = 1.604e-05
# Epoch = 446,	loss = 7.278e-05
# Epoch = 447,	loss = 1.027e-04
# Epoch = 448,	loss = 3.364e-05
# Epoch = 449,	loss = 2.192e-05
# Epoch = 450,	loss = 6.914e-05
# Epoch = 451,	loss = 4.185e-05
# Epoch = 452,	loss = 1.676e-05
# Epoch = 453,	loss = 4.948e-05
# Epoch = 454,	loss = 3.428e-05
# Epoch = 455,	loss = 1.663e-05
# Epoch = 456,	loss = 3.969e-05
# Epoch = 457,	loss = 2.521e-05
# Epoch = 458,	loss = 1.972e-05
# Epoch = 459,	loss = 3.430e-05
# Epoch = 460,	loss = 1.896e-05
# Epoch = 461,	loss = 2.180e-05
# Epoch = 462,	loss = 2.776e-05
# Epoch = 463,	loss = 1.518e-05
# Epoch = 464,	loss = 2.137e-05
# Epoch = 465,	loss = 2.323e-05
# Epoch = 466,	loss = 1.419e-05
# Epoch = 467,	loss = 1.949e-05
# Epoch = 468,	loss = 2.004e-05
# Epoch = 469,	loss = 1.308e-05
# Epoch = 470,	loss = 1.683e-05
# Epoch = 471,	loss = 1.793e-05
# Epoch = 472,	loss = 1.267e-05
# Epoch = 473,	loss = 1.474e-05
# Epoch = 474,	loss = 1.666e-05
# Epoch = 475,	loss = 1.265e-05
# Epoch = 476,	loss = 1.252e-05
# Epoch = 477,	loss = 1.512e-05
# Epoch = 478,	loss = 1.334e-05
# Epoch = 479,	loss = 1.139e-05
# Epoch = 480,	loss = 1.305e-05
# Epoch = 481,	loss = 1.376e-05
# Epoch = 482,	loss = 1.181e-05
# Epoch = 483,	loss = 1.114e-05
# Epoch = 484,	loss = 1.249e-05
# Epoch = 485,	loss = 1.266e-05
# Epoch = 486,	loss = 1.133e-05
# Epoch = 487,	loss = 1.099e-05
# Epoch = 488,	loss = 1.188e-05
# Epoch = 489,	loss = 1.208e-05
# Epoch = 490,	loss = 1.125e-05
# Epoch = 491,	loss = 1.078e-05
# Epoch = 492,	loss = 1.123e-05
# Epoch = 493,	loss = 1.169e-05
# Epoch = 494,	loss = 1.142e-05
# Epoch = 495,	loss = 1.086e-05
# Epoch = 496,	loss = 1.075e-05
# Epoch = 497,	loss = 1.110e-05
# Epoch = 498,	loss = 1.131e-05
# Epoch = 499,	loss = 1.110e-05
# Epoch = 500,	loss = 1.110e-05
# Epoch = 501,	loss = 1.109e-05
# Epoch = 502,	loss = 1.107e-05
# Epoch = 503,	loss = 1.105e-05
# Epoch = 504,	loss = 1.102e-05
# Epoch = 505,	loss = 1.099e-05
# Epoch = 506,	loss = 1.096e-05
# Epoch = 507,	loss = 1.093e-05
# Epoch = 508,	loss = 1.090e-05
# Epoch = 509,	loss = 1.087e-05
# Epoch = 510,	loss = 1.085e-05
# Epoch = 511,	loss = 1.082e-05
# Epoch = 512,	loss = 1.080e-05
# Epoch = 513,	loss = 1.078e-05
# Epoch = 514,	loss = 1.076e-05
# Epoch = 515,	loss = 1.074e-05
# Epoch = 516,	loss = 1.073e-05
# Epoch = 517,	loss = 1.072e-05
# Epoch = 518,	loss = 1.072e-05
# Epoch = 519,	loss = 1.071e-05
# Epoch = 520,	loss = 1.071e-05
# Epoch = 521,	loss = 1.070e-05
# Epoch = 522,	loss = 1.070e-05
# Epoch = 523,	loss = 1.070e-05
# Epoch = 524,	loss = 1.070e-05
# Epoch = 525,	loss = 1.070e-05
# Epoch = 526,	loss = 1.070e-05
# Epoch = 527,	loss = 1.071e-05
# Epoch = 528,	loss = 1.071e-05
# Epoch = 529,	loss = 1.071e-05
# Epoch = 530,	loss = 1.071e-05
# Epoch = 531,	loss = 1.071e-05
# Epoch = 532,	loss = 1.071e-05
# Epoch = 533,	loss = 1.071e-05
# Epoch = 534,	loss = 1.071e-05
# Epoch = 535,	loss = 1.071e-05
# Epoch = 536,	loss = 1.071e-05
# Epoch = 537,	loss = 1.071e-05
# Epoch = 538,	loss = 1.071e-05
# Epoch = 539,	loss = 1.071e-05
# Epoch = 540,	loss = 1.071e-05
# Epoch = 541,	loss = 1.071e-05
# Epoch = 542,	loss = 1.071e-05
# Epoch = 543,	loss = 1.070e-05
# Epoch = 544,	loss = 1.070e-05
# Epoch = 545,	loss = 1.070e-05
# Epoch = 546,	loss = 1.070e-05
# Epoch = 547,	loss = 1.070e-05
# Epoch = 548,	loss = 1.070e-05
# Epoch = 549,	loss = 1.070e-05
# Epoch = 550,	loss = 1.070e-05
# Epoch = 551,	loss = 1.070e-05
# Epoch = 552,	loss = 1.070e-05
# Epoch = 553,	loss = 1.070e-05
# Epoch = 554,	loss = 1.070e-05
# Epoch = 555,	loss = 1.070e-05
# Epoch = 556,	loss = 1.070e-05
# Epoch = 557,	loss = 1.070e-05
# Epoch = 558,	loss = 1.070e-05
# Epoch = 559,	loss = 1.070e-05
# Epoch = 560,	loss = 1.070e-05
# Epoch = 561,	loss = 1.070e-05
# Epoch = 562,	loss = 1.070e-05
# Epoch = 563,	loss = 1.070e-05
# Epoch = 564,	loss = 1.070e-05
# Epoch = 565,	loss = 1.070e-05
# Epoch = 566,	loss = 1.070e-05
# Epoch = 567,	loss = 1.070e-05
# Epoch = 568,	loss = 1.070e-05
# Epoch = 569,	loss = 1.070e-05
# Epoch = 570,	loss = 1.070e-05
# Epoch = 571,	loss = 1.070e-05
# Epoch = 572,	loss = 1.070e-05
# Epoch = 573,	loss = 1.070e-05
# Epoch = 574,	loss = 1.070e-05
# Epoch = 575,	loss = 1.070e-05
# Epoch = 576,	loss = 1.070e-05
# Epoch = 577,	loss = 1.070e-05
# Epoch = 578,	loss = 1.070e-05
# Epoch = 579,	loss = 1.070e-05
# Epoch = 580,	loss = 1.070e-05
# Epoch = 581,	loss = 1.070e-05
# Epoch = 582,	loss = 1.070e-05
# Epoch = 583,	loss = 1.070e-05
# Epoch = 584,	loss = 1.070e-05
# Epoch = 585,	loss = 1.070e-05
# Epoch = 586,	loss = 1.069e-05
# Epoch = 587,	loss = 1.069e-05
# Epoch = 588,	loss = 1.069e-05
# Epoch = 589,	loss = 1.069e-05
# Epoch = 590,	loss = 1.069e-05
# Epoch = 591,	loss = 1.069e-05
# Epoch = 592,	loss = 1.069e-05
# Epoch = 593,	loss = 1.069e-05
# Epoch = 594,	loss = 1.069e-05
# Epoch = 595,	loss = 1.069e-05
# Epoch = 596,	loss = 1.069e-05
# Epoch = 597,	loss = 1.069e-05
# Epoch = 598,	loss = 1.069e-05
# Epoch = 599,	loss = 1.069e-05
# Epoch = 600,	loss = 1.069e-05
# Epoch = 601,	loss = 1.069e-05
# Epoch = 602,	loss = 1.069e-05
# Epoch = 603,	loss = 1.069e-05
# Epoch = 604,	loss = 1.069e-05
# Epoch = 605,	loss = 1.069e-05
# Epoch = 606,	loss = 1.069e-05
# Epoch = 607,	loss = 1.069e-05
# Epoch = 608,	loss = 1.069e-05
# Epoch = 609,	loss = 1.069e-05
# Epoch = 610,	loss = 1.069e-05
# Epoch = 611,	loss = 1.069e-05
# Epoch = 612,	loss = 1.069e-05
# Epoch = 613,	loss = 1.069e-05
# Epoch = 614,	loss = 1.069e-05
# Epoch = 615,	loss = 1.069e-05
# Epoch = 616,	loss = 1.069e-05
# Epoch = 617,	loss = 1.069e-05
# Epoch = 618,	loss = 1.069e-05
# Epoch = 619,	loss = 1.069e-05
# Epoch = 620,	loss = 1.069e-05
# Epoch = 621,	loss = 1.069e-05
# Epoch = 622,	loss = 1.069e-05
# Epoch = 623,	loss = 1.069e-05
# Epoch = 624,	loss = 1.069e-05
# Epoch = 625,	loss = 1.069e-05
# Epoch = 626,	loss = 1.069e-05
# Epoch = 627,	loss = 1.069e-05
# Epoch = 628,	loss = 1.069e-05
# Epoch = 629,	loss = 1.069e-05
# Epoch = 630,	loss = 1.069e-05
# Epoch = 631,	loss = 1.069e-05
# Epoch = 632,	loss = 1.069e-05
# Epoch = 633,	loss = 1.069e-05
# Epoch = 634,	loss = 1.069e-05
# Epoch = 635,	loss = 1.069e-05
# Epoch = 636,	loss = 1.069e-05
# Epoch = 637,	loss = 1.069e-05
# Epoch = 638,	loss = 1.069e-05
# Epoch = 639,	loss = 1.069e-05
# Epoch = 640,	loss = 1.069e-05
# Epoch = 641,	loss = 1.069e-05
# Epoch = 642,	loss = 1.069e-05
# Epoch = 643,	loss = 1.069e-05
# Epoch = 644,	loss = 1.069e-05
# Epoch = 645,	loss = 1.069e-05
# Epoch = 646,	loss = 1.069e-05
# Epoch = 647,	loss = 1.069e-05
# Epoch = 794,	loss = 1.069e-05
# Epoch = 795,	loss = 1.069e-05
# Epoch = 796,	loss = 1.069e-05
# Epoch = 797,	loss = 1.069e-05
# Epoch = 798,	loss = 1.069e-05
# Epoch = 799,	loss = 1.069e-05
# Epoch = 800,	loss = 1.069e-05
# Epoch = 801,	loss = 1.069e-05
# Epoch = 802,	loss = 1.069e-05
# Epoch = 803,	loss = 1.069e-05
# Epoch = 804,	loss = 1.069e-05
# Epoch = 805,	loss = 1.069e-05
# Epoch = 806,	loss = 1.068e-05
# Epoch = 807,	loss = 1.068e-05
# Epoch = 808,	loss = 1.068e-05
# Epoch = 809,	loss = 1.068e-05
# Epoch = 810,	loss = 1.068e-05
# Epoch = 811,	loss = 1.068e-05
# Epoch = 812,	loss = 1.068e-05
# Epoch = 813,	loss = 1.068e-05
# Epoch = 814,	loss = 1.068e-05
# Epoch = 815,	loss = 1.068e-05
# Epoch = 816,	loss = 1.068e-05
# Epoch = 817,	loss = 1.068e-05
# Epoch = 818,	loss = 1.068e-05
# Epoch = 819,	loss = 1.068e-05
# Epoch = 820,	loss = 1.068e-05
# Epoch = 821,	loss = 1.068e-05
# Epoch = 822,	loss = 1.068e-05
# Epoch = 823,	loss = 1.068e-05
# Epoch = 824,	loss = 1.068e-05
# Epoch = 825,	loss = 1.068e-05
# Epoch = 826,	loss = 1.068e-05
# Epoch = 827,	loss = 1.068e-05
# Epoch = 828,	loss = 1.068e-05
# Epoch = 829,	loss = 1.068e-05
# Epoch = 830,	loss = 1.068e-05
# Epoch = 831,	loss = 1.068e-05
# Epoch = 832,	loss = 1.068e-05
# Epoch = 833,	loss = 1.068e-05
# Epoch = 834,	loss = 1.068e-05
# Epoch = 835,	loss = 1.068e-05
# Epoch = 836,	loss = 1.068e-05
# Epoch = 837,	loss = 1.068e-05
# Epoch = 838,	loss = 1.068e-05
# Epoch = 839,	loss = 1.068e-05
# Epoch = 840,	loss = 1.068e-05
# Epoch = 841,	loss = 1.068e-05
# Epoch = 842,	loss = 1.068e-05
# Epoch = 843,	loss = 1.068e-05
# Epoch = 844,	loss = 1.068e-05
# Epoch = 845,	loss = 1.068e-05
# Epoch = 846,	loss = 1.068e-05
# Epoch = 847,	loss = 1.068e-05
# Epoch = 848,	loss = 1.068e-05
# Epoch = 849,	loss = 1.068e-05
# Epoch = 850,	loss = 1.068e-05
# Epoch = 851,	loss = 1.068e-05
# Epoch = 852,	loss = 1.068e-05
# Epoch = 853,	loss = 1.068e-05
# Epoch = 854,	loss = 1.068e-05
# Epoch = 855,	loss = 1.068e-05
# Epoch = 856,	loss = 1.068e-05
# Epoch = 857,	loss = 1.068e-05
# Epoch = 858,	loss = 1.068e-05
# Epoch = 859,	loss = 1.068e-05
# Epoch = 860,	loss = 1.068e-05
# Epoch = 861,	loss = 1.068e-05
# Epoch = 862,	loss = 1.068e-05
# Epoch = 863,	loss = 1.068e-05
# Epoch = 864,	loss = 1.068e-05
# Epoch = 865,	loss = 1.068e-05
# Epoch = 866,	loss = 1.068e-05
# Epoch = 867,	loss = 1.068e-05
# Epoch = 868,	loss = 1.068e-05
# Epoch = 869,	loss = 1.068e-05
# Epoch = 870,	loss = 1.068e-05
# Epoch = 871,	loss = 1.068e-05
# Epoch = 872,	loss = 1.068e-05
# Epoch = 873,	loss = 1.068e-05
# Epoch = 874,	loss = 1.068e-05
# Epoch = 875,	loss = 1.068e-05
# Epoch = 876,	loss = 1.068e-05
# Epoch = 877,	loss = 1.068e-05
# Epoch = 878,	loss = 1.068e-05
# Epoch = 879,	loss = 1.068e-05
# Epoch = 880,	loss = 1.068e-05
# Epoch = 881,	loss = 1.068e-05
# Epoch = 882,	loss = 1.068e-05
# Epoch = 883,	loss = 1.068e-05
# Epoch = 884,	loss = 1.068e-05
# Epoch = 885,	loss = 1.068e-05
# Epoch = 886,	loss = 1.068e-05
# Epoch = 887,	loss = 1.068e-05
# Epoch = 888,	loss = 1.068e-05
# Epoch = 889,	loss = 1.068e-05
# Epoch = 890,	loss = 1.068e-05
# Epoch = 891,	loss = 1.068e-05
# Epoch = 892,	loss = 1.068e-05
# Epoch = 893,	loss = 1.068e-05
# Epoch = 894,	loss = 1.068e-05
# Epoch = 895,	loss = 1.068e-05
# Epoch = 896,	loss = 1.068e-05
# Epoch = 897,	loss = 1.068e-05
# Epoch = 898,	loss = 1.068e-05
# Epoch = 899,	loss = 1.068e-05
# Epoch = 900,	loss = 1.068e-05
# Epoch = 901,	loss = 1.068e-05
# Epoch = 902,	loss = 1.068e-05
# Epoch = 903,	loss = 1.068e-05
# Epoch = 904,	loss = 1.068e-05
# Epoch = 905,	loss = 1.068e-05
# Epoch = 906,	loss = 1.068e-05
# Epoch = 907,	loss = 1.068e-05
# Epoch = 908,	loss = 1.068e-05
# Epoch = 909,	loss = 1.068e-05
# Epoch = 910,	loss = 1.068e-05
# Epoch = 911,	loss = 1.068e-05
# Epoch = 912,	loss = 1.068e-05
# Epoch = 913,	loss = 1.068e-05
# Epoch = 914,	loss = 1.068e-05
# Epoch = 915,	loss = 1.068e-05
# Epoch = 916,	loss = 1.068e-05
# Epoch = 917,	loss = 1.068e-05
# Epoch = 918,	loss = 1.068e-05
# Epoch = 919,	loss = 1.068e-05
# Epoch = 920,	loss = 1.068e-05
# Epoch = 921,	loss = 1.068e-05
# Epoch = 922,	loss = 1.068e-05
# Epoch = 923,	loss = 1.068e-05
# Epoch = 924,	loss = 1.068e-05
# Epoch = 925,	loss = 1.068e-05
# Epoch = 926,	loss = 1.068e-05
# Epoch = 927,	loss = 1.068e-05
# Epoch = 928,	loss = 1.068e-05
# Epoch = 929,	loss = 1.068e-05
# Epoch = 930,	loss = 1.068e-05
# Epoch = 931,	loss = 1.068e-05
# Epoch = 932,	loss = 1.068e-05
# Epoch = 933,	loss = 1.068e-05
# Epoch = 934,	loss = 1.068e-05
# Epoch = 935,	loss = 1.068e-05
# Epoch = 936,	loss = 1.068e-05
# Epoch = 937,	loss = 1.068e-05
# Epoch = 938,	loss = 1.068e-05
# Epoch = 939,	loss = 1.068e-05
# Epoch = 940,	loss = 1.068e-05
# Epoch = 941,	loss = 1.068e-05
# Epoch = 942,	loss = 1.068e-05
# Epoch = 943,	loss = 1.068e-05
# Epoch = 944,	loss = 1.068e-05
# Epoch = 945,	loss = 1.068e-05
# Epoch = 946,	loss = 1.068e-05
# Epoch = 947,	loss = 1.068e-05
# Epoch = 948,	loss = 1.068e-05
# Epoch = 949,	loss = 1.068e-05
# Epoch = 950,	loss = 1.068e-05
# Epoch = 951,	loss = 1.068e-05
# Epoch = 952,	loss = 1.068e-05
# Epoch = 953,	loss = 1.068e-05
# Epoch = 954,	loss = 1.068e-05
# Epoch = 955,	loss = 1.068e-05
# Epoch = 956,	loss = 1.068e-05
# Epoch = 957,	loss = 1.068e-05
# Epoch = 958,	loss = 1.068e-05
# Epoch = 959,	loss = 1.068e-05
# Epoch = 960,	loss = 1.068e-05
# Epoch = 961,	loss = 1.068e-05
# Epoch = 962,	loss = 1.068e-05
# Epoch = 963,	loss = 1.068e-05
# Epoch = 964,	loss = 1.068e-05
# Epoch = 965,	loss = 1.068e-05
# Epoch = 966,	loss = 1.068e-05
# Epoch = 967,	loss = 1.068e-05
# Epoch = 968,	loss = 1.068e-05
# Epoch = 969,	loss = 1.068e-05
# Epoch = 970,	loss = 1.068e-05
# Epoch = 971,	loss = 1.068e-05
# Epoch = 972,	loss = 1.068e-05
# Epoch = 973,	loss = 1.068e-05
# Epoch = 974,	loss = 1.068e-05
# Epoch = 975,	loss = 1.068e-05
# Epoch = 976,	loss = 1.068e-05
# Epoch = 977,	loss = 1.068e-05
# Epoch = 978,	loss = 1.068e-05
# Epoch = 979,	loss = 1.068e-05
# Epoch = 980,	loss = 1.068e-05
# Epoch = 981,	loss = 1.068e-05
# Epoch = 982,	loss = 1.068e-05
# Epoch = 983,	loss = 1.068e-05
# Epoch = 984,	loss = 1.068e-05
# Epoch = 985,	loss = 1.068e-05
# Epoch = 986,	loss = 1.068e-05
# Epoch = 987,	loss = 1.068e-05
# Epoch = 988,	loss = 1.068e-05
# Epoch = 989,	loss = 1.068e-05
# Epoch = 990,	loss = 1.068e-05
# Epoch = 991,	loss = 1.068e-05
# Epoch = 992,	loss = 1.068e-05
# Epoch = 993,	loss = 1.068e-05
# Epoch = 994,	loss = 1.068e-05
# Epoch = 995,	loss = 1.068e-05
# Epoch = 996,	loss = 1.068e-05
# Epoch = 997,	loss = 1.068e-05
# Epoch = 998,	loss = 1.068e-05
# Epoch = 999,	loss = 1.068e-05
# Epoch = 1000,	loss = 1.068e-05
# Epoch = 1001,	loss = 1.068e-05
# Epoch = 1002,	loss = 1.068e-05
# Epoch = 1003,	loss = 1.068e-05
# Epoch = 1004,	loss = 1.068e-05
# Epoch = 1005,	loss = 1.068e-05
# Epoch = 1006,	loss = 1.068e-05
# Epoch = 1007,	loss = 1.068e-05
# Epoch = 1008,	loss = 1.068e-05
# Epoch = 1009,	loss = 1.068e-05
# Epoch = 1010,	loss = 1.068e-05
# Epoch = 1011,	loss = 1.068e-05
# Epoch = 1012,	loss = 1.068e-05
# Epoch = 1013,	loss = 1.068e-05
# Epoch = 1014,	loss = 1.068e-05
# Epoch = 1015,	loss = 1.068e-05
# Epoch = 1016,	loss = 1.068e-05
# Epoch = 1017,	loss = 1.068e-05
# Epoch = 1018,	loss = 1.068e-05
# Epoch = 1019,	loss = 1.068e-05
# Epoch = 1020,	loss = 1.068e-05
# Epoch = 1021,	loss = 1.068e-05
# Epoch = 1022,	loss = 1.068e-05
# Epoch = 1023,	loss = 1.068e-05
# Epoch = 1024,	loss = 1.068e-05
# Epoch = 1025,	loss = 1.068e-05
# Epoch = 1026,	loss = 1.068e-05
# Epoch = 1027,	loss = 1.068e-05
# Epoch = 1028,	loss = 1.068e-05
# Epoch = 1029,	loss = 1.068e-05
# Epoch = 1030,	loss = 1.068e-05
# Epoch = 1031,	loss = 1.068e-05
# Epoch = 1032,	loss = 1.068e-05
# Epoch = 1033,	loss = 1.068e-05
# Epoch = 1034,	loss = 1.068e-05
# Epoch = 1035,	loss = 1.068e-05
# Epoch = 1036,	loss = 1.068e-05
# Epoch = 1037,	loss = 1.068e-05
# Epoch = 1038,	loss = 1.068e-05
# Epoch = 1039,	loss = 1.068e-05
# Epoch = 1040,	loss = 1.068e-05
# Epoch = 1041,	loss = 1.068e-05
# Epoch = 1042,	loss = 1.068e-05
# Epoch = 1043,	loss = 1.068e-05
# Epoch = 1044,	loss = 1.068e-05
# Epoch = 1045,	loss = 1.068e-05
# Epoch = 1046,	loss = 1.068e-05
# Epoch = 1047,	loss = 1.068e-05
# Epoch = 1048,	loss = 1.068e-05
# Epoch = 1049,	loss = 1.068e-05
# Epoch = 1050,	loss = 1.068e-05
# Epoch = 1051,	loss = 1.068e-05
# Epoch = 1052,	loss = 1.068e-05
# Epoch = 1053,	loss = 1.068e-05
# Epoch = 1054,	loss = 1.068e-05
# Epoch = 1055,	loss = 1.068e-05
# Epoch = 1056,	loss = 1.068e-05
# Epoch = 1057,	loss = 1.068e-05
# Epoch = 1058,	loss = 1.068e-05
# Epoch = 1059,	loss = 1.068e-05
# Epoch = 1060,	loss = 1.068e-05
# Epoch = 1061,	loss = 1.068e-05
# Epoch = 1062,	loss = 1.068e-05
# Epoch = 1063,	loss = 1.068e-05
# Epoch = 1064,	loss = 1.068e-05
# Epoch = 1065,	loss = 1.068e-05
# Epoch = 1066,	loss = 1.068e-05
# Epoch = 1067,	loss = 1.068e-05
# Epoch = 1068,	loss = 1.068e-05
# Epoch = 1069,	loss = 1.068e-05
# Epoch = 1070,	loss = 1.068e-05
# Epoch = 1071,	loss = 1.068e-05
# Epoch = 1072,	loss = 1.068e-05
# Epoch = 1073,	loss = 1.068e-05
# Epoch = 1074,	loss = 1.068e-05
# Epoch = 1075,	loss = 1.068e-05
# Epoch = 1076,	loss = 1.068e-05
# Epoch = 1077,	loss = 1.068e-05
# Epoch = 1078,	loss = 1.068e-05
# Epoch = 1079,	loss = 1.068e-05
# Epoch = 1080,	loss = 1.068e-05
# Epoch = 1081,	loss = 1.068e-05
# Epoch = 1082,	loss = 1.068e-05
# Epoch = 1083,	loss = 1.068e-05
# Epoch = 1084,	loss = 1.068e-05
# Epoch = 1085,	loss = 1.068e-05
# Epoch = 1086,	loss = 1.068e-05
# Epoch = 1087,	loss = 1.068e-05
# Epoch = 1088,	loss = 1.068e-05
# Epoch = 1089,	loss = 1.068e-05
# Epoch = 1090,	loss = 1.068e-05
# Epoch = 1091,	loss = 1.068e-05
# Epoch = 1092,	loss = 1.068e-05
# Epoch = 1093,	loss = 1.068e-05
# Epoch = 1094,	loss = 1.068e-05
# Epoch = 1095,	loss = 1.068e-05
# Epoch = 1096,	loss = 1.067e-05
# Epoch = 1097,	loss = 1.067e-05
# Epoch = 1098,	loss = 1.067e-05
# Epoch = 1099,	loss = 1.067e-05
# Epoch = 1100,	loss = 1.067e-05
# Epoch = 1101,	loss = 1.067e-05
# Epoch = 1102,	loss = 1.067e-05
# Epoch = 1103,	loss = 1.067e-05
# Epoch = 1104,	loss = 1.067e-05
# Epoch = 1105,	loss = 1.067e-05
# Epoch = 1106,	loss = 1.067e-05
# Epoch = 1107,	loss = 1.067e-05
# Epoch = 1108,	loss = 1.067e-05
# Epoch = 1109,	loss = 1.067e-05
# Epoch = 1110,	loss = 1.067e-05
# Epoch = 1111,	loss = 1.067e-05
# Epoch = 1112,	loss = 1.067e-05
# Epoch = 1113,	loss = 1.067e-05
# Epoch = 1114,	loss = 1.067e-05
# Epoch = 1115,	loss = 1.067e-05
# Epoch = 1116,	loss = 1.067e-05
# Epoch = 1117,	loss = 1.067e-05
# Epoch = 1118,	loss = 1.067e-05
# Epoch = 1119,	loss = 1.067e-05
# Epoch = 1120,	loss = 1.067e-05
# Epoch = 1121,	loss = 1.067e-05
# Epoch = 1122,	loss = 1.067e-05
# Epoch = 1123,	loss = 1.067e-05
# Epoch = 1124,	loss = 1.067e-05
# Epoch = 1125,	loss = 1.067e-05
# Epoch = 1126,	loss = 1.067e-05
# Epoch = 1127,	loss = 1.067e-05
# Epoch = 1128,	loss = 1.067e-05
# Epoch = 1129,	loss = 1.067e-05
# Epoch = 1130,	loss = 1.067e-05
# Epoch = 1131,	loss = 1.067e-05
# Epoch = 1132,	loss = 1.067e-05
# Epoch = 1133,	loss = 1.067e-05
# Epoch = 1134,	loss = 1.067e-05
# Epoch = 1135,	loss = 1.067e-05
# Epoch = 1136,	loss = 1.067e-05
# Epoch = 1137,	loss = 1.067e-05
# Epoch = 1138,	loss = 1.067e-05
# Epoch = 1139,	loss = 1.067e-05
# Epoch = 1140,	loss = 1.067e-05
# Epoch = 1141,	loss = 1.067e-05
# Epoch = 1142,	loss = 1.067e-05
# Epoch = 1143,	loss = 1.067e-05
# Epoch = 1144,	loss = 1.067e-05
# Epoch = 1145,	loss = 1.067e-05
# Epoch = 1146,	loss = 1.067e-05
# Epoch = 1147,	loss = 1.067e-05
# Epoch = 1148,	loss = 1.067e-05
# Epoch = 1149,	loss = 1.067e-05
# Epoch = 1150,	loss = 1.067e-05
# Epoch = 1151,	loss = 1.067e-05
# Epoch = 1152,	loss = 1.067e-05
# Epoch = 1153,	loss = 1.067e-05
# Epoch = 1154,	loss = 1.067e-05
# Epoch = 1155,	loss = 1.067e-05
# Epoch = 1156,	loss = 1.067e-05
# Epoch = 1157,	loss = 1.067e-05
# Epoch = 1158,	loss = 1.067e-05
# Epoch = 1159,	loss = 1.067e-05
# Epoch = 1160,	loss = 1.067e-05
# Epoch = 1161,	loss = 1.067e-05
# Epoch = 1162,	loss = 1.067e-05
# Epoch = 1163,	loss = 1.067e-05
# Epoch = 1164,	loss = 1.067e-05
# Epoch = 1165,	loss = 1.067e-05
# Epoch = 1166,	loss = 1.067e-05
# Epoch = 1167,	loss = 1.067e-05
# Epoch = 1168,	loss = 1.067e-05
# Epoch = 1169,	loss = 1.067e-05
# Epoch = 1170,	loss = 1.067e-05
# Epoch = 1171,	loss = 1.067e-05
# Epoch = 1172,	loss = 1.067e-05
# Epoch = 1173,	loss = 1.067e-05
# Epoch = 1174,	loss = 1.067e-05
# Epoch = 1175,	loss = 1.067e-05
# Epoch = 1176,	loss = 1.067e-05
# Epoch = 1177,	loss = 1.067e-05
# Epoch = 1178,	loss = 1.067e-05
# Epoch = 1179,	loss = 1.067e-05
# Epoch = 1180,	loss = 1.067e-05
# Epoch = 1181,	loss = 1.067e-05
# Epoch = 1182,	loss = 1.067e-05
# Epoch = 1183,	loss = 1.067e-05
# Epoch = 1184,	loss = 1.067e-05
# Epoch = 1185,	loss = 1.067e-05
# Epoch = 1186,	loss = 1.067e-05
# Epoch = 1187,	loss = 1.067e-05
# Epoch = 1188,	loss = 1.067e-05
# Epoch = 1189,	loss = 1.067e-05
# Epoch = 1190,	loss = 1.067e-05
# Epoch = 1191,	loss = 1.067e-05
# Epoch = 1192,	loss = 1.067e-05
# Epoch = 1193,	loss = 1.067e-05
# Epoch = 1194,	loss = 1.067e-05
# Epoch = 1195,	loss = 1.067e-05
# Epoch = 1196,	loss = 1.067e-05
# Epoch = 1197,	loss = 1.067e-05
# Epoch = 1198,	loss = 1.067e-05
# Epoch = 1199,	loss = 1.067e-05
# Epoch = 1200,	loss = 1.067e-05
# Epoch = 1201,	loss = 1.067e-05
# Epoch = 1202,	loss = 1.067e-05
# Epoch = 1203,	loss = 1.067e-05
# Epoch = 1204,	loss = 1.067e-05
# Epoch = 1205,	loss = 1.067e-05
# Epoch = 1206,	loss = 1.067e-05
# Epoch = 1207,	loss = 1.067e-05
# Epoch = 1208,	loss = 1.067e-05
# Epoch = 1209,	loss = 1.067e-05
# Epoch = 1210,	loss = 1.067e-05
# Epoch = 1211,	loss = 1.067e-05
# Epoch = 1212,	loss = 1.067e-05
# Epoch = 1213,	loss = 1.067e-05
# Epoch = 1214,	loss = 1.067e-05
# Epoch = 1215,	loss = 1.067e-05
# Epoch = 1216,	loss = 1.067e-05
# Epoch = 1217,	loss = 1.067e-05
# Epoch = 1218,	loss = 1.067e-05
# Epoch = 1219,	loss = 1.067e-05
# Epoch = 1220,	loss = 1.067e-05
# Epoch = 1221,	loss = 1.067e-05
# Epoch = 1222,	loss = 1.067e-05
# Epoch = 1223,	loss = 1.067e-05
# Epoch = 1224,	loss = 1.067e-05
# Epoch = 1225,	loss = 1.067e-05
# Epoch = 1226,	loss = 1.067e-05
# Epoch = 1227,	loss = 1.067e-05
# Epoch = 1228,	loss = 1.067e-05
# Epoch = 1229,	loss = 1.067e-05
# Epoch = 1230,	loss = 1.067e-05
# Epoch = 1231,	loss = 1.067e-05
# Epoch = 1232,	loss = 1.067e-05
# Epoch = 1233,	loss = 1.067e-05
# Epoch = 1234,	loss = 1.067e-05
# Epoch = 1235,	loss = 1.067e-05
# Epoch = 1236,	loss = 1.067e-05
# Epoch = 1237,	loss = 1.067e-05
# Epoch = 1238,	loss = 1.067e-05
# Epoch = 1239,	loss = 1.067e-05
# Epoch = 1240,	loss = 1.067e-05
# Epoch = 1241,	loss = 1.067e-05
# Epoch = 1242,	loss = 1.067e-05
# Epoch = 1243,	loss = 1.067e-05
# Epoch = 1244,	loss = 1.067e-05
# Epoch = 1245,	loss = 1.067e-05
# Epoch = 1246,	loss = 1.067e-05
# Epoch = 1247,	loss = 1.067e-05
# Epoch = 1248,	loss = 1.067e-05
# Epoch = 1249,	loss = 1.067e-05
# Epoch = 1250,	loss = 1.067e-05
# Epoch = 1251,	loss = 1.067e-05
# Epoch = 1252,	loss = 1.067e-05
# Epoch = 1253,	loss = 1.067e-05
# Epoch = 1254,	loss = 1.067e-05
# Epoch = 1255,	loss = 1.067e-05
# Epoch = 1256,	loss = 1.067e-05
# Epoch = 1257,	loss = 1.067e-05
# Epoch = 1258,	loss = 1.067e-05
# Epoch = 1259,	loss = 1.067e-05
# Epoch = 1260,	loss = 1.067e-05
# Epoch = 1261,	loss = 1.067e-05
# Epoch = 1262,	loss = 1.067e-05
# Epoch = 1263,	loss = 1.067e-05
# Epoch = 1264,	loss = 1.067e-05
# Epoch = 1265,	loss = 1.067e-05
# Epoch = 1266,	loss = 1.067e-05
# Epoch = 1267,	loss = 1.067e-05
# Epoch = 1268,	loss = 1.067e-05
# Epoch = 1269,	loss = 1.067e-05
# Epoch = 1270,	loss = 1.067e-05
# Epoch = 1271,	loss = 1.067e-05
# Epoch = 1272,	loss = 1.067e-05
# Epoch = 1273,	loss = 1.067e-05
# Epoch = 1274,	loss = 1.067e-05
# Epoch = 1275,	loss = 1.067e-05
# Epoch = 1276,	loss = 1.067e-05
# Epoch = 1277,	loss = 1.067e-05
# Epoch = 1278,	loss = 1.067e-05
# Epoch = 1279,	loss = 1.067e-05
# Epoch = 1280,	loss = 1.067e-05
# Epoch = 1281,	loss = 1.067e-05
# Epoch = 1282,	loss = 1.067e-05
# Epoch = 1283,	loss = 1.067e-05
# Epoch = 1284,	loss = 1.067e-05
# Epoch = 1285,	loss = 1.067e-05
# Epoch = 1286,	loss = 1.067e-05
# Epoch = 1287,	loss = 1.067e-05
# Epoch = 1288,	loss = 1.067e-05
# Epoch = 1289,	loss = 1.067e-05
# Epoch = 1290,	loss = 1.067e-05
# Epoch = 1291,	loss = 1.067e-05
# Epoch = 1292,	loss = 1.067e-05
# Epoch = 1293,	loss = 1.067e-05
# Epoch = 1294,	loss = 1.067e-05
# Epoch = 1295,	loss = 1.067e-05
# Epoch = 1296,	loss = 1.067e-05
# Epoch = 1297,	loss = 1.067e-05
# Epoch = 1298,	loss = 1.067e-05
# Epoch = 1299,	loss = 1.067e-05
# Epoch = 1300,	loss = 1.067e-05
# Epoch = 1301,	loss = 1.067e-05
# Epoch = 1302,	loss = 1.067e-05
# Epoch = 1303,	loss = 1.067e-05
# Epoch = 1304,	loss = 1.067e-05
# Epoch = 1305,	loss = 1.067e-05
# Epoch = 1306,	loss = 1.067e-05
# Epoch = 1307,	loss = 1.067e-05
# Epoch = 1308,	loss = 1.067e-05
# Epoch = 1309,	loss = 1.067e-05
# Epoch = 1310,	loss = 1.067e-05
# Epoch = 1311,	loss = 1.067e-05
# Epoch = 1312,	loss = 1.067e-05
# Epoch = 1313,	loss = 1.067e-05
# Epoch = 1314,	loss = 1.067e-05
# Epoch = 1315,	loss = 1.067e-05
# Epoch = 1316,	loss = 1.067e-05
# Epoch = 1317,	loss = 1.067e-05
# Epoch = 1318,	loss = 1.067e-05
# Epoch = 1319,	loss = 1.067e-05
# Epoch = 1320,	loss = 1.067e-05
# Epoch = 1321,	loss = 1.067e-05
# Epoch = 1322,	loss = 1.067e-05
# Epoch = 1323,	loss = 1.067e-05
# Epoch = 1324,	loss = 1.067e-05
# Epoch = 1325,	loss = 1.067e-05
# Epoch = 1326,	loss = 1.067e-05
# Epoch = 1327,	loss = 1.067e-05
# Epoch = 1328,	loss = 1.067e-05
# Epoch = 1329,	loss = 1.067e-05
# Epoch = 1330,	loss = 1.067e-05
# Epoch = 1331,	loss = 1.067e-05
# Epoch = 1332,	loss = 1.067e-05
# Epoch = 1333,	loss = 1.067e-05
# Epoch = 1334,	loss = 1.067e-05
# Epoch = 1335,	loss = 1.067e-05
# Epoch = 1336,	loss = 1.067e-05
# Epoch = 1337,	loss = 1.067e-05
# Epoch = 1338,	loss = 1.067e-05
# Epoch = 1339,	loss = 1.067e-05
# Epoch = 1340,	loss = 1.067e-05
# Epoch = 1341,	loss = 1.067e-05
# Epoch = 1342,	loss = 1.067e-05
# Epoch = 1343,	loss = 1.067e-05
# Epoch = 1344,	loss = 1.067e-05
# Epoch = 1345,	loss = 1.067e-05
# Epoch = 1346,	loss = 1.067e-05
# Epoch = 1347,	loss = 1.067e-05
# Epoch = 1348,	loss = 1.067e-05
# Epoch = 1349,	loss = 1.067e-05
# Epoch = 1350,	loss = 1.067e-05
# Epoch = 1351,	loss = 1.067e-05
# Epoch = 1352,	loss = 1.067e-05
# Epoch = 1353,	loss = 1.067e-05
# Epoch = 1354,	loss = 1.067e-05
# Epoch = 1355,	loss = 1.067e-05
# Epoch = 1356,	loss = 1.066e-05
# Epoch = 1357,	loss = 1.066e-05
# Epoch = 1358,	loss = 1.066e-05
# Epoch = 1359,	loss = 1.066e-05
# Epoch = 1360,	loss = 1.066e-05
# Epoch = 1361,	loss = 1.066e-05
# Epoch = 1362,	loss = 1.066e-05
# Epoch = 1363,	loss = 1.066e-05
# Epoch = 1364,	loss = 1.066e-05
# Epoch = 1365,	loss = 1.066e-05
# Epoch = 1366,	loss = 1.066e-05
# Epoch = 1367,	loss = 1.066e-05
# Epoch = 1368,	loss = 1.066e-05
# Epoch = 1369,	loss = 1.066e-05
# Epoch = 1370,	loss = 1.066e-05
# Epoch = 1371,	loss = 1.066e-05
# Epoch = 1372,	loss = 1.066e-05
# Epoch = 1373,	loss = 1.066e-05
# Epoch = 1374,	loss = 1.066e-05
# Epoch = 1375,	loss = 1.066e-05
# Epoch = 1376,	loss = 1.066e-05
# Epoch = 1377,	loss = 1.066e-05
# Epoch = 1378,	loss = 1.066e-05
# Epoch = 1379,	loss = 1.066e-05
# Epoch = 1380,	loss = 1.066e-05
# Epoch = 1381,	loss = 1.066e-05
# Epoch = 1382,	loss = 1.066e-05
# Epoch = 1383,	loss = 1.066e-05
# Epoch = 1384,	loss = 1.066e-05
# Epoch = 1385,	loss = 1.066e-05
# Epoch = 1386,	loss = 1.066e-05
# Epoch = 1387,	loss = 1.066e-05
# Epoch = 1388,	loss = 1.066e-05
# Epoch = 1389,	loss = 1.066e-05
# Epoch = 1390,	loss = 1.066e-05
# Epoch = 1391,	loss = 1.066e-05
# Epoch = 1392,	loss = 1.066e-05
# Epoch = 1393,	loss = 1.066e-05
# Epoch = 1394,	loss = 1.066e-05
# Epoch = 1395,	loss = 1.066e-05
# Epoch = 1396,	loss = 1.066e-05
# Epoch = 1397,	loss = 1.066e-05
# Epoch = 1398,	loss = 1.066e-05
# Epoch = 1399,	loss = 1.066e-05
# Epoch = 1400,	loss = 1.066e-05
# Epoch = 1401,	loss = 1.066e-05
# Epoch = 1402,	loss = 1.066e-05
# Epoch = 1403,	loss = 1.066e-05
# Epoch = 1404,	loss = 1.066e-05
# Epoch = 1405,	loss = 1.066e-05
# Epoch = 1406,	loss = 1.066e-05
# Epoch = 1407,	loss = 1.066e-05
# Epoch = 1408,	loss = 1.066e-05
# Epoch = 1409,	loss = 1.066e-05
# Epoch = 1410,	loss = 1.066e-05
# Epoch = 1411,	loss = 1.066e-05
# Epoch = 1412,	loss = 1.066e-05
# Epoch = 1413,	loss = 1.066e-05
# Epoch = 1414,	loss = 1.066e-05
# Epoch = 1415,	loss = 1.066e-05
# Epoch = 1416,	loss = 1.066e-05
# Epoch = 1417,	loss = 1.066e-05
# Epoch = 1418,	loss = 1.066e-05
# Epoch = 1419,	loss = 1.066e-05
# Epoch = 1420,	loss = 1.066e-05
# Epoch = 1421,	loss = 1.066e-05
# Epoch = 1422,	loss = 1.066e-05
# Epoch = 1423,	loss = 1.066e-05
# Epoch = 1424,	loss = 1.066e-05
# Epoch = 1425,	loss = 1.066e-05
# Epoch = 1426,	loss = 1.066e-05
# Epoch = 1427,	loss = 1.066e-05
# Epoch = 1428,	loss = 1.066e-05
# Epoch = 1429,	loss = 1.066e-05
# Epoch = 1430,	loss = 1.066e-05
# Epoch = 1431,	loss = 1.066e-05
# Epoch = 1432,	loss = 1.066e-05
# Epoch = 1433,	loss = 1.066e-05
# Epoch = 1434,	loss = 1.066e-05
# Epoch = 1435,	loss = 1.066e-05
# Epoch = 1436,	loss = 1.066e-05
# Epoch = 1437,	loss = 1.066e-05
# Epoch = 1438,	loss = 1.066e-05
# Epoch = 1439,	loss = 1.066e-05
# Epoch = 1440,	loss = 1.066e-05
# Epoch = 1441,	loss = 1.066e-05
# Epoch = 1442,	loss = 1.066e-05
# Epoch = 1443,	loss = 1.066e-05
# Epoch = 1444,	loss = 1.066e-05
# Epoch = 1445,	loss = 1.066e-05
# Epoch = 1446,	loss = 1.066e-05
# Epoch = 1447,	loss = 1.066e-05
# Epoch = 1448,	loss = 1.066e-05
# Epoch = 1449,	loss = 1.066e-05
# Epoch = 1450,	loss = 1.066e-05
# Epoch = 1451,	loss = 1.066e-05
# Epoch = 1452,	loss = 1.066e-05
# Epoch = 1453,	loss = 1.066e-05
# Epoch = 1454,	loss = 1.066e-05
# Epoch = 1455,	loss = 1.066e-05
# Epoch = 1456,	loss = 1.066e-05
# Epoch = 1457,	loss = 1.066e-05
# Epoch = 1458,	loss = 1.066e-05
# Epoch = 1459,	loss = 1.066e-05
# Epoch = 1460,	loss = 1.066e-05
# Epoch = 1461,	loss = 1.066e-05
# Epoch = 1462,	loss = 1.066e-05
# Epoch = 1463,	loss = 1.066e-05
# Epoch = 1464,	loss = 1.066e-05
# Epoch = 1465,	loss = 1.066e-05
# Epoch = 1466,	loss = 1.066e-05
# Epoch = 1467,	loss = 1.066e-05
# Epoch = 1468,	loss = 1.066e-05
# Epoch = 1469,	loss = 1.066e-05
# Epoch = 1470,	loss = 1.066e-05
# Epoch = 1471,	loss = 1.066e-05
# Epoch = 1472,	loss = 1.066e-05
# Epoch = 1473,	loss = 1.066e-05
# Epoch = 1474,	loss = 1.066e-05
# Epoch = 1475,	loss = 1.066e-05
# Epoch = 1476,	loss = 1.066e-05
# Epoch = 1477,	loss = 1.066e-05
# Epoch = 1478,	loss = 1.066e-05
# Epoch = 1479,	loss = 1.066e-05
# Epoch = 1480,	loss = 1.066e-05
# Epoch = 1481,	loss = 1.066e-05
# Epoch = 1482,	loss = 1.066e-05
# Epoch = 1483,	loss = 1.066e-05
# Epoch = 1484,	loss = 1.066e-05
# Epoch = 1485,	loss = 1.066e-05
# Epoch = 1486,	loss = 1.066e-05
# Epoch = 1487,	loss = 1.066e-05
# Epoch = 1488,	loss = 1.066e-05
# Epoch = 1489,	loss = 1.066e-05
# Epoch = 1490,	loss = 1.066e-05
# Epoch = 1491,	loss = 1.066e-05
# Epoch = 1492,	loss = 1.066e-05
# Epoch = 1493,	loss = 1.066e-05
# Epoch = 1494,	loss = 1.066e-05
# Epoch = 1495,	loss = 1.066e-05
# Epoch = 1496,	loss = 1.066e-05
# Epoch = 1497,	loss = 1.066e-05
# Epoch = 1498,	loss = 1.066e-05
# Epoch = 1499,	loss = 1.066e-05
# Epoch = 1500,	loss = 1.066e-05
# Epoch = 1501,	loss = 1.066e-05
# Epoch = 1502,	loss = 1.066e-05
# Epoch = 1503,	loss = 1.066e-05
# Epoch = 1504,	loss = 1.066e-05
# Epoch = 1505,	loss = 1.066e-05
# Epoch = 1506,	loss = 1.066e-05
# Epoch = 1507,	loss = 1.066e-05
# Epoch = 1508,	loss = 1.066e-05
# Epoch = 1509,	loss = 1.066e-05
# Epoch = 1510,	loss = 1.066e-05
# Epoch = 1511,	loss = 1.066e-05
# Epoch = 1512,	loss = 1.066e-05
# Epoch = 1513,	loss = 1.066e-05
# Epoch = 1514,	loss = 1.066e-05
# Epoch = 1515,	loss = 1.066e-05
# Epoch = 1516,	loss = 1.066e-05
# Epoch = 1517,	loss = 1.066e-05
# Epoch = 1518,	loss = 1.066e-05
# Epoch = 1519,	loss = 1.066e-05
# Epoch = 1520,	loss = 1.066e-05
# Epoch = 1521,	loss = 1.066e-05
# Epoch = 1522,	loss = 1.066e-05
# Epoch = 1523,	loss = 1.066e-05
# Epoch = 1524,	loss = 1.066e-05
# Epoch = 1525,	loss = 1.066e-05
# Epoch = 1526,	loss = 1.066e-05
# Epoch = 1527,	loss = 1.066e-05
# Epoch = 1528,	loss = 1.066e-05
# Epoch = 1529,	loss = 1.066e-05
# Epoch = 1530,	loss = 1.066e-05
# Epoch = 1531,	loss = 1.066e-05
# Epoch = 1532,	loss = 1.066e-05
# Epoch = 1533,	loss = 1.066e-05
# Epoch = 1534,	loss = 1.066e-05
# Epoch = 1535,	loss = 1.066e-05
# Epoch = 1536,	loss = 1.066e-05
# Epoch = 1537,	loss = 1.066e-05
# Epoch = 1538,	loss = 1.066e-05
# Epoch = 1539,	loss = 1.066e-05
# Epoch = 1540,	loss = 1.066e-05
# Epoch = 1541,	loss = 1.066e-05
# Epoch = 1542,	loss = 1.066e-05
# Epoch = 1543,	loss = 1.066e-05
# Epoch = 1544,	loss = 1.066e-05
# Epoch = 1545,	loss = 1.066e-05
# Epoch = 1546,	loss = 1.066e-05
# Epoch = 1547,	loss = 1.066e-05
# Epoch = 1548,	loss = 1.066e-05
# Epoch = 1549,	loss = 1.066e-05
# Epoch = 1550,	loss = 1.066e-05
# Epoch = 1551,	loss = 1.066e-05
# Epoch = 1552,	loss = 1.066e-05
# Epoch = 1553,	loss = 1.066e-05
# Epoch = 1554,	loss = 1.066e-05
# Epoch = 1555,	loss = 1.066e-05
# Epoch = 1556,	loss = 1.066e-05
# Epoch = 1557,	loss = 1.066e-05
# Epoch = 1558,	loss = 1.066e-05
# Epoch = 1559,	loss = 1.066e-05
# Epoch = 1560,	loss = 1.066e-05
# Epoch = 1561,	loss = 1.066e-05
# Epoch = 1562,	loss = 1.066e-05
# Epoch = 1563,	loss = 1.066e-05
# Epoch = 1564,	loss = 1.066e-05
# Epoch = 1565,	loss = 1.066e-05
# Epoch = 1566,	loss = 1.066e-05
# Epoch = 1567,	loss = 1.066e-05
# Epoch = 1568,	loss = 1.066e-05
# Epoch = 1569,	loss = 1.066e-05
# Epoch = 1570,	loss = 1.066e-05
# Epoch = 1571,	loss = 1.066e-05
# Epoch = 1572,	loss = 1.066e-05
# Epoch = 1573,	loss = 1.066e-05
# Epoch = 1574,	loss = 1.066e-05
# Epoch = 1575,	loss = 1.066e-05
# Epoch = 1576,	loss = 1.066e-05
# Epoch = 1577,	loss = 1.066e-05
# Epoch = 1578,	loss = 1.066e-05
# Epoch = 1579,	loss = 1.066e-05
# Epoch = 1580,	loss = 1.066e-05
# Epoch = 1581,	loss = 1.066e-05
# Epoch = 1582,	loss = 1.066e-05
# Epoch = 1583,	loss = 1.066e-05
# ...
# Epoch = 9487,	loss = 1.028e-05
# Epoch = 9488,	loss = 1.028e-05
# Epoch = 9489,	loss = 1.028e-05
# Epoch = 9490,	loss = 1.028e-05
# Epoch = 9491,	loss = 1.028e-05
# Epoch = 9492,	loss = 1.028e-05
# Epoch = 9493,	loss = 1.028e-05
# Epoch = 9494,	loss = 1.028e-05
# Epoch = 9495,	loss = 1.028e-05
# Epoch = 9496,	loss = 1.028e-05
# Epoch = 9497,	loss = 1.028e-05
# Epoch = 9498,	loss = 1.028e-05
# Epoch = 9499,	loss = 1.028e-05
# Epoch = 9500,	loss = 1.028e-05
# Epoch = 9501,	loss = 1.028e-05
# Epoch = 9502,	loss = 1.028e-05
# Epoch = 9503,	loss = 1.028e-05
# Epoch = 9504,	loss = 1.028e-05
# Epoch = 9505,	loss = 1.028e-05
# Epoch = 9506,	loss = 1.028e-05
# Epoch = 9507,	loss = 1.028e-05
# Epoch = 9508,	loss = 1.028e-05
# Epoch = 9509,	loss = 1.028e-05
# Epoch = 9510,	loss = 1.028e-05
# Epoch = 9511,	loss = 1.028e-05
# Epoch = 9512,	loss = 1.028e-05
# Epoch = 9513,	loss = 1.028e-05
# Epoch = 9514,	loss = 1.028e-05
# Epoch = 9515,	loss = 1.028e-05
# Epoch = 9516,	loss = 1.028e-05
# Epoch = 9517,	loss = 1.028e-05
# Epoch = 9518,	loss = 1.028e-05
# Epoch = 9519,	loss = 1.028e-05
# Epoch = 9520,	loss = 1.028e-05
# Epoch = 9521,	loss = 1.028e-05
# Epoch = 9522,	loss = 1.028e-05
# Epoch = 9523,	loss = 1.028e-05
# Epoch = 9524,	loss = 1.028e-05
# Epoch = 9525,	loss = 1.028e-05
# Epoch = 9526,	loss = 1.028e-05
# Epoch = 9527,	loss = 1.028e-05
# Epoch = 9528,	loss = 1.028e-05
# Epoch = 9529,	loss = 1.028e-05
# Epoch = 9530,	loss = 1.028e-05
# Epoch = 9531,	loss = 1.028e-05
# Epoch = 9532,	loss = 1.028e-05
# Epoch = 9533,	loss = 1.028e-05
# Epoch = 9534,	loss = 1.028e-05
# Epoch = 9535,	loss = 1.028e-05
# Epoch = 9536,	loss = 1.028e-05
# Epoch = 9537,	loss = 1.028e-05
# Epoch = 9538,	loss = 1.028e-05
# Epoch = 9539,	loss = 1.028e-05
# Epoch = 9540,	loss = 1.028e-05
# Epoch = 9541,	loss = 1.028e-05
# Epoch = 9542,	loss = 1.028e-05
# Epoch = 9543,	loss = 1.028e-05
# Epoch = 9544,	loss = 1.028e-05
# Epoch = 9545,	loss = 1.028e-05
# Epoch = 9546,	loss = 1.028e-05
# Epoch = 9547,	loss = 1.028e-05
# Epoch = 9548,	loss = 1.028e-05
# Epoch = 9549,	loss = 1.028e-05
# Epoch = 9550,	loss = 1.028e-05
# Epoch = 9551,	loss = 1.028e-05
# Epoch = 9552,	loss = 1.028e-05
# Epoch = 9553,	loss = 1.028e-05
# Epoch = 9554,	loss = 1.028e-05
# Epoch = 9555,	loss = 1.028e-05
# Epoch = 9556,	loss = 1.028e-05
# Epoch = 9557,	loss = 1.028e-05
# Epoch = 9558,	loss = 1.028e-05
# Epoch = 9559,	loss = 1.028e-05
# Epoch = 9560,	loss = 1.028e-05
# Epoch = 9561,	loss = 1.028e-05
# Epoch = 9562,	loss = 1.028e-05
# Epoch = 9563,	loss = 1.028e-05
# Epoch = 9564,	loss = 1.028e-05
# Epoch = 9565,	loss = 1.028e-05
# Epoch = 9566,	loss = 1.028e-05
# Epoch = 9567,	loss = 1.028e-05
# Epoch = 9568,	loss = 1.028e-05
# Epoch = 9569,	loss = 1.028e-05
# Epoch = 9570,	loss = 1.028e-05
# Epoch = 9571,	loss = 1.028e-05
# Epoch = 9572,	loss = 1.028e-05
# Epoch = 9573,	loss = 1.028e-05
# Epoch = 9574,	loss = 1.028e-05
# Epoch = 9575,	loss = 1.028e-05
# Epoch = 9576,	loss = 1.028e-05
# Epoch = 9577,	loss = 1.028e-05
# Epoch = 9578,	loss = 1.028e-05
# Epoch = 9579,	loss = 1.028e-05
# Epoch = 9580,	loss = 1.028e-05
# Epoch = 9581,	loss = 1.028e-05
# Epoch = 9582,	loss = 1.028e-05
# Epoch = 9583,	loss = 1.028e-05
# Epoch = 9584,	loss = 1.028e-05
# Epoch = 9585,	loss = 1.028e-05
# Epoch = 9586,	loss = 1.028e-05
# Epoch = 9587,	loss = 1.028e-05
# Epoch = 9588,	loss = 1.028e-05
# Epoch = 9589,	loss = 1.028e-05
# Epoch = 9590,	loss = 1.028e-05
# Epoch = 9591,	loss = 1.028e-05
# Epoch = 9592,	loss = 1.028e-05
# Epoch = 9593,	loss = 1.028e-05
# Epoch = 9594,	loss = 1.028e-05
# Epoch = 9595,	loss = 1.028e-05
# Epoch = 9596,	loss = 1.028e-05
# Epoch = 9597,	loss = 1.028e-05
# Epoch = 9598,	loss = 1.028e-05
# Epoch = 9599,	loss = 1.028e-05
# Epoch = 9600,	loss = 1.028e-05
# Epoch = 9601,	loss = 1.028e-05
# Epoch = 9602,	loss = 1.028e-05
# Epoch = 9603,	loss = 1.028e-05
# Epoch = 9604,	loss = 1.028e-05
# Epoch = 9605,	loss = 1.028e-05
# Epoch = 9606,	loss = 1.028e-05
# Epoch = 9607,	loss = 1.028e-05
# Epoch = 9608,	loss = 1.028e-05
# Epoch = 9609,	loss = 1.028e-05
# Epoch = 9610,	loss = 1.028e-05
# Epoch = 9611,	loss = 1.028e-05
# Epoch = 9612,	loss = 1.028e-05
# Epoch = 9613,	loss = 1.028e-05
# Epoch = 9614,	loss = 1.028e-05
# Epoch = 9615,	loss = 1.028e-05
# Epoch = 9616,	loss = 1.028e-05
# Epoch = 9967,	loss = 1.027e-05
# Epoch = 9968,	loss = 1.027e-05
# Epoch = 9969,	loss = 1.027e-05
# Epoch = 9970,	loss = 1.027e-05
# Epoch = 9971,	loss = 1.027e-05
# Epoch = 9972,	loss = 1.027e-05
# Epoch = 9973,	loss = 1.027e-05
# Epoch = 9974,	loss = 1.027e-05
# Epoch = 9975,	loss = 1.027e-05
# Epoch = 9976,	loss = 1.027e-05
# Epoch = 9977,	loss = 1.027e-05
# Epoch = 9978,	loss = 1.027e-05
# Epoch = 9979,	loss = 1.027e-05
# Epoch = 9980,	loss = 1.027e-05
# Epoch = 9981,	loss = 1.027e-05
# Epoch = 9982,	loss = 1.027e-05
# Epoch = 9983,	loss = 1.027e-05
# Epoch = 9984,	loss = 1.027e-05
# Epoch = 9985,	loss = 1.027e-05
# Epoch = 9986,	loss = 1.027e-05
# Epoch = 9987,	loss = 1.027e-05
# Epoch = 9988,	loss = 1.027e-05
# Epoch = 9989,	loss = 1.027e-05
# Epoch = 9990,	loss = 1.027e-05
# Epoch = 9991,	loss = 1.027e-05
# Epoch = 9992,	loss = 1.027e-05
# Epoch = 9993,	loss = 1.027e-05
# Epoch = 9994,	loss = 1.027e-05
# Epoch = 9995,	loss = 1.027e-05
# Epoch = 9996,	loss = 1.027e-05
# Epoch = 9997,	loss = 1.027e-05
# Epoch = 9998,	loss = 1.027e-05
# Epoch = 9999,	loss = 1.027e-05
# CPU times: user 37.7 s, sys: 2.67 s, total: 40.4 s
# Wall time: 33.8 s

# %%
# Plotting the Loss Curve
plt.semilogy(loss_value, label="Total", linewidth=2) # Plots the total loss
plt.semilogy(loss_pde, label="PDE", linewidth=2)     # Plots the PDE loss
#plt.semilogy(loss_tau, label="tau", linewidth=2)    # Plots the tau loss

plt.title("Smooth Velocity Loss", fontsize=14)   # Sets the title of the figure

plt.xlabel("Epochs ", fontsize=15)              # Sets the x-axis label of the figure
plt.ylabel("Loss", fontsize=15,)                # Sets the y-axis label of the figure

plt.grid(color = 'black', linestyle = '--', linewidth = 0.5) # Sets the grid of the figure

plt.legend(loc="upper right")   # Sets the legend of the figure

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/Smooth Velocity Loss.pdf", format="pdf", bbox_inches="tight") # Saves the figure

plt.show() # Displays the figure

# %% [markdown]
# <a id="tau_pred"></a>
# #### Tau Prediction

# %%
# Predicts tau output
tau_pred = tau(params,X_star[0].reshape(-1,1),X_star[1].reshape(-1,1))

# %%
# Computes Analytical tau
tau_data = jnp.where(T0 != 0, jnp.divide(T_data, T0), 1)

# %%
#Maximum absolute difference between tau predicted and tau analytical
diff = jnp.abs(tau_pred-tau_data.reshape(-1,1))
jnp.max(diff)
# Out:
# Array(0.00279456, dtype=float32)

# %%
# Tau predicted and tau analytical difference plot

plt.style.use('default')         # Sets the default style for the plot

plt.figure(figsize=(4,4))        # Creates a new figure with a size of 4x4 inches

plt.title("Smooth Velocity Difference Plot (Tau)", fontsize=14)    # Sets the title of the figure

ax = plt.gca()                   # Gets the current axes instance
im = ax.imshow(jnp.abs(tau_pred.reshape(101,101)-tau_data), extent=[x_min,x_max,z_max,z_min], aspect=1, cmap="jet")   # Plots the velocity model velmodel as an image on the current axes (ax)

ax.plot(sx,sz,'k*',markersize=8) # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14)     # Sets the label for the x-axis
plt.xticks(fontsize=10)          # Sets the font size for the x-axis tick labels

plt.ylabel('Depth (km)', fontsize=14)      # Sets the label for the y-axis
plt.yticks(fontsize=10)          # Sets the font size for the y-axis tick labels

ax.xaxis.set_major_locator(plt.MultipleLocator(0.5))   # Sets the major tick locator for the x-axis to have ticks at intervals of 0.5.
ax.yaxis.set_major_locator(plt.MultipleLocator(0.5))   # Sets the major tick locator for the y-axis to have ticks at intervals of 0.5.

divider = make_axes_locatable(ax)         # Creates a divider to make room for the colorbar
cax = divider.append_axes("right", size="6%", pad=0.15) # Appends an axes on the right side of the plot to accommodate the colorbar

cbar = plt.colorbar(im, cax=cax) # Adds a colorbar to the plot using the image im and the colorbar axes cax

cbar.set_label('seconds',size=10)   # Sets the label for the colorbar.
cbar.ax.tick_params(labelsize=10)        # Sets the font size of the colorbar tick labels.

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/Smooth Velocity Difference Plot (Tau).pdf", format= "pdf",bbox_inches="tight")  # Saves the image as a pdf file at the specified file directory

plt.show()   # Displays the defined image

# %%
# Traveltime contour plots

plt.figure(figsize=(5,5)) # Creates a new figure with a size of 5x5 inches

ax = plt.gca()      # Gets the current axes instance

plt.title("Smooth Velocity Contour Plot (Tau)", fontsize=14)    # Sets the title of the figure

im1 = ax.contour(tau_pred.reshape(101,101), 6, extent=[x_min,x_max,z_min,z_max], colors='b') # Plots the contour of tau_pred as an image
im2 = ax.contour(tau_data.reshape(101,101), 6, extent=[x_min,x_max,z_min,z_max], colors='r',linestyles = 'dashed')   # Plots the contour of tau_data as an image

ax.plot(sx,sz,'k*',markersize=8) # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14)   # Sets the x-axis label
plt.ylabel('Depth (km)', fontsize=14)    # Sets the y-axis label

ax.tick_params(axis='both', which='major', labelsize=8)
plt.gca().invert_yaxis()
h1,_ = im1.legend_elements()     # Sets im1 legend
h2,_ = im2.legend_elements()     # Sets im1 legend

ax.legend([h1[0], h2[0]], ['PINN Tau', 'Analytical Tau'],fontsize=12,)  # Sets the combined legend

ax.xaxis.set_major_locator(plt.MultipleLocator(0.5))   # Sets the x-axis
ax.yaxis.set_major_locator(plt.MultipleLocator(0.5))   # Sets the y-axis

plt.xticks(fontsize=10)   # Sets the x-axis ticks
plt.yticks(fontsize=10)   # Sets the y-axis ticks

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/Smooth Velocity Contour Plot (Tau).pdf", format="pdf", bbox_inches="tight")

plt.show()

# %% [markdown]
# <a id="t_pred"></a>
# #### T Prediction

# %%
# Computes T predicted using tau predicted
T_pred = tau_pred *T0.reshape(-1,1)
T_pred.shape
# Out:
# (10201, 1)

# %%
# T predicted and T analytical difference plot

plt.style.use('default')         # Sets the default style for the plot

plt.figure(figsize=(4,4))        # Creates a new figure with a size of 4x4 inches

plt.title("Smooth Velocity Difference Plot (T_1)", fontsize=14)    # Sets the title of the figure

ax = plt.gca()                   # Gets the current axes instance

im = ax.imshow(jnp.abs(T_pred.reshape(101,101)-T_data), extent=[x_min,x_max,z_max,z_min], aspect=1, cmap="jet")# Plots the velocity model velmodel as an image on the current axes (ax)

ax.plot(sx,sz,'k*',markersize=8) # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14)     # Sets the label for the x-axis
plt.xticks(fontsize=10)          # Sets the font size for the x-axis tick labels

plt.ylabel('Depth (km)', fontsize=14)      # Sets the label for the y-axis
plt.yticks(fontsize=10)          # Sets the font size for the y-axis tick labels

ax.xaxis.set_major_locator(plt.MultipleLocator(0.5))   # Sets the major tick locator for the x-axis to have ticks at intervals of 0.5.
ax.yaxis.set_major_locator(plt.MultipleLocator(0.5))   # Sets the major tick locator for the y-axis to have ticks at intervals of 0.5.

divider = make_axes_locatable(ax)         # Creates a divider to make room for the colorbar
cax = divider.append_axes("right", size="6%", pad=0.15) # Appends an axes on the right side of the plot to accommodate the colorbar

cbar = plt.colorbar(im, cax=cax) # Adds a colorbar to the plot using the image im and the colorbar axes cax

cbar.set_label('seconds',size=10)   # Sets the label for the colorbar.
cbar.ax.tick_params(labelsize=10)        # Sets the font size of the colorbar tick labels.

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/Smooth Velocity Difference Plot (T_1).pdf", format= "pdf",bbox_inches="tight")  # Saves the image as a pdf file at the specified file directory

plt.show()   # Displays the defined image

# %%
# Load fast sweeping traveltims for comparison
T_fsm = jnp.load("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/inputs/vofz/traveltimes/Tcomp.npy")

# %%
# T predicted and T analytical difference plot

plt.style.use('default')         # Sets the default style for the plot

plt.figure(figsize=(4,4))        # Creates a new figure with a size of 4x4 inches

plt.title("Smooth Velocity Difference Plot (T_2)", fontsize=14)    # Sets the title of the figure

ax = plt.gca()                   # Gets the current axes instance

im = ax.imshow(jnp.abs(T_fsm.reshape(101,101)-T_data.reshape(101,101)), extent=[x_min,x_max,z_max,z_min], aspect=1, cmap="jet")# Plots the velocity model velmodel as an image on the current axes (ax)

ax.plot(sx,sz,'k*',markersize=8) # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14)     # Sets the label for the x-axis
plt.xticks(fontsize=10)          # Sets the font size for the x-axis tick labels

plt.ylabel('Depth (km)', fontsize=14)      # Sets the label for the y-axis
plt.yticks(fontsize=10)          # Sets the font size for the y-axis tick labels

ax.xaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the major tick locator for the x-axis to have ticks at intervals of 0.5.
ax.yaxis.set_major_locator(plt.MultipleLocator(2))   # Sets the major tick locator for the y-axis to have ticks at intervals of 0.5.

divider = make_axes_locatable(ax)         # Creates a divider to make room for the colorbar
cax = divider.append_axes("right", size="6%", pad=0.15) # Appends an axes on the right side of the plot to accommodate the colorbar

cbar = plt.colorbar(im, cax=cax) # Adds a colorbar to the plot using the image im and the colorbar axes cax

cbar.set_label('seconds',size=10)   # Sets the label for the colorbar.
cbar.ax.tick_params(labelsize=10)        # Sets the font size of the colorbar tick labels.

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/Smooth Velocity Difference Plot (T_2).pdf", format= "pdf",bbox_inches="tight")  # Saves the image as a pdf file at the specified file directory

plt.show()   # Displays the defined image

# %%
# Traveltime contour plots

plt.figure(figsize=(5,5)) # Creates a new figure with a size of 5x5 inches

ax = plt.gca()      # Gets the current axes instance

plt.title("Smooth Velocity Contour Plot (T)", fontsize=14)    # Sets the title of the figure

# Plots the contours of the difference T values as an image
im1 = ax.contour(T_data.reshape(101,101), 6, extent=[x_min,x_max,z_min,z_max], colors='r')
im2 = ax.contour(T_pred.reshape(101,101), 6, extent=[x_min,x_max,z_min,z_max], colors='b',linestyles = 'dashed')
im3 = ax.contour(T_fsm.reshape(101,101), 6, extent=[x_min,x_max,z_min,z_max], colors='k',linestyles = 'dotted')


ax.plot(sx,sz,'k*',markersize=8) # Plots a black star marker at the source location 

plt.xlabel('Offset (km)', fontsize=14)   # Sets the x-axis label
plt.ylabel('Depth (km)', fontsize=14)    # Sets the y-axis label

ax.tick_params(axis='both', which='major', labelsize=8)
plt.gca().invert_yaxis()

# Sets im1 legend
h1,_ = im1.legend_elements()
h2,_ = im2.legend_elements()
h3,_ = im3.legend_elements()

ax.legend([h1[0], h2[0], h3[0]], ['Analytical', 'PINN', 'Fast sweeping'],fontsize=12)  # Sets the combined legend

ax.xaxis.set_major_locator(plt.MultipleLocator(0.5))   # Sets the x-axis
ax.yaxis.set_major_locator(plt.MultipleLocator(0.5))   # Sets the y-axis

plt.xticks(fontsize=10)   # Sets the x-axis ticks
plt.yticks(fontsize=10)   # Sets the y-axis ticks

plt.savefig("/home/archibong/Desktop/PINNs/Jax/Archibong1/PINNEik Using Jax/Images/Smooth Velocity Contour Plot (T).pdf", format="pdf", bbox_inches="tight")

plt.show()

# %% [markdown]
# <a id="accuracy"></a>
# #### Rapid Accuracy Assessment

# %%
# Determining the accuracy of the model by quantifying the difference between T_pred and T_data using Vector Norm
print(jnp.linalg.norm(T_pred-T_data.reshape(-1,1))/jnp.linalg.norm(T_data))
print(jnp.linalg.norm(T_pred-T_data.reshape(-1,1)))
# Out:
# 0.00026755294
# 0.008985362
